# %% [markdown]
# # Day 50 Challenges: Writing Files

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write the string `'Hello, file world!'` to a file called `greeting.txt`,
# then read it back and print it.
#
# Expected output: `Hello, file world!`

# %%
# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Write the following list to `fruits.txt`, one fruit per line:
# ```python
# fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']
# ```
# Then read the file back and print it.

# %%
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry']

# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Create `log.txt` with write mode and add `'First entry'`.
# Then open it twice more in **append** mode to add `'Second entry'` and `'Third entry'`.
# Read it back and confirm all three entries are there.

# %%
# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Use `.writelines()` to write these three strings to `demo_writelines.txt`:
# ```python
# lines = ['line one\n', 'line two\n', 'line three\n']
# ```
# Read it back and confirm it looks right.

# %%
lines = ['line one\n', 'line two\n', 'line three\n']

# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write the integers 1 to 10 to `numbers.txt` (one per line).
# Then read the file back and print the **sum** of all the numbers.
#
# Expected output: `Sum: 55`

# %%
# your code here
