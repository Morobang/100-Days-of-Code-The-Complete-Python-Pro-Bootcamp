# %% [markdown]
# # Day 51 Challenges: Working with Paths

# %% [markdown]
# ## Challenge 1 ⭐
#
# Print the current working directory using `os.getcwd()`.

# %%
import os

# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Use `os.path.join()` to build the path `'data/reports/summary.txt'` from three parts.
# Then check whether that path exists on disk and print `True` or `False`.

# %%
import os

# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given `path = 'docs/reports/annual_report.txt'`, use `os.path` functions to print:
# - The filename only: `annual_report.txt`
# - The directory: `docs/reports`
# - The name without extension: `annual_report`
# - The extension: `.txt`

# %%
import os

path = 'docs/reports/annual_report.txt'

# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# List everything in the current directory using `os.listdir('.')`.
# For each entry print whether it is a `FILE` or a `DIR` followed by its name.
# Sort the output alphabetically.

# %%
import os

# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Repeat Challenge 4 using `pathlib.Path` instead of `os`.
# Use `Path('.').iterdir()` and the `.is_dir()` / `.is_file()` methods.
# Also print the file extension (`.suffix`) for files, or `'dir'` for directories.

# %%
from pathlib import Path

# your code here
