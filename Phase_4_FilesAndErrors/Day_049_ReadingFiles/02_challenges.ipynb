# %% [markdown]
# # Day 49 Challenges: Reading Files
#
# All challenges read from `sample.txt` in this folder.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Open `sample.txt` using a `with` statement and `.read()`, then print the full contents.

# %%
# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Count and print the number of lines in `sample.txt`.
#
# Expected output: `Number of lines: 5`

# %%
# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Read `sample.txt` line by line and print each line with its leading and trailing whitespace removed.
# Use `for line in f:` — do not use `.readlines()`.

# %%
# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Count how many times the word `'the'` appears in `sample.txt` (case-insensitive).
#
# Hint: `.lower().split()` and `.count()`.

# %%
# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Find and print the **longest line** in `sample.txt` and its character count.
#
# Expected format: `Longest line (44 chars): The quick brown fox...`

# %%
# your code here
