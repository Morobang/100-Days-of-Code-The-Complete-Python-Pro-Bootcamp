# %% [markdown]
# # Day 52 Challenges: Exception Handling

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write `safe_divide(a, b)` that returns `a / b`.
# If `b` is zero, catch the exception, print `'Error: cannot divide by zero'`, and return `None`.
#
# ```python
# safe_divide(10, 2)   # 5.0
# safe_divide(10, 0)   # prints error, returns None
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Write `safe_int(s)` that tries to convert `s` to an integer.
# If it fails, print an error message and return `None`.
#
# ```python
# safe_int('42')    # 42
# safe_int('abc')   # error message, None
# safe_int('3.5')   # error message, None
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write `read_file_safe(filename)` that opens and reads a file.
# If the file does not exist, catch the exception, print a message, and return `None`.
#
# ```python
# read_file_safe('nope.txt')   # prints 'File not found', returns None
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write `parse_number(s)` that tries to convert `s` to `int`.
# Handle two exception types separately:
# - `ValueError` — print `'ValueError: ...'` with the error text
# - `TypeError` — print `'TypeError: expected a string'`
#
# Use `else` to print `'Parsed: {value}'` on success.
#
# ```python
# parse_number('10')   # Parsed: 10
# parse_number('abc')  # ValueError message
# parse_number(None)   # TypeError message
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write `safe_divide_v2(a, b)` that uses all four clauses: `try`, `except`, `else`, `finally`.
#
# - `except`: catch `ZeroDivisionError`, print an error
# - `else`: print the result (only runs if no error)
# - `finally`: always print `'done'`
# - Return the result (or `None` on error)
#
# ```python
# safe_divide_v2(10, 2)   # prints result, then 'done'
# safe_divide_v2(10, 0)   # prints error, then 'done'
# ```

# %%
# your code here
