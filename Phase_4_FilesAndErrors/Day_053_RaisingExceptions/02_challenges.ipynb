# %% [markdown]
# # Day 53 Challenges: Raising Exceptions

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write `get_positive(n)` that returns `n` if it is greater than zero.
# Otherwise raise `ValueError` with a descriptive message.
#
# ```python
# get_positive(5)    # 5
# get_positive(0)    # ValueError
# get_positive(-3)   # ValueError
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Write `divide(a, b)` that returns `a / b`.
# If `b` is zero, raise `ZeroDivisionError` with a custom message (do not let Python's default fire).
#
# ```python
# divide(10, 2)   # 5.0
# divide(10, 0)   # ZeroDivisionError: 'cannot divide by zero'
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write `validate_age(age)` that:
# - Raises `TypeError` if `age` is not an `int`
# - Raises `ValueError` if `age` is outside the range 0–150
# - Returns `age` if valid
#
# Test it with `[25, -1, 200, 'thirty']` and catch each exception.

# %%
# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write `safe_open(filename)` that tries to open and read a file.
# If the file is not found, catch `FileNotFoundError` and re-raise it with a clearer message:
# `f"Required file '{filename}' is missing"`.
#
# Test it with a filename that does not exist.

# %%
# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write two functions:
# - `risky()` — always raises `RuntimeError('something went wrong')`
# - `wrapper()` — calls `risky()`, catches `RuntimeError`, prints `'logging error'`, then **re-raises** it
#
# Call `wrapper()` inside a `try/except` and confirm the outer block catches the re-raised exception.

# %%
# your code here
