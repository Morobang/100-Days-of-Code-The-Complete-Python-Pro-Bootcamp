# %% [markdown]
# # Day 36 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–36.
# All functions today take **no parameters** — just `def name():`

# %% [markdown]
# ## Challenge 1 ⭐
#
# Define a function called `print_greeting()` that prints a short two-line greeting.
#
# Then call it **three times** in a row. Confirm you get the same output each time.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Define two functions:
# - `print_separator()` — prints a row of 40 dashes
# - `print_title()` — prints the text `'MY PYTHON JOURNAL'` centred between two separators
#
# Call them in an order that produces a nice title block.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Define a `show_menu()` function that prints a numbered menu:
# ```
# 1. Add item
# 2. View items
# 3. Quit
# ```
#
# Call it, then read the user's choice. Print a message confirming which option they chose (just the text — don't implement the options yet).

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Define **four** functions — one for each section of a simple profile card:
# - `print_name()` — prints your name
# - `print_role()` — prints your job title or student status
# - `print_skills()` — prints 3 skills you have or want
# - `print_goal()` — prints one sentence about your goal
#
# Then write a `print_profile()` function that calls all four in order with a separator between each section. Call `print_profile()` once.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a **morning report program** using only no-parameter functions.
#
# Define at least 5 functions that each print one section:
# - `print_date_section()` — use `input()` to ask for today's date, print it
# - `print_mood_section()` — ask for today's mood (1–5), print a message based on it
# - `print_tasks_section()` — ask for 3 tasks, print them as a numbered list
# - `print_goal_section()` — print an encouraging fixed message
# - `print_report_header()` and `print_report_footer()` — formatted borders
#
# Write a `run_report()` function that calls all of them in order. Call `run_report()` once.

# %%
# Your code here
