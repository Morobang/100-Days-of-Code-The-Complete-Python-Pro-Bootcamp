# %% [markdown]
# # Day 41 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–41.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write a function `display_info(**kwargs)` that prints each key-value pair on its own line:
# ```
# name: Alice
# age: 30
# city: Cape Town
# ```
#
# Call it twice with completely different sets of keyword arguments.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Write a function `create_profile(username, **details)` that:
# - Prints `'Profile: {username}'` as a header
# - Prints each key-value pair from `details` indented
# - Prints `'(no details provided)'` if `details` is empty
#
# Call it with and without details.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write a function `configure(host='localhost', port=8080, **options)` that:
# - Prints the required settings (`host` and `port`)
# - Prints any additional options from `**options`
#
# Call it:
# 1. With no arguments (all defaults)
# 2. With just `host`
# 3. With `host`, `port`, and extra options (`debug=True`, `log_level='info'`)

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# You have this function:
# ```python
# def book_flight(destination, passengers, class_type='economy'):
#     print(f'Booking {passengers} seat(s) to {destination} ({class_type})')
# ```
#
# Create two dicts:
# ```python
# booking1 = {'destination': 'Paris', 'passengers': 2}
# booking2 = {'destination': 'Tokyo', 'passengers': 1, 'class_type': 'business'}
# ```
#
# Use `**` unpacking to call `book_flight` with each dict.
# Then create a `defaults` dict and an `overrides` dict, merge them with `**`, and call the function with the merged result.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write a function `build_report(title, *sections, **metadata)` that:
# - Prints `title` as a header
# - Prints each string in `sections` as a numbered section body
# - Prints any `metadata` key-value pairs as a footer
#
# Example call:
# ```python
# build_report(
#     'Monthly Sales Report',
#     'Revenue increased by 12%.',
#     'Top product: Widget Pro.',
#     'Customer complaints down 5%.',
#     author='Alice',
#     date='2024-11-01',
#     version='2'
# )
# ```
#
# Expected output:
# ```
# === Monthly Sales Report ===
# 1. Revenue increased by 12%.
# 2. Top product: Widget Pro.
# 3. Customer complaints down 5%.
# --- Metadata ---
# author: Alice
# date: 2024-11-01
# version: 2
# ```

# %%
# Your code here
