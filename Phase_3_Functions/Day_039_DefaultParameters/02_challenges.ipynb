# %% [markdown]
# # Day 39 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–39.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write a function `greet(name, greeting='Hello', punctuation='!')` that prints the greeting.
#
# Call it:
# 1. With just a name
# 2. With a name and a custom greeting
# 3. With all three arguments
# 4. Using keyword arguments to set only `punctuation` (skip the greeting)

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Write a function `make_box(text, width=40, border_char='*')` that prints a text centred inside a box:
#
# ```
# ****************************************
# *            Hello World!             *
# ****************************************
# ```
#
# Call it three times:
# 1. With just text (defaults)
# 2. With a custom width
# 3. With a custom border character

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write a function `power(base, exponent=2)` that returns `base ** exponent`.
#
# Then write `power_table(base, max_exp=5)` that prints all powers of `base` from 1 to `max_exp`:
# ```
# 3^1 = 3
# 3^2 = 9
# 3^3 = 27
# ...
# ```
#
# Call `power_table` twice — once with just a base, once with a custom max_exp.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write a function `search(items, target, case_sensitive=False)` that:
# - Returns `True` if `target` is in `items`
# - When `case_sensitive=False` (default), ignores case during comparison
# - When `case_sensitive=True`, matches exactly
#
# Test:
# ```python
# words = ['Python', 'Java', 'Rust', 'Go']
# search(words, 'python')         # True  (case-insensitive)
# search(words, 'python', True)   # False (case-sensitive — 'python' ≠ 'Python')
# search(words, 'Python', True)   # True
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a `format_table(data, headers=None, col_width=12)` function that prints a list of tuples as a formatted table.
#
# - `data` — a list of tuples, one per row
# - `headers` — optional tuple of column header names
# - `col_width` — width of each column (default 12)
#
# Example:
# ```python
# rows = [('Alice', 88, 'A'), ('Bob', 75, 'B'), ('Charlie', 92, 'A')]
# format_table(rows, headers=('Name', 'Score', 'Grade'))
# ```
# ```
# Name        Score       Grade
# ------------ ------------ ------------
# Alice        88           A
# Bob          75           B
# Charlie      92           A
# ```

# %%
# Your code here
