# %% [markdown]
# # Day 46 Challenges: Lambda Functions

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create a lambda called `double` that takes one number and returns it multiplied by 2.
#
# ```python
# double(5)   # 10
# double(3)   # 6
# double(0)   # 0
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Sort the list `words` by word length (shortest first) using `sorted()` with a lambda `key=`.
#
# ```python
# words = ['banana', 'apple', 'cherry', 'date']
# # expected: ['date', 'apple', 'banana', 'cherry']
# ```

# %%
words = ['banana', 'apple', 'cherry', 'date']

# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Sort the list of tuples by the **second** element using a lambda `key=`.
#
# ```python
# pairs = [(3, 'c'), (1, 'a'), (2, 'b')]
# # expected: [(1, 'a'), (2, 'b'), (3, 'c')]
# ```

# %%
pairs = [(3, 'c'), (1, 'a'), (2, 'b')]

# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Create a lambda called `add` that takes **two** numbers and returns their sum.
#
# ```python
# add(3, 7)   # 10
# add(10, 5)  # 15
# add(0, 0)   # 0
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Sort the list of dicts by `age` (ascending) using a lambda `key=`.
# Then print each person's name and age on one line.
#
# Expected output:
# ```
# Alice: 25
# Charlie: 30
# Bob: 35
# ```

# %%
people = [
    {'name': 'Charlie', 'age': 30},
    {'name': 'Alice',   'age': 25},
    {'name': 'Bob',     'age': 35},
]

# your code here
