# %% [markdown]
# # Day 40 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–40.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write a function `my_sum(*args)` that returns the sum of any number of arguments.
#
# Then write `my_product(*args)` that returns the product.
#
# Test each with 0, 1, and several arguments.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Write `print_all(label, *items)` that prints a label followed by each item on its own line:
#
# ```
# Fruits:
#   - apple
#   - banana
#   - cherry
# ```
#
# Call it with at least 3 different labels and varying numbers of items.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write a function `stats(*numbers)` that returns the minimum, maximum, and average of any set of numbers. Handle the case where no numbers are passed (return `None, None, None`).
#
# Unpack the return values and print a formatted summary.
#
# Then call it by unpacking an existing list with `*`.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write a function `concatenate(separator, *words)` that joins any number of words with the given separator and returns the result.
#
# ```python
# concatenate('-', 'hello', 'world')           # 'hello-world'
# concatenate(', ', 'one', 'two', 'three')     # 'one, two, three'
# concatenate(' | ', 'a')                      # 'a'
# concatenate('/', 'usr', 'local', 'bin')      # 'usr/local/bin'
# ```
#
# Do **not** use `str.join()` — build the string with a loop.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write a function `run_pipeline(*functions, value)` — wait, that won't work without keyword-only args. Instead:
#
# Write `apply_all(value, *functions)` that applies each function in `functions` to `value` in sequence, passing the output of one as the input to the next, and returns the final result.
#
# ```python
# def double(x): return x * 2
# def add_ten(x): return x + 10
# def square(x): return x ** 2
#
# result = apply_all(3, double, add_ten, square)
# # 3 → double → 6 → add_ten → 16 → square → 256
# print(result)   # 256
# ```
#
# Test with at least 3 different pipelines.

# %%
# Your code here
