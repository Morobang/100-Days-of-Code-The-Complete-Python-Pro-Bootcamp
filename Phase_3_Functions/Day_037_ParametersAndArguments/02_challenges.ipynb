# %% [markdown]
# # Day 37 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–37.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write a function `greet(name)` that prints `'Hello, {name}! Welcome.'`
#
# Call it with at least 4 different names.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Write a function `describe_book(title, author, year)` that prints a one-line description:
# `'Title' by Author (Year)`
#
# Call it with three different books.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write a function `print_list(title, items)` that:
# 1. Prints the `title` as a header (with a separator below it)
# 2. Prints each item in `items` as a numbered list
#
# Call it twice with different titles and lists.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write a function `print_score_report(name, score, subject)` that prints a formatted one-line report:
# ```
# Alice  | Maths   | Score: 88 | Grade: B
# ```
# (Grade: A≥80, B≥70, C≥60, D≥50, F otherwise)
#
# Call it for at least 4 different students across different subjects.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write a suite of functions that all take the **same** list of `(name, score)` tuples and produce different reports:
#
# - `print_all_results(results)` — print every student and score
# - `print_passing(results)` — print only students with score ≥ 70
# - `print_failing(results)` — print only students with score < 70
# - `print_top_scorer(results)` — print the name and score of the highest scorer
# - `print_summary(results)` — print count, average, highest, and lowest score
#
# Test with:
# ```python
# data = [('Alice', 88), ('Bob', 45), ('Charlie', 72), ('Diana', 91), ('Eve', 55), ('Frank', 78)]
# ```

# %%
# Your code here
