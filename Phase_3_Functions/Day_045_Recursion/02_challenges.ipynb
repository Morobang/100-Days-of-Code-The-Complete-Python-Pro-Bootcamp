# %% [markdown]
# # Day 45 Challenges: Recursion

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write a recursive function `countdown(n)` that prints every integer from `n` down to `0`.
#
# Expected output for `countdown(5)`: `5 4 3 2 1 0` (one per line).

# %%
# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Write a recursive function `sum_list(numbers)` that returns the sum of a list of numbers.
#
# Do **not** use `sum()` or a loop.
#
# ```python
# sum_list([1, 2, 3, 4, 5])  # 15
# sum_list([10])              # 10
# sum_list([])                # 0
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write a recursive function `factorial(n)` that returns `n!`.
#
# Recall: `0! = 1`, `n! = n * (n-1)!`
#
# ```python
# factorial(0)   # 1
# factorial(5)   # 120
# factorial(10)  # 3628800
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write a recursive function `power(base, exp)` that returns `base ** exp`.
#
# Do **not** use the `**` operator — implement it using multiplication only.
#
# Hint: `base ** exp = base * base ** (exp - 1)` and `base ** 0 = 1`.
#
# ```python
# power(2, 10)  # 1024
# power(3, 4)   # 81
# power(5, 0)   # 1
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write a recursive function `reverse_string(s)` that returns the reverse of a string.
#
# Do **not** use slicing (`s[::-1]`) — implement it recursively.
#
# Hint: the reverse of `'hello'` is the reverse of `'ello'` plus `'h'` at the end.
#
# ```python
# reverse_string('hello')   # 'olleh'
# reverse_string('Python')  # 'nohtyP'
# reverse_string('')        # ''
# reverse_string('a')       # 'a'
# ```

# %%
# your code here
