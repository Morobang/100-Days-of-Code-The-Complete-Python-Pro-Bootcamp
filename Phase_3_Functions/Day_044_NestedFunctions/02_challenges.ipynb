# %% [markdown]
# # Day 44 Challenges: Nested Functions

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write a function `outer()` that:
# - Defines a local variable `message = 'I am from the outer function'`
# - Defines an inner function `inner()` that prints `message`
# - Calls `inner()`
#
# Call `outer()` to verify it works.

# %%
# your code here

# %% [markdown]
# ## Challenge 2 ⭐⭐
#
# Write a factory function `make_greeter(greeting)` that returns a function.
# The returned function should take a `name` parameter and print `'{greeting}, {name}!'`.
#
# ```python
# hello = make_greeter('Hello')
# hi    = make_greeter('Hi')
# hello('Alice')   # Hello, Alice!
# hi('Bob')        # Hi, Bob!
# hello('Charlie') # Hello, Charlie!
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write a factory function `make_counter()` that returns an `increment` function.
# Each call to the returned function should add 1 to a private count and return it.
# Each call to `make_counter()` should produce an **independent** counter.
#
# Hint: use `nonlocal`.
#
# ```python
# counter = make_counter()
# print(counter())  # 1
# print(counter())  # 2
# print(counter())  # 3
# other = make_counter()
# print(other())    # 1  — independent
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write a factory function `make_power(exp)` that returns a function.
# The returned function takes a `base` and returns `base ** exp`.
#
# ```python
# square = make_power(2)
# cube   = make_power(3)
# print(square(4))   # 16
# print(cube(3))     # 27
# print(square(10))  # 100
# ```

# %%
# your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write a factory function `make_pipeline(func1, func2)` that returns a function.
# The returned function takes a single value, applies `func1` to it, then applies `func2` to the result.
#
# Test it with these two simple functions:
# ```python
# def double(x):
#     return x * 2
#
# def add_ten(x):
#     return x + 10
# ```
#
# Expected:
# ```python
# double_then_add = make_pipeline(double, add_ten)
# add_then_double = make_pipeline(add_ten, double)
# print(double_then_add(5))  # (5 * 2) + 10 = 20
# print(add_then_double(5))  # (5 + 10) * 2 = 30
# ```

# %%
def double(x):
    return x * 2

def add_ten(x):
    return x + 10

# your code here
