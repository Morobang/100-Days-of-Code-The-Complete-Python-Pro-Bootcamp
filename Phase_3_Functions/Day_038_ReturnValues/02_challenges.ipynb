# %% [markdown]
# # Day 38 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–38.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Write the following functions that each **return** a value:
# 1. `cube(n)` — returns n³
# 2. `celsius_to_fahrenheit(c)` — returns the Fahrenheit equivalent (`c * 9/5 + 32`)
# 3. `initials(first, last)` — returns a string like `'A.S.'`
#
# Print the return value of each.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Write these boolean-returning functions:
# 1. `is_palindrome(word)` — returns `True` if the word reads the same backwards
# 2. `is_strong_password(password)` — returns `True` if the password is at least 8 characters and contains at least one digit
#
# Test each with at least 3 inputs.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Write a function `analyse(numbers)` that takes a list of numbers and returns **four values**: minimum, maximum, total, and average.
#
# Unpack all four values when you call it. Print a formatted summary using the unpacked values.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Write a function `safe_divide(a, b)` that:
# - Returns the result of `a / b` normally
# - Uses an **early return** of `None` if `b` is zero
#
# Then write a function `format_result(result)` that:
# - Returns `'Error: division by zero'` if `result is None`
# - Returns the result formatted to 2 decimal places otherwise
#
# Chain them: call `format_result(safe_divide(a, b))` for several pairs.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a **unit converter** using a chain of functions.
#
# Write these functions (all return values — none print directly):
# - `get_value()` — asks user for a number, returns it as a float
# - `km_to_miles(km)` — returns the value in miles (1 km = 0.621371)
# - `miles_to_km(miles)` — returns the value in km
# - `kg_to_pounds(kg)` — returns the value in pounds (1 kg = 2.20462)
# - `format_conversion(original, unit_from, result, unit_to)` — returns a formatted string
#
# Then write a `run_converter()` function that shows a menu, gets user input, calls the right converter, and prints the formatted result.
#
# Example output: `5.0 km = 3.11 miles`

# %%
# Your code here
