# %% [markdown]
# # Day 34 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–34.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Using **dict comprehensions**, create and print:
# 1. A dict mapping numbers 1–10 to their cubes: `{1: 1, 2: 8, 3: 27, ...}`
# 2. A dict mapping each word in `['cat', 'elephant', 'dog', 'ant']` to its length
# 3. A dict mapping each letter in `'python'` to its position in the string (0-indexed)

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given:
# ```python
# inventory = {'apple': 50, 'banana': 0, 'cherry': 20, 'mango': 0, 'kiwi': 15}
# ```
#
# Using dict comprehensions, create:
# 1. A dict of only items **in stock** (quantity > 0)
# 2. A dict of items **out of stock**
# 3. A dict of in-stock items with their quantities **doubled**

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given:
# ```python
# student_ids = {'Alice': 1001, 'Bob': 1002, 'Charlie': 1003, 'Diana': 1004}
# ```
#
# 1. Use a dict comprehension to **invert** the dict (id → name).
# 2. Use that inverted dict to look up who has student ID `1003`.
# 3. Add a grade for each student: create a new dict `{name: 'unknown'}` for all students using `dict.fromkeys()`, then update it with real grades using `.update()`.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Ask the user to enter a sentence. Using a **dict comprehension**, build a word frequency dictionary.
#
# Then using another dict comprehension, create a filtered version that only includes words that appear **more than once**.
#
# Print both dicts.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Given:
# ```python
# results = [
#     ('Alice', 88), ('Bob', 45), ('Charlie', 72),
#     ('Diana', 91), ('Eve', 55), ('Frank', 78)
# ]
# ```
#
# Using comprehensions (list, dict, or set — choose appropriately):
#
# 1. A **dict** mapping name → score for everyone
# 2. A **dict** mapping name → grade (A≥80, B≥70, C≥60, D≥50, F otherwise)
# 3. A **set** of all grades that appear
# 4. A **list** of strings `'Name passed'` or `'Name failed'` depending on whether score ≥ 70
#
# Print all four.

# %%
# Your code here
