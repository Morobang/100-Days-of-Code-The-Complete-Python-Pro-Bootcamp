# %% [markdown]
# # Day 24 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–24.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Given:
# ```python
# grid = [
#     [10, 20, 30],
#     [40, 50, 60],
#     [70, 80, 90]
# ]
# ```
#
# Print:
# - The value at row 0, column 2
# - The value at row 2, column 0
# - The centre value
# - The entire second row
# - The last value using only negative indices

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given a classroom seating chart:
# ```python
# classroom = [
#     ['Alice', 'Bob', 'Charlie'],
#     ['Diana', 'Eve', 'Frank'],
#     ['Grace', 'Heidi', 'Ivan']
# ]
# ```
#
# Print it neatly so each row appears on one line with names separated by ' | '.
#
# Example:
# ```
# Row 1: Alice | Bob | Charlie
# Row 2: Diana | Eve | Frank
# Row 3: Grace | Heidi | Ivan
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given:
# ```python
# numbers = [
#     [3, 7, 2, 9],
#     [1, 5, 8, 4],
#     [6, 0, 3, 7]
# ]
# ```
#
# Use nested loops to:
# 1. Find and print the **largest** value in the entire grid
# 2. Find and print the **sum** of all values
# 3. Count how many values are **greater than 5**

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# **Flatten** a 2D list into a 1D list using nested loops.
#
# ```python
# matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# ```
#
# Expected result: `[1, 2, 3, 4, 5, 6, 7, 8, 9]`
#
# Then print the sum, min, and max of the flattened list.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a **5×5 multiplication table** as a 2D list (rows 1–5, columns 1–5), then print it formatted.
#
# Expected output:
# ```
#    1   2   3   4   5
#    2   4   6   8  10
#    3   6   9  12  15
#    4   8  12  16  20
#    5  10  15  20  25
# ```
#
# Each number should be right-aligned in a field of width 4.

# %%
# Your code here
