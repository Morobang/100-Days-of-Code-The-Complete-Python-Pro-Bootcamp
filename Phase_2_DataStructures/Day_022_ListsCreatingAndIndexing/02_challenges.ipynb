# %% [markdown]
# # Day 22 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–22.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create a list of 5 of your favourite foods. Using only indexing (no hardcoded positions like `[0]` allowed except for first/last), print:
# - The first food
# - The last food
# - The middle food (hint: use `len()` and `//`)

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Use `list(range())` to create:
# 1. A list of even numbers from 2 to 20 (inclusive)
# 2. A list counting down from 10 to 1
# 3. A list of multiples of 3 from 3 to 30
#
# Print each list.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given:
# ```python
# letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
# ```
#
# Using slices, print:
# 1. The first four letters
# 2. The last three letters
# 3. Every other letter (a, c, e, g)
# 4. The list reversed

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Create a list of at least 6 fruit names. Ask the user to enter a fruit.
#
# - If it's in the list: print how many fruits are in the list and what position (index) the entered fruit is at.
# - If it's not in the list: print a message saying it's not available.
#
# Make the check case-insensitive.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# **The copy trap — spot the bug, then fix it.**
#
# Part A: Run this code and explain why both lists change:
# ```python
# team_a = ['Alice', 'Bob', 'Charlie']
# team_b = team_a
# team_b.append('Diana')
# print('team_a:', team_a)
# print('team_b:', team_b)
# ```
#
# Part B: Fix the code so that adding Diana to team_b does NOT affect team_a.
# Then add a different player to team_a and print both lists to prove they are independent.

# %%
# Your code here
