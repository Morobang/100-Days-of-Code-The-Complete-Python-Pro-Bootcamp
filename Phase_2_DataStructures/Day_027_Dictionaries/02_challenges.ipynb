# %% [markdown]
# # Day 27 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–27.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Given:
# ```python
# results = ['pass', 'fail', 'pass', 'pass', 'fail', 'pass', 'fail', 'pass']
# ```
#
# Count how many times each result appears using a dictionary. Print each result and its count.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Ask the user to enter a sentence. Count the frequency of each **letter** (ignore spaces, case-insensitive).
#
# Print each letter and its count, sorted alphabetically.
#
# Example for `'Hello World'`:
# ```
# d: 1
# e: 1
# h: 1
# l: 3
# o: 2
# r: 1
# w: 1
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given:
# ```python
# students = [
#     ('Alice', 'Maths'),
#     ('Bob', 'Science'),
#     ('Charlie', 'Maths'),
#     ('Diana', 'English'),
#     ('Eve', 'Science'),
#     ('Frank', 'Maths')
# ]
# ```
#
# Build a dictionary that groups students by subject. Each key is a subject name, each value is a list of student names.
#
# Expected result:
# ```python
# {'Maths': ['Alice', 'Charlie', 'Frank'], 'Science': ['Bob', 'Eve'], 'English': ['Diana']}
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Given these two parallel lists:
# ```python
# elements = ['Hydrogen', 'Helium', 'Lithium', 'Carbon', 'Oxygen']
# symbols  = ['H', 'He', 'Li', 'C', 'O']
# ```
#
# 1. Build a `name → symbol` dictionary.
# 2. Build the inverted `symbol → name` dictionary.
# 3. Ask the user to enter either an element name or a symbol. Look it up in whichever dict applies and print the other value.
#
# Example:
# ```
# Enter element or symbol: He
# He → Helium
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user to enter exam scores for students (name and score per line). Stop when they type `done`.
#
# Then print:
# 1. A **grade distribution** — count how many scores fall into each grade band:
#    - A: 80–100, B: 70–79, C: 60–69, D: 50–59, F: below 50
# 2. The **top scorer** (name and score)
# 3. The **class average** (rounded to 1 decimal place)
#
# Example:
# ```
# Name (or 'done'): Alice
# Score: 88
# Name (or 'done'): Bob
# Score: 73
# Name (or 'done'): done
#
# Grade distribution:
#   A: 1
#   B: 1
# Top scorer: Alice — 88
# Average: 80.5
# ```

# %%
# Your code here
