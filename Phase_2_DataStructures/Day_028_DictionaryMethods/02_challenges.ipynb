# %% [markdown]
# # Day 28 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–28.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create the same dictionary three ways:
# 1. Using a literal `{}`
# 2. Using `dict()` with keyword arguments
# 3. Using `dict()` with a list of tuples
#
# The dict should represent a book: `title`, `author`, `year`.
#
# Print all three and confirm they are equal with `==`.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Use `dict.fromkeys()` to create a "stock tracker" for these items:
# ```python
# items = ['apple', 'banana', 'cherry', 'mango', 'kiwi']
# ```
#
# All items should start with a stock of `0`. Then update a few items with real stock values. Print the final dict.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given:
# ```python
# base   = {'host': 'localhost', 'port': 5432, 'db': 'myapp', 'debug': False}
# override = {'port': 3306, 'debug': True}
# ```
#
# 1. Use `**` unpacking to merge them into a new dict (override wins).
# 2. Also add a key `'version': '2.0'` in the same expression.
# 3. Print the merged dict and confirm the originals are unchanged.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Given:
# ```python
# session = {'user': 'Alice', 'token': 'xyz999', 'role': 'admin', 'temp_flag': True}
# ```
#
# 1. Remove `'token'` using `.pop()` and print the removed value.
# 2. Try to remove `'expires_at'` (which doesn't exist) using `.pop()` with a default of `'not set'`. Print the result — it should NOT raise an error.
# 3. Print the final session dict.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user to enter items (one per line) until they type `'done'`. Count each item's occurrences using `.get()`.
#
# Then:
# 1. Print the full frequency table (each item and count), sorted alphabetically.
# 2. Print the **most entered** item using `max()` with `key=d.get`.
# 3. Print the **least entered** item.
# 4. Print the total number of entries.
#
# Example:
# ```
# Item: apple
# Item: banana
# Item: apple
# Item: cherry
# Item: apple
# Item: done
#
# apple: 3
# banana: 1
# cherry: 1
# Most common: apple
# Least common: banana
# Total entries: 5
# ```

# %%
# Your code here
