# %% [markdown]
# # Day 23 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–23.

# %% [markdown]
# ## Challenge 1 ⭐
#
# You have two shopping lists:
# ```python
# list1 = ['milk', 'eggs', 'bread']
# list2 = ['butter', 'cheese', 'yogurt']
# ```
#
# Merge them using `.extend()` so that `list1` contains all 6 items. Print the result.
# Then show what would have happened if you used `.append()` instead (print that result too).

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given:
# ```python
# items = ['apple', 'banana', 'cherry', 'date', 'elderberry']
# ```
#
# 1. Remove `'banana'` using `.remove()`
# 2. Remove the last item using `.pop()` and print what was removed
# 3. Remove the item at index 1 using `del`
# 4. Print the final list

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given:
# ```python
# names = ['Charlie', 'alice', 'Bob', 'diana', 'Eve']
# ```
#
# 1. Print the names sorted alphabetically (case-insensitive). The original list should remain unchanged.
# 2. Print the names sorted by length (shortest first). Same length = any order is fine.
# 3. Print the names sorted by length, longest first.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Simulate a browser's **back button** using a list as a stack.
#
# 1. Use a `while` loop to let the user 'visit' pages (type a URL to add it to history).
# 2. If the user types `'back'`, pop the last page and show where they are now.
# 3. If the user types `'quit'`, stop.
# 4. Always print the current page after each action.
#
# Example:
# ```
# Action: google.com
# Current page: google.com
# Action: news.com
# Current page: news.com
# Action: back
# Current page: google.com
# Action: quit
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a simple **priority task manager**.
#
# 1. Use a `while` loop to let the user add tasks. For each task, ask for:
#    - The task name
#    - A priority number (1 = highest, 3 = lowest)
#    - Store each as a tuple: `(priority, task_name)`
# 2. Stop when the user types `'done'`.
# 3. Sort the task list so highest priority (lowest number) appears first.
# 4. Print the tasks in priority order.
#
# Example output:
# ```
# Task 1: [1] Write report
# Task 2: [1] Reply to emails
# Task 3: [3] Clean desk
# ```
#
# Hint: tuples sort naturally by their first element — you don't need `key=`.

# %%
# Your code here
