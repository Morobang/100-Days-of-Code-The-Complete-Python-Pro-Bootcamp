# %% [markdown]
# # Day 29 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–29.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Given:
# ```python
# library = {
#     'Python Crash Course': {'author': 'Matthes', 'year': 2019, 'available': True},
#     'Clean Code':          {'author': 'Martin',  'year': 2008, 'available': False},
#     'The Pragmatic Programmer': {'author': 'Thomas', 'year': 2019, 'available': True}
# }
# ```
#
# Print:
# 1. The author of `'Clean Code'`
# 2. The year of `'Python Crash Course'`
# 3. Whether `'The Pragmatic Programmer'` is available
# 4. The result of looking up a book that doesn't exist (`'SICP'`), using `.get()` to avoid a KeyError — print `'Not in library'` as the default

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Using the same `library` dict from Challenge 1:
#
# 1. Mark `'Clean Code'` as available (`available: True`).
# 2. Add a `'pages'` key to `'Python Crash Course'` with value `544`.
# 3. Add a new book to the library: `'Fluent Python'` by `'Ramalho'`, year `2022`, available `True`.
# 4. Print the full updated library, one book per line.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given:
# ```python
# products = {
#     'laptop':  {'price': 12000, 'stock': 5,  'category': 'electronics'},
#     'mouse':   {'price': 350,   'stock': 20, 'category': 'electronics'},
#     'desk':    {'price': 4500,  'stock': 3,  'category': 'furniture'},
#     'chair':   {'price': 3200,  'stock': 8,  'category': 'furniture'},
#     'monitor': {'price': 6800,  'stock': 7,  'category': 'electronics'}
# }
# ```
#
# Print:
# 1. All products in the `'electronics'` category with their price
# 2. The total value of all stock (`price × stock` for each item, summed)
# 3. The name of the most expensive product

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Given:
# ```python
# team = {
#     'Alice':   {'tasks_done': 12, 'tasks_total': 15},
#     'Bob':     {'tasks_done': 8,  'tasks_total': 10},
#     'Charlie': {'tasks_done': 5,  'tasks_total': 20},
#     'Diana':   {'tasks_done': 18, 'tasks_total': 18}
# }
# ```
#
# For each person, calculate their completion percentage and add it as a new key `'pct'` (rounded to 1 decimal place).
#
# Then print each person's name and percentage, sorted from highest to lowest completion.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a **student record system** from user input.
#
# 1. Use a `while` loop to add students. For each, ask for: name, age, and score.
# 2. Stop when the user types `'done'`.
# 3. After entry is complete, print:
#    - A formatted table of all students (name, age, score, and a grade: A≥80, B≥70, C≥60, D≥50, F otherwise)
#    - The name of the highest-scoring student
#    - The class average score
#
# Example:
# ```
# Name: Alice
# Age: 20
# Score: 88
# Name: Bob
# Age: 21
# Score: 74
# Name: done
#
# Alice  | age 20 | score 88 | grade A
# Bob    | age 21 | score 74 | grade C
# Top: Alice (88)
# Average: 81.0
# ```

# %%
# Your code here
