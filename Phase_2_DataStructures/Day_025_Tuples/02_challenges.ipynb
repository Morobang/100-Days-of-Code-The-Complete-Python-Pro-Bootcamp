# %% [markdown]
# # Day 25 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–25.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Given:
# ```python
# colours = ('red', 'green', 'blue', 'red', 'yellow', 'blue', 'red')
# ```
#
# 1. Print how many times `'red'` appears.
# 2. Print the index of the first `'blue'`.
# 3. Print the index of the second `'blue'` (hint: use `.index()` with a start argument).
# 4. Print the total number of items.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given the tuple:
# ```python
# temperatures = (22.5, 19.0, 25.3, 18.7, 23.1, 20.8)
# ```
#
# Without modifying the tuple directly:
# 1. Print the highest and lowest temperature.
# 2. Sort the temperatures from lowest to highest and print the result as a **list**.
# 3. Print the average temperature (rounded to 1 decimal place).

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user to enter 5 numbers (one per line). Store them in a **list** as you collect them, then convert the list to a **tuple** when done.
#
# Print:
# - The tuple
# - The largest value
# - The smallest value
# - Whether the number `7` appears in the tuple

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Given this scoreboard as a list of `(name, score)` tuples:
# ```python
# scoreboard = [('Alice', 88), ('Bob', 75), ('Charlie', 92), ('Diana', 75), ('Eve', 88)]
# ```
#
# 1. Print the scoreboard sorted alphabetically by name.
# 2. Build a new list of `(score, name)` tuples using a loop, then sort it to show scores from highest to lowest. Print the result.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a simple **coordinate map** using tuples as dictionary keys.
#
# 1. Create a dictionary where the keys are `(row, col)` tuples and the values are labels (strings). Include at least 6 entries covering a 3×3 grid.
# 2. Use a `while` loop to ask the user to enter a row and column (as two separate inputs).
# 3. Look up the coordinate in the dictionary and print the label, or print `'Empty'` if it's not there.
# 4. Stop when the user types `'quit'` for the row.
#
# Example:
# ```
# Row (or 'quit'): 0
# Column: 0
# top-left
# Row (or 'quit'): 2
# Column: 2
# bottom-right
# ```

# %%
# Your code here
