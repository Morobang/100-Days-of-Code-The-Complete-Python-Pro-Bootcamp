# %% [markdown]
# # Day 31 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–31.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Starting with:
# ```python
# cart = {'apple', 'banana', 'cherry'}
# ```
#
# 1. Use `|=` to add `{'mango', 'kiwi', 'banana'}` to the cart.
# 2. Use `-=` to remove `{'banana', 'kiwi'}` from the cart.
# 3. Print the cart after each step.
# 4. What is the final cart? Confirm it matches your expectation.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given attendance across four days:
# ```python
# mon = {'Alice', 'Bob', 'Charlie', 'Diana'}
# tue = {'Bob', 'Charlie', 'Eve'}
# wed = {'Alice', 'Charlie', 'Frank'}
# thu = {'Charlie', 'Diana', 'Eve', 'Frank'}
# ```
#
# Find and print:
# 1. Who attended **all four days**
# 2. Who attended **at least one day** (sorted)
# 3. Who attended **Monday but not Thursday**
# 4. Who attended **exactly two of the four days** — find the symmetric difference of `(mon | thu)` and `(tue | wed)` ... or think about it differently!

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given three courses and their enrolled students:
# ```python
# maths   = {'Alice', 'Bob', 'Charlie', 'Diana', 'Eve'}
# science = {'Bob', 'Charlie', 'Frank', 'Grace'}
# english = {'Alice', 'Charlie', 'Diana', 'Grace', 'Heidi'}
# ```
#
# Find:
# 1. Students enrolled in **all three** courses
# 2. Students enrolled in **Maths and Science but not English**
# 3. Students enrolled in **only one course** (symmetric diff of all three pairs, then narrow it down)
# 4. Total unique students across all courses

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# You're building a tag filter for a blog. Given:
# ```python
# blocklist = {'spam', 'ads', 'promo', 'click', 'buy', 'free', 'win'}
# ```
#
# Ask the user to type a sentence. Split it into a set of unique words (lowercase).
#
# Print:
# 1. The clean words (after removing blocklist words)
# 2. The flagged words (intersection with blocklist)
# 3. Whether the message is clean (`isdisjoint` check)
#
# Then use `&=` to update the word set to keep only clean words, and print the filtered sentence (words joined by spaces).

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# **Friend recommendations** using set operations.
#
# Given a social network:
# ```python
# friends = {
#     'Alice':   {'Bob', 'Charlie', 'Diana'},
#     'Bob':     {'Alice', 'Charlie', 'Eve'},
#     'Charlie': {'Alice', 'Bob', 'Diana', 'Frank'},
#     'Diana':   {'Alice', 'Charlie'},
#     'Eve':     {'Bob', 'Frank'},
#     'Frank':   {'Charlie', 'Eve'}
# }
# ```
#
# For a given user (ask for input), calculate and print:
# 1. Their direct friends
# 2. **Friend recommendations** — people who are friends of their friends, but NOT already their friend and NOT themselves
# 3. For each recommendation, how many mutual friends they share (intersection size)

# %%
# Your code here
