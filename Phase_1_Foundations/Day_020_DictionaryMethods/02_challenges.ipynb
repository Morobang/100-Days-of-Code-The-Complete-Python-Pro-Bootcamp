# %% [markdown]
# # Day 20 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–20.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Given this inventory dictionary:
# ```python
# inventory = {'apple': 50, 'banana': 30, 'cherry': 20}
# ```
#
# Ask the user for an item name. Use `.get()` with a default of `0` to look it up.
# Print how many are in stock, or a message if the item isn't in the inventory.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given:
# ```python
# scores = {'Alice': 88, 'Bob': 75, 'Charlie': 92}
# ```
#
# 1. Print a list of all names using `.keys()`.
# 2. Print a list of all scores using `.values()`.
# 3. Use `.items()` in a loop to print each name and score on one line.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# You have two dictionaries. Use `.update()` to merge the second into the first, then print the result.
#
# ```python
# defaults = {'theme': 'light', 'language': 'english', 'font_size': 14}
# user_prefs = {'theme': 'dark', 'font_size': 16}
# ```
#
# Expected result: `{'theme': 'dark', 'language': 'english', 'font_size': 16}`

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Starting with:
# ```python
# scores = {'Alice': 88, 'Bob': 75, 'Charlie': 92}
# ```
#
# Use `.pop()` to remove `'Bob'`. Print the value that was removed, then print the remaining dictionary.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a simple **contact book** using a dictionary.
#
# 1. Use a `while` loop to let the user add contacts (name → phone number). Stop when they type `done`.
# 2. After adding contacts, ask for a name to look up. Use `.get()` to find the phone number or print `'Not found'`.
#
# Example:
# ```
# Name: Alice
# Phone: 083-111-2222
# Name: Bob
# Phone: 072-333-4444
# Name: done
#
# Look up contact: Alice
# Alice: 083-111-2222
# ```

# %%
# Your code here
