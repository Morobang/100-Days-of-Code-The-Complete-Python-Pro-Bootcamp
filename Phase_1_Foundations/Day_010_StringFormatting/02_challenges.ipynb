# %% [markdown]
# # Day 10 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–10.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Ask the user for their name and age. Use an f-string to print:
#
# ```
# My name is Alice and I am 30 years old.
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Ask the user for a price (as a float). Print it formatted to exactly 2 decimal places with an `R` prefix.
#
# Example: input `12.5` → output `R12.50`

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for a decimal value between 0 and 1 (e.g. `0.735`).
# Print it as a percentage with 2 decimal places.
#
# Example: input `0.735` → output `73.50%`
#
# **Hint:** the `:.2%` format spec does the multiplication for you.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Print a receipt row with aligned columns. Use these hard-coded values:
#
# - Item: `Coffee`, Qty: `2`, Price: `35.50`
#
# The output should look like this (item left-aligned in 20 chars, qty right-aligned in 5, price right-aligned in 8):
#
# ```
# Item                   Qty    Price
# Coffee                   2    35.50
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user for their name and their role (e.g. `Developer`).
# Print a formatted name badge like this:
#
# ```
# ------------------------------
# |           Alice            |
# |         Developer          |
# ------------------------------
# ```
#
# The border is 30 dashes. The name and role are centered inside the `| |` borders.
# **Hint:** the content width is 28 characters (30 minus the two `|` characters).

# %%
# Your code here
