# %% [markdown]
# # Day 2 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–2.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create 3 variables: your first name, your last name, and your age. Print each one on its own line.

# %%
# Your code here
first_name = "Rocket"
last_name = "Space"
age = 27

print(first_name)
print(last_name)
print(age)
# Out:
# Rocket
# Space
# 27

# %% [markdown]
# ## Challenge 2 ⭐
#
# Create a variable called `favourite_food`. Print it. Then change it to something different and print it again.

# %%
# Your code here
favourite_food = "Meat"
print(favourite_food)
favourite_food = "KaNama"
print(favourite_food)
# Out:
# Meat
# KaNama

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Create variables to represent a product in a store:
# - `product_name` — a string
# - `price` — a number with decimals
# - `quantity` — a whole number
#
# Print each variable on its own line with a label (e.g. `Product: Coffee`).

# %%
# Your code here

product_name = "PS5 Controller"
price = 1599.99
quantity = 2

print(f"Product:   {product_name}")
print(f"Price:     R{price}")
print(f"Quantity:  {quantity}")
# Out:
# Product:   PS5 Controller
# Price:     R1599.99
# Quantity:  2

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Create 4 variables with these values: `"hello"`, `42`, `3.14`, `True`. Print the `type()` of each one.

# %%
# Your code here
my_string = "hello"
my_int = 42
my_deci = 3.14
my_bool = True

print(type(my_string),type(my_int),type(my_deci),type(my_bool),sep="\n")
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# The following variable names are all invalid or poorly named. For each one, write the corrected version as a comment explaining the problem, then create a properly named variable.
#
# ```python
# 2fast = "very fast"
# first-name = "Alex"
# MyAge = 25
# totalprice = 99.99
# for = "loop"
# ```

# %%
# Your code here
# Example:
# 2fast — starts with digit
two_fast = "very fast"

# first-name — hyphen not allowed
first_name = "Alex"

# MyAge — not snake_case
my_age = 25

# totalprice — should have underscore for readability
total_price = 99.99

# for — reserved keyword
loop_label = "loop"
