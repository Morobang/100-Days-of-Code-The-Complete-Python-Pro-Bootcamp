# %% [markdown]
# # Day 11 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–11.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Ask the user for a word. Print the first 3 characters and the last 3 characters on separate lines.
#
# Example for `'strawberry'`:
# ```
# First 3: str
# Last 3:  rry
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Ask the user to enter any text. Print it reversed using slicing.
#
# Example: `'hello'` → `'olleh'`

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for a word. Print every other character, starting from the first.
#
# Example: `'strawberry'` → `'srwer'`
#
# **Hint:** use the step in a slice.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Ask the user for a filename like `report_2024.txt`.
# Extract and print:
# - The base name (everything before the `.`)
# - The extension (everything from the `.` onwards)
#
# Example for `report_2024.txt`:
# ```
# Name:      report_2024
# Extension: .txt
# ```
#
# **Hint:** use `.find('.')` to locate the dot, then slice around it.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user for a sentence. Split it into two halves using slicing and print each half on its own line.
#
# Example for `'Hello, World!'` (13 characters, midpoint = 6):
# ```
# First half:  Hello,
# Second half:  World!
# ```
#
# **Hint:** use `len()` and `//` to find the midpoint.

# %%
# Your code here
