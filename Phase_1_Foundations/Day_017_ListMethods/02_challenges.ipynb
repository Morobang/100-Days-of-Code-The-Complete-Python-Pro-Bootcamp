# %% [markdown]
# # Day 17 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–17.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Given this list: `[3, 1, 4, 1, 5, 9, 2, 6]`
#
# 1. Sort it ascending and print it.
# 2. Reverse it and print it.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given this list: `['apple', 'banana', 'apple', 'cherry', 'apple']`
#
# 1. Count how many times `'apple'` appears.
# 2. Find the index of the first `'apple'`.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for 5 numbers (one at a time, append each to a list).
# Remove the largest number from the list using `max()` and `.remove()`.
# Print the remaining list.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Start with this list: `colours = ['red', 'green', 'blue']`
#
# 1. Print the list.
# 2. Insert `'purple'` at the beginning (index 0).
# 3. Remove the last colour using `.pop()`.
# 4. Print the final list.
#
# Expected result: `['purple', 'red', 'green']`

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user for 5 numbers. After collecting them all, print:
#
# - The list sorted in ascending order
# - The sum
# - The minimum
# - The maximum
# - The average (formatted to 2 decimal places)
#
# Example:
# ```
# Sorted:  [3.0, 5.0, 7.0, 8.0, 12.0]
# Sum:     35.0
# Min:     3.0
# Max:     12.0
# Average: 7.00
# ```

# %%
# Your code here
