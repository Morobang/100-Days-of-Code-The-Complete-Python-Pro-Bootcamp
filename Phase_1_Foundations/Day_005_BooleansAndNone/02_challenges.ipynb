# %% [markdown]
# # Day 5 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–5.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create 4 boolean variables: `is_student`, `is_employed`, `has_id`, `is_adult`. Give them `True` or `False` values that make sense for a person you describe. Print each one with a label.

# %%
# Your code here
is_student = True
is_employed = False
has_id = True
is_adult = True
print("Student:", is_student)
print("Employed:", is_employed)
print("Has ID:", has_id)
print("Adult:", is_adult)

# %% [markdown]
# ## Challenge 2 ⭐
#
# Use `bool()` to convert these values and print each result:
# - `0`
# - `1`
# - `""`  (empty string)
# - `"Python"`
# - `-5`

# %%
# Your code here
print(bool(0))
print(bool(1))
print(bool(""))
print(bool("Python"))
print(bool(-5))
# Out:
# False
# True
# False
# True
# True

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Create a variable `middle_name = None` (the user hasn't provided one). Print it and print its type. Then reassign it to an actual name and print the type again.

# %%
# Your code here
middle_name = None

print(type(middle_name))


middle_name = "Rockie"

print(type(middle_name))
# Out:
# <class 'NoneType'>
# <class 'str'>

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Before running the code, predict whether each `bool()` call will return `True` or `False`. Then run it and check.
#
# ```python
# bool(0)
# bool(100)
# bool("")
# bool("False")   # careful — what type is "False"?
# bool(None)
# ```

# %%
# Write your predictions as comments, then verify:
# bool(0)       -> I think: 
# bool(100)     -> I think: 
# bool("")      -> I think: 
# bool("False") -> I think: 
# bool(None)    -> I think: 

print(bool(0))
print(bool(100))
print(bool(""))
print(bool("False"))
print(bool(None))

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Create variables to represent a user profile:
# - `username` — a string
# - `age` — an integer
# - `is_verified` — a boolean
# - `bio` — set to `None` (the user hasn't written one yet)
#
# Print each variable and its type on its own line.

# %%
# Your code here
username = "alex_dev"
age = 25
is_verified = True
bio = None

print(username, type(username))
print(age, type(age))
print(is_verified, type(is_verified))
print(bio, type(bio))
