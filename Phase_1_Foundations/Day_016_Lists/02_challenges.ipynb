# %% [markdown]
# # Day 16 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–16.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create a list of 5 of your favourite foods. Print the first item and the last item using indexing.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Start with an empty list. Ask the user for 3 names (one at a time) and append each to the list.
# Print the full list and its length.
#
# Example:
# ```
# Enter name 1: Alice
# Enter name 2: Bob
# Enter name 3: Charlie
# ['Alice', 'Bob', 'Charlie']
# Total names: 3
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given this list: `[5, 12, 3, 18, 7, 25, 9, 11]`
#
# Use a `for` loop to print only the numbers **greater than 10**.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Given this list of fruits:
# ```python
# fruits = ['apple', 'banana', 'cherry', 'mango', 'grape']
# ```
#
# Ask the user to enter a fruit name. Use `in` to check if it is in the list and print a message.
#
# Make the search case-insensitive.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user for 5 numbers (one at a time). Collect them in a list.
# Find and print the largest number **without using** `max()` — use a loop and a variable to track the current largest.
#
# **Hint:** start by assuming `numbers[0]` is the largest, then loop through the rest.

# %%
# Your code here
