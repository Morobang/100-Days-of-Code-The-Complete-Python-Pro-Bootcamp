# %% [markdown]
# # Day 9 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–9.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Ask the user for their name. Print it in ALL CAPS and then in all lowercase.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Ask the user for a word. Count how many times the letter `'a'` appears (case-insensitive — `'A'` and `'a'` both count).
# Print the result.
#
# Example: `'Banana'` → `3`

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for a sentence (they might accidentally add spaces at the start or end).
# Strip the extra whitespace, then replace every space between words with a hyphen `-`.
# Print the result.
#
# Example: `'  hello world  '` → `'hello-world'`

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Ask the user to enter exactly 3 items separated by commas (e.g. `milk,eggs,bread`).
# Split the string. Print each item on its own line.
# Then print all items joined with `' and '`.
#
# Expected output for `milk,eggs,bread`:
# ```
# milk
# eggs
# bread
# milk and eggs and bread
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user to enter any word. Print the following checks:
#
# - Is it all digits? (`.isdigit()`)
# - Is it all letters? (`.isalpha()`)
# - Does it start with the letter `'a'`? (case-insensitive)
# - Does it end with `'ing'`? (case-insensitive)
# - Print the word in UPPERCASE
#
# Example for `'running'`:
# ```
# All digits?      False
# All letters?     True
# Starts with 'a'? False
# Ends with 'ing'? True
# Uppercase:       RUNNING
# ```

# %%
# Your code here
