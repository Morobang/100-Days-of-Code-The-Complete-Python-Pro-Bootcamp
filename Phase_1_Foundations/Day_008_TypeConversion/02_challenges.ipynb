# %% [markdown]
# # Day 8 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–8.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Convert the string `"100"` to an integer. Add 50 to it. Print the result.

# %%
# Your code here
number = "100"

print(int(number) + 5)
# Out:
# 105

# %% [markdown]
# ## Challenge 2 ⭐
#
# Ask the user for two numbers. Add them together and print the sum.
#
# Watch out — `input()` returns strings, so `"3" + "5"` gives `"35"`, not `8`.

# %%
# Your code here
first_number = input("Enter first number: ")
second_number = input("Enter second number: ")

print(first_number + second_number)
print(int(first_number) + int(second_number))
# Out:
# 2023
# 43

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for a price. Convert it to float. Calculate a 15% tip. Print both the tip amount and the total.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# What does `int(3.9)` return? What about `int(3.1)`? Run the code and explain in a comment why the results are what they are.

# %%
# Your code here

# Explanation:

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user for their birth year. Calculate their age. Then print their age as:
# - An integer
# - A float
# - A string
#
# Print the `type()` of each to confirm the conversion worked.

# %%
# Your code here
