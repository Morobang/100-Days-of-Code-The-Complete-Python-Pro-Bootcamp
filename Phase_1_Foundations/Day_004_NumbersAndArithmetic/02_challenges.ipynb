# %% [markdown]
# # Day 4 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–4.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create variables `width = 12` and `height = 7`. Calculate and print the area of the rectangle.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# You have R500. Each item costs R37.
#
# Use `//` and `%` to calculate:
# - How many items you can buy
# - How much change you get
#
# Print both answers.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# A right triangle has sides of length 3 and 4. Calculate the hypotenuse.
#
# Formula: `hypotenuse = √(a² + b²)`
#
# Use both `math.sqrt()` and `**` (you can use `** 0.5` as an alternative to `sqrt`).

# %%
import math
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# A pizza has a radius of 15cm. Calculate its area using `math.pi`.
#
# Formula: `area = π × r²`
#
# Print the result rounded down to the nearest whole number using `math.floor()`.

# %%
import math
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Write calculations to convert Celsius to Fahrenheit. Formula: `F = (C × 9/5) + 32`
#
# Convert 0°C, 100°C, and 37°C. Store each result in a variable and print all three.

# %%
# Your code here
