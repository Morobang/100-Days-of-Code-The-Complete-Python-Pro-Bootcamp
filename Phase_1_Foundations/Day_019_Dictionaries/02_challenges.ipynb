# %% [markdown]
# # Day 19 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–19.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create a dictionary with three key-value pairs about yourself: `name`, `age`, and `city`.
# Print each value using its key.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Starting with your dictionary from Challenge 1:
# 1. Add a new key `'email'` with any value.
# 2. Update your `'age'` to a different value.
# 3. Print the dictionary before and after.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Create a dictionary of at least 5 countries and their capitals. Ask the user to enter a country name.
# Look it up and print the capital, or print a message if it's not in the dictionary.
#
# Make the lookup case-insensitive.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Given this dictionary of scores:
# ```python
# scores = {'Alice': 88, 'Bob': 75, 'Charlie': 92, 'Diana': 81}
# ```
#
# Use a `for` loop with `.items()` to print each name and score neatly aligned.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user for a sentence. Split it into words and build a **word frequency dictionary** — a dict where each key is a word and the value is how many times it appears.
#
# Print each word and its count.
#
# Example for `'the cat sat on the mat the cat'`:
# ```
# 'the': 3
# 'cat': 2
# 'sat': 1
# 'on': 1
# 'mat': 1
# ```

# %%
# Your code here
