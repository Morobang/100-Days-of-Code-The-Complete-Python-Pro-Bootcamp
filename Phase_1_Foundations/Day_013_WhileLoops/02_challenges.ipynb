# %% [markdown]
# # Day 13 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–13.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Use a `while` loop to print the numbers 1 through 5, one per line.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Use a `while` loop to count down from 10 to 1 (one number per line).
# After the loop, print `Blast off!`

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Keep asking the user to enter a number. Print each number they enter.
# Stop the loop when they enter `0`. Print `Done.` at the end.
#
# Example:
# ```
# Enter a number (0 to stop): 5
# You entered: 5
# Enter a number (0 to stop): 3
# You entered: 3
# Enter a number (0 to stop): 0
# Done.
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Ask the user for their age. If the age is not a valid number (must be between 1 and 120), keep asking until they enter a valid one. Then print a confirmation.
#
# Example:
# ```
# Enter your age: -5
# That doesn't look like a valid age. Try again.
# Enter your age: 200
# That doesn't look like a valid age. Try again.
# Enter your age: 25
# Got it — you are 25 years old.
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Keep asking the user for numbers and add them to a running total.
# Stop when they enter `0`.
# At the end, print how many numbers were entered and what the total is.
#
# Example:
# ```
# Enter a number (0 to stop): 10
# Enter a number (0 to stop): 25
# Enter a number (0 to stop): 5
# Enter a number (0 to stop): 0
# Numbers entered: 3
# Total: 40.0
# ```

# %%
# Your code here
