# %% [markdown]
# # Day 15 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–15.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Ask the user for a word. Use a `for` loop to print each character on its own line.
#
# Example for `'cat'`:
# ```
# c
# a
# t
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Use `range()` and a `for` loop to print the numbers 1 through 10, one per line.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for a number. Print its multiplication table from 1 to 10.
#
# Example for `7`:
# ```
# 7 x 1 = 7
# 7 x 2 = 14
# ...
# 7 x 10 = 70
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Ask the user for a word. Count and print how many vowels (`a e i o u`) it contains.
# The count should be case-insensitive (`A` counts as a vowel).
#
# Example: `'Python'` → `Vowels found: 1`

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# **FizzBuzz.** Print every number from 1 to 20, but:
#
# - If the number is divisible by **3**, print `Fizz` instead
# - If the number is divisible by **5**, print `Buzz` instead
# - If divisible by **both 3 and 5**, print `FizzBuzz`
# - Otherwise print the number
#
# Expected output starts: `1, 2, Fizz, 4, Buzz, Fizz, 7, 8, Fizz, Buzz, 11, Fizz, 13, 14, FizzBuzz, ...`
#
# **Hint:** check the divisible-by-both case first.

# %%
# Your code here
