# %% [markdown]
# # Day 3 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–3.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create a variable called `full_name` with your full name. Print the first character and the last character using indexing.

# %%
# Your code here
full_name = "Rocket"

print(full_name[0])
print(full_name[-1])
# Out:
# R
# t

# %% [markdown]
# ## Challenge 2 ⭐
#
# Print the length of the word `"extraordinary"`.

# %%
# Your code here
word = "extraordinary"

print(len(word))
# Out:
# 13

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Create two variables: `greeting = "Hello"` and `name = "World"`.
#
# Use concatenation to print: `Hello, World!`
#
# Do not hardcode the full string — build it from the two variables.

# %%
# Your code here
greeting = "Hello"
name = "World"

print(greeting + ", " + name + "!")
# Out:
# Hello, World!

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Print a divider line of exactly 40 dashes using string repetition. Do not type 40 dashes manually.

# %%
# Your code here
print("-"*40)
# Out:
# ----------------------------------------

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Create three variables: `title`, `author`, and `year`. Build and print a formatted book label using only concatenation and string repetition (no f-strings yet — that's Day 10):
#
# ```
# ----------------------------------------
# Title:  The Alchemist
# Author: Paulo Coelho
# Year:   1988
# ----------------------------------------
# ```

# %%
# Your code here
title = "The Alchemist"
author = "Paulo Coelho"
year = "1988"

print("-" * 40)
print("Title:  " + title)
print("Author: " + author)
print("Year:   " + year)
print("-" * 40)
