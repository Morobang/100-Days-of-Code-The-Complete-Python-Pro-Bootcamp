# %% [markdown]
# # Day 1 — Challenges
#
# **Rules:**
# - Attempt every challenge before looking at `solution.py`
# - If you are stuck for more than 15 minutes, re-read `01_learn.ipynb`
# - ⭐ = straightforward | ⭐⭐ = requires some thought | ⭐⭐⭐ = challenging

# %% [markdown]
# ## Challenge 1 ⭐
#
# Print your name, age, and city — each on a separate line — using 3 separate `print()` calls.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Print `Python is awesome` on one line using three separate string values and the `sep` parameter. Do not hardcode the spaces — let `sep` handle it.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Print this address block using **only ONE `print()` call**. Use `\n` to create the line breaks.
#
# ```
# 123 Main Street
# Cape Town
# South Africa
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Print a loading sequence that all appears on **one line**, like this:
#
# ```
# Loading... 10%... 20%... 30%... Done!
# ```
#
# Use multiple `print()` calls with the `end` parameter.

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Print a simple receipt that looks like this:
#
# ```
# ========== RECEIPT ==========
# Item           Price
# Coffee         R25.00
# Sandwich       R45.00
# ==============================
# TOTAL          R70.00
# ```
#
# It does not need to be perfectly aligned yet — just get the structure right using `print()` and `\n`.

# %%
# Your code here
