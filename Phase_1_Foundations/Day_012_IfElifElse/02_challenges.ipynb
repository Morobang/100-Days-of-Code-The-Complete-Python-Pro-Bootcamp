# %% [markdown]
# # Day 12 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–12.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Ask the user for a number. Print whether it is `positive`, `negative`, or `zero`.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Ask the user for their age. Print their life stage:
#
# - Under 13 → `child`
# - 13 to 17 → `teenager`
# - 18 and above → `adult`

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for a password. If it matches `secret123`, print `Access granted`. Otherwise print `Access denied`.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Ask the user for two numbers. Print the larger one.
# If they are equal, print `They are equal`.
#
# Example:
# ```
# Enter first number: 7
# Enter second number: 12
# The larger number is 12.0
# ```

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user for a score between 0 and 100. Calculate and print the letter grade and whether they passed.
#
# | Score | Grade |
# |-------|-------|
# | 90+ | A |
# | 80–89 | B |
# | 70–79 | C |
# | 60–69 | D |
# | Below 60 | F |
#
# Passing is 60 or above.
#
# Example output: `Grade: B — Pass`

# %%
# Your code here
