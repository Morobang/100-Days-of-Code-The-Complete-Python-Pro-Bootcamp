# %% [markdown]
# # Day 6 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–6.
#
# Run each cell — these are interactive programs, so you will need to type input when prompted.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Ask the user for their name and print: `Nice to meet you, [name]!`

# %%
# Your code here
name = input("What is your name? ")
print("Nice to meet you, " + name + "!")

# %% [markdown]
# ## Challenge 2 ⭐
#
# Ask the user for their birth year. Calculate their age using 2025 as the current year and print it.

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Ask the user for the length and width of a room. Calculate the area and print it.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# Ask the user for a temperature in Celsius. Convert it to Fahrenheit and print the result.
#
# Formula: `F = (C × 9/5) + 32`

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Build a bill splitter. Ask the user for:
# - Total bill amount
# - Number of people splitting it
# - Tip percentage (e.g. 15 for 15%)
#
# Calculate and print each person's share including the tip.

# %%
# Your code here
