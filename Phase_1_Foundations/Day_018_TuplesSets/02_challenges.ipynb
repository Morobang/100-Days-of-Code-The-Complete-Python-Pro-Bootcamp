# %% [markdown]
# # Day 18 — Challenges
#
# **Rules:** Attempt every challenge before looking at `solution.py`. Use only concepts from Days 1–18.

# %% [markdown]
# ## Challenge 1 ⭐
#
# Create a tuple containing your name, age, and city. Print each value using indexing.

# %%
# Your code here

# %% [markdown]
# ## Challenge 2 ⭐
#
# Given this tuple: `person = ('Alice', 30, 'Cape Town')`
#
# Unpack it into variables `name`, `age`, and `city`. Print a sentence using them:
#
# `Alice is 30 years old and lives in Cape Town.`

# %%
# Your code here

# %% [markdown]
# ## Challenge 3 ⭐⭐
#
# Given this list with duplicates:
# ```python
# numbers = [1, 3, 2, 1, 5, 3, 2, 4, 1, 5]
# ```
#
# Convert it to a set to remove duplicates. Print the unique values and how many there are.

# %%
# Your code here

# %% [markdown]
# ## Challenge 4 ⭐⭐
#
# You have two sets of student names:
# ```python
# class_a = {'Alice', 'Bob', 'Charlie', 'Diana'}
# class_b = {'Charlie', 'Diana', 'Eve', 'Frank'}
# ```
#
# Print:
# - Students in **both** classes
# - Students in **either** class
# - Students only in class A

# %%
# Your code here

# %% [markdown]
# ## Challenge 5 ⭐⭐⭐
#
# Ask the user to enter 10 numbers (one at a time). Use a `set` to track which values are unique.
# At the end, print how many unique values they entered and list them in sorted order.
#
# Example:
# ```
# Enter number 1: 5
# Enter number 2: 3
# Enter number 3: 5
# ...
# You entered 7 unique value(s): [1, 2, 3, 4, 5, 7, 9]
# ```

# %%
# Your code here
