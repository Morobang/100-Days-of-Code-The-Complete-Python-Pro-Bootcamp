# %% [markdown]
# # Day 24 Challenges — Array & List Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Find max and min ⭐
#
# Write `find_min_max(lst)` — return `(min, max)` without using built-ins `min()`/`max()`.

# %%
def find_min_max(lst: list) -> tuple:
    pass

# %% [markdown]
# ## 2. Remove duplicates (in-place) ⭐
#
# Write `remove_duplicates(lst)` — remove duplicates from a SORTED list in-place, return new length.
# ```
# remove_duplicates([1,1,2,2,3]) → 3  (list becomes [1,2,3,...])
# ```

# %%
def remove_duplicates(lst: list) -> int:
    pass

# %% [markdown]
# ## 3. Two sum (unsorted) ⭐⭐
#
# Write `two_sum(lst, target)` — return indices of two numbers that add to target. O(n).
# ```
# two_sum([2,7,11,15], 9) → (0,1)
# ```

# %%
def two_sum(lst: list, target: int) -> tuple:
    pass

# %% [markdown]
# ## 4. Maximum subarray (Kadane's) ⭐⭐
#
# Write `max_subarray(lst)` — return the sum of the contiguous subarray with the largest sum.
# ```
# max_subarray([-2,1,-3,4,-1,2,1,-5,4]) → 6
# ```

# %%
def max_subarray(lst: list) -> int:
    pass

# %% [markdown]
# ## 5. Rotate array ⭐⭐
#
# Write `rotate(lst, k)` — rotate array right by k steps.
# ```
# rotate([1,2,3,4,5,6,7], 3) → [5,6,7,1,2,3,4]
# ```

# %%
def rotate(lst: list, k: int) -> list:
    pass

# %% [markdown]
# ## 6. Product except self ⭐⭐⭐
#
# Write `product_except_self(lst)` — return array where each element is the product of all others. No division, O(n).
# ```
# product_except_self([1,2,3,4]) → [24,12,8,6]
# ```

# %%
def product_except_self(lst: list) -> list:
    pass

# %% [markdown]
# ## 7. Longest increasing subsequence length ⭐⭐⭐
#
# Write `lis_length(lst)` — return the length of the longest strictly increasing subsequence.
# ```
# lis_length([10,9,2,5,3,7,101,18]) → 4
# ```

# %%
def lis_length(lst: list) -> int:
    pass

# %% [markdown]
# ## 8. Merge intervals ⭐⭐⭐
#
# Write `merge_intervals(intervals)` — merge overlapping intervals.
# ```
# merge_intervals([[1,3],[2,6],[8,10],[15,18]]) → [[1,6],[8,10],[15,18]]
# ```

# %%
def merge_intervals(intervals: list) -> list:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert find_min_max([3,1,4,1,5,9]) == (1,9)
lst=[1,1,2,2,3]; n=remove_duplicates(lst)
assert n==3 and lst[:3]==[1,2,3]
assert two_sum([2,7,11,15],9)==(0,1)
assert two_sum([3,2,4],6)==(1,2)
assert max_subarray([-2,1,-3,4,-1,2,1,-5,4])==6
assert max_subarray([-1,-2,-3])==-1
assert rotate([1,2,3,4,5,6,7],3)==[5,6,7,1,2,3,4]
assert product_except_self([1,2,3,4])==[24,12,8,6]
assert lis_length([10,9,2,5,3,7,101,18])==4
assert merge_intervals([[1,3],[2,6],[8,10],[15,18]])==[[1,6],[8,10],[15,18]]
print('✅ All tests passed!')
