# %% [markdown]
# # Day 20 Challenges — Modules, pip & Virtual Environments
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Password generator ⭐⭐
#
# Write `generate_password(length=12)` using `random` and `string` modules. Mix uppercase, lowercase, digits, symbols.

# %%
import random, string

def generate_password(length: int = 12) -> str:
    # write your solution
    pass

print(generate_password())
print(generate_password(20))

# %% [markdown]
# ## Challenge 2 — Days until birthday ⭐⭐
#
# Write `days_until_birthday(month, day)` → int. Returns days until next occurrence of that date.

# %%
from datetime import date

def days_until_birthday(month: int, day: int) -> int:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 3 — File organiser ⭐⭐⭐
#
# Write `list_py_files(directory)` using `os` — return a sorted list of all `.py` filenames in the directory (not full paths).

# %%
import os

def list_py_files(directory: str) -> list:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests

# %%
import random, string, os

pwd = generate_password()
assert len(pwd) == 12
assert generate_password(20).__len__() == 20
assert generate_password() != generate_password()

py_files = list_py_files('.')
assert all(f.endswith('.py') for f in py_files)
assert py_files == sorted(py_files)
print('✅ All tests passed!')
