# %% [markdown]
# # Day 35 Challenges — Bit Manipulation
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Is odd ⭐
#
# Write `is_odd(n)` using bitwise AND. No `%` operator.

# %%
def is_odd(n: int) -> bool:
    pass

# %% [markdown]
# ## 2. Is power of 2 ⭐
#
# Write `is_power_of_two(n)` — True if n is a power of 2. O(1), one line.

# %%
def is_power_of_two(n: int) -> bool:
    pass

# %% [markdown]
# ## 3. Count set bits ⭐⭐
#
# Write `count_bits(n)` — count the number of 1-bits in the binary representation.

# %%
def count_bits(n: int) -> int:
    pass

# %% [markdown]
# ## 4. Single number ⭐⭐
#
# Write `single_number(lst)` — every element appears twice except one. Find it. O(n), O(1) space.
# ```
# single_number([4,1,2,1,2]) → 4
# ```

# %%
def single_number(lst: list) -> int:
    pass

# %% [markdown]
# ## 5. Missing number ⭐⭐
#
# Write `missing_number(lst)` — given 0..n with one missing, find it. O(n), O(1) space.

# %%
def missing_number(lst: list) -> int:
    pass

# %% [markdown]
# ## 6. Reverse bits ⭐⭐
#
# Write `reverse_bits(n)` — reverse all 32 bits of an unsigned integer.

# %%
def reverse_bits(n: int) -> int:
    pass

# %% [markdown]
# ## 7. Two non-repeating numbers ⭐⭐⭐
#
# Write `two_single_numbers(lst)` — every element appears twice except two. Find both. O(n), O(1) space.

# %%
def two_single_numbers(lst: list) -> tuple:
    pass

# %% [markdown]
# ## 8. Sum without + operator ⭐⭐⭐
#
# Write `add_bits(a, b)` — add two integers using only bit operations.

# %%
def add_bits(a: int, b: int) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert is_odd(3)==True and is_odd(4)==False
assert is_power_of_two(8)==True
assert is_power_of_two(6)==False
assert is_power_of_two(1)==True

assert count_bits(11)==3   # 1011 has three 1s
assert count_bits(0)==0

assert single_number([4,1,2,1,2])==4
assert single_number([2,2,1])==1

assert missing_number([3,0,1])==2
assert missing_number([0,1])==2

r=reverse_bits(43261596)  # specific 32-bit test
assert isinstance(r,int)

a,b=two_single_numbers([1,2,1,3,2,5])
assert set((a,b))=={3,5}

assert add_bits(1,2)==3
assert add_bits(3,5)==8
assert add_bits(0,0)==0
print('✅ All tests passed!')
