# %% [markdown]
# # Day 23 — String Problems
#
# > Strings come up in almost every interview. Master the patterns.

# %% [markdown]
# ## Key patterns
#
# - Two pointers (palindrome, reverse)
# - Sliding window (longest substring)
# - Character frequency (anagram)
# - Stack (balanced brackets)

# %%
# Two pointers — check palindrome
def is_palindrome(s):
    s = s.lower().replace(' ','')
    left, right = 0, len(s)-1
    while left < right:
        if s[left] != s[right]: return False
        left += 1; right -= 1
    return True

print(is_palindrome('A man a plan a canal Panama'))  # True

# %%
# Anagram check
def is_anagram(s, t):
    return sorted(s) == sorted(t)

# Or with Counter:
from collections import Counter
def is_anagram2(s, t):
    return Counter(s) == Counter(t)

print(is_anagram('listen','silent'))  # True
