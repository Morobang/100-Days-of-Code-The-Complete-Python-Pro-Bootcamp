# %% [markdown]
# # Day 23 Challenges — String Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Reverse words ⭐
#
# Write `reverse_words(s)` — reverse the order of words in a sentence.
# ```
# reverse_words('Hello World') → 'World Hello'
# ```

# %%
def reverse_words(s: str) -> str:
    pass

# %% [markdown]
# ## 2. Is palindrome ⭐
#
# Write `is_palindrome(s)` — ignore case and non-alphanumeric chars.
# ```
# is_palindrome('A man a plan a canal Panama') → True
# ```

# %%
def is_palindrome(s: str) -> bool:
    pass

# %% [markdown]
# ## 3. Is anagram ⭐
#
# Write `is_anagram(s, t)` — return True if s and t are anagrams.

# %%
def is_anagram(s: str, t: str) -> bool:
    pass

# %% [markdown]
# ## 4. First non-repeating char ⭐⭐
#
# Write `first_unique(s)` — return the first character that appears only once, or `''` if none.
# ```
# first_unique('aabbcde') → 'c'
# ```

# %%
def first_unique(s: str) -> str:
    pass

# %% [markdown]
# ## 5. Longest common prefix ⭐⭐
#
# Write `longest_common_prefix(words)` — find the longest prefix shared by all words.
# ```
# longest_common_prefix(['flower','flow','flight']) → 'fl'
# ```

# %%
def longest_common_prefix(words: list) -> str:
    pass

# %% [markdown]
# ## 6. Valid brackets ⭐⭐
#
# Write `is_valid_brackets(s)` — True if all brackets are correctly matched and closed.
# ```
# is_valid_brackets('()[]{}') → True
# is_valid_brackets('([)]')   → False
# ```

# %%
def is_valid_brackets(s: str) -> bool:
    pass

# %% [markdown]
# ## 7. Longest substring without repeating chars ⭐⭐⭐
#
# Write `longest_unique_substring(s)` — return the length of the longest substring with no repeating characters.
# ```
# longest_unique_substring('abcabcbb') → 3
# ```

# %%
def longest_unique_substring(s: str) -> int:
    pass

# %% [markdown]
# ## 8. Group anagrams ⭐⭐⭐
#
# Write `group_anagrams(words)` — group words that are anagrams of each other.
# ```
# group_anagrams(['eat','tea','tan','ate','nat','bat'])
# → [['eat','tea','ate'],['tan','nat'],['bat']]
# ```

# %%
def group_anagrams(words: list) -> list:
    pass

# %% [markdown]
# ## 9. Zigzag string ⭐⭐⭐
#
# Write `is_rotation(s, t)` — return True if t is a rotation of s.
# ```
# is_rotation('abcde','cdeab') → True
# ```

# %%
def is_rotation(s: str, t: str) -> bool:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert reverse_words('Hello World') == 'World Hello'
assert reverse_words('  spaces  here  ') == 'here spaces'
assert is_palindrome('racecar') == True
assert is_palindrome('A man a plan a canal Panama') == True
assert is_palindrome('hello') == False
assert is_anagram('listen','silent') == True
assert is_anagram('hello','world') == False
assert first_unique('aabbcde') == 'c'
assert first_unique('aabb') == ''
assert longest_common_prefix(['flower','flow','flight']) == 'fl'
assert longest_common_prefix(['dog','car']) == ''
assert is_valid_brackets('()[]{}') == True
assert is_valid_brackets('([)]') == False
assert is_valid_brackets('') == True
assert longest_unique_substring('abcabcbb') == 3
assert longest_unique_substring('bbbbb') == 1
assert longest_unique_substring('pwwkew') == 3
groups = group_anagrams(['eat','tea','tan','ate','nat','bat'])
assert len(groups) == 3
assert is_rotation('abcde','cdeab') == True
assert is_rotation('abcde','abced') == False
print('✅ All tests passed!')
