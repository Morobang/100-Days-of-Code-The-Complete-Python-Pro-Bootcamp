# %% [markdown]
# # Day 07 Challenges — Loops — while
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Countdown ⭐
#
# Print countdown from 10 to 1, then print 'Blast off!'

# %%
# write your solution

# %% [markdown]
# ## Challenge 2 — Sum until done ⭐⭐
#
# Keep asking the user for numbers. Sum them up. Stop when they type 'done'. Print the total.

# %%
# write your solution

# %% [markdown]
# ## Challenge 3 — Number guessing game ⭐⭐⭐
#
# Secret number is 7. Keep asking until correct.
# Print 'Too high', 'Too low', or 'Correct! in X attempts'.

# %%
secret = 7
# write your solution

# %% [markdown]
# ## ✅ Tests

# %%
result = []
n = 10
while n >= 1:
    result.append(n)
    n -= 1
assert result == list(range(10, 0, -1))
print('✅ Countdown logic correct!')
print('Challenges 2 & 3 — run them manually (they use input())')
