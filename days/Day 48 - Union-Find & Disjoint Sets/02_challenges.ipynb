# %% [markdown]
# # Day 48 Challenges — Union-Find & Disjoint Sets
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Implement UnionFind ⭐⭐
#
# Build a complete `UnionFind` class with path compression + union by rank.
# Methods: `find(x)`, `union(x,y)` → True if merged, `connected(x,y)`, `count` property (number of components).

# %%
class UnionFind:
    def __init__(self, n: int):
        self.parent = list(range(n))
        self.rank = [0]*n
        self._count = n

    def find(self, x):
        pass

    def union(self, x, y) -> bool:
        pass

    def connected(self, x, y) -> bool:
        pass

    @property
    def count(self): return self._count

# %% [markdown]
# ## 2. Number of provinces ⭐⭐
#
# Write `find_provinces(is_connected)` — given an n×n adjacency matrix, return number of connected components (provinces).

# %%
def find_provinces(is_connected: list) -> int:
    pass

# %% [markdown]
# ## 3. Redundant connection ⭐⭐
#
# Write `find_redundant(edges)` — find the edge that creates a cycle in an undirected graph.
# ```
# find_redundant([[1,2],[1,3],[2,3]]) → [2,3]
# ```

# %%
def find_redundant(edges: list) -> list:
    pass

# %% [markdown]
# ## 4. Accounts merge ⭐⭐⭐
#
# Write `accounts_merge(accounts)` — merge accounts sharing any email. Each account is `[name, email1, email2, ...]`.

# %%
def accounts_merge(accounts: list) -> list:
    pass

# %% [markdown]
# ## 5. Satisfiability of equality equations ⭐⭐
#
# Write `equations_possible(equations)` — True if all equality/inequality equations can be satisfied simultaneously.
# ```
# equations_possible(['a==b','b!=c','c==a']) → False
# ```

# %%
def equations_possible(equations: list) -> bool:
    pass

# %% [markdown]
# ## 6. Minimum spanning tree cost ⭐⭐⭐
#
# Write `min_spanning_tree(n, edges)` — return total cost of minimum spanning tree using Kruskal's. Edges are `[u,v,weight]`.

# %%
def min_spanning_tree(n: int, edges: list) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
uf=UnionFind(5)
assert uf.count==5
uf.union(0,1); uf.union(1,2)
assert uf.connected(0,2)==True
assert uf.connected(0,3)==False
assert uf.count==3

ic=[[1,1,0],[1,1,0],[0,0,1]]
assert find_provinces(ic)==2

assert find_redundant([[1,2],[1,3],[2,3]])==[2,3]
assert find_redundant([[1,2],[2,3],[3,4],[1,4],[1,5]])==[1,4]

eq=['a==b','b!=c','c==a']
assert equations_possible(eq)==False
eq2=['c==c','b==d','x!=z']
assert equations_possible(eq2)==True

assert min_spanning_tree(4,[[0,1,10],[0,2,6],[0,3,5],[1,3,15],[2,3,4]])==19
print('✅ All tests passed!')
