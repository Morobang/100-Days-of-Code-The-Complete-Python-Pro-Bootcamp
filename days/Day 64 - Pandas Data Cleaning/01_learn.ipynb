# %% [markdown]
# # Day 64 — Pandas Data Cleaning
#
# > See `notes.md` for syntax reference and key patterns.

# %% [markdown]
# ## Core concepts
#
# This day covers **Pandas Data Cleaning**. Work through the notes first, then tackle the challenges.
