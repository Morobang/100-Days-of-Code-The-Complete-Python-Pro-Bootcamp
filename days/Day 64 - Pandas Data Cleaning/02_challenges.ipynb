# %% [markdown]
# # Day 64 Challenges — Pandas Data Cleaning
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Remove duplicates ⭐
#
# Write `dedupe(df, subset)` — remove duplicate rows based on subset of columns, keep first.

# %%
import pandas as pd

def dedupe(df, subset):
    pass

# %% [markdown]
# ## 2. Parse dates ⭐⭐
#
# Write `parse_dates(df, col)` — parse a date column and extract year, month, day, and day_of_week as new columns.

# %%
def parse_dates(df, col):
    pass

# %% [markdown]
# ## 3. Remove outliers ⭐⭐
#
# Write `remove_outliers(df, col)` — remove rows where col value is more than 3 standard deviations from the mean.

# %%
def remove_outliers(df, col):
    pass

# %% [markdown]
# ## 4. Standardise text ⭐⭐
#
# Write `clean_text(df, col)` — lowercase, strip whitespace, remove special chars from a text column.

# %%
def clean_text(df, col):
    pass

# %% [markdown]
# ## 5. Apply custom function ⭐⭐
#
# Write `categorise_score(df)` — add a 'grade' column using a custom function (A/B/C/D/F based on score).

# %%
def categorise_score(df):
    pass

# %% [markdown]
# ## 6. Merge datasets ⭐⭐⭐
#
# Write `merge_customer_orders(customers_df, orders_df)` — merge on customer_id, fill missing order totals with 0.

# %%
def merge_customer_orders(customers_df, orders_df):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
print('Run each challenge cell — check output manually')
print('✅ Complete!')
