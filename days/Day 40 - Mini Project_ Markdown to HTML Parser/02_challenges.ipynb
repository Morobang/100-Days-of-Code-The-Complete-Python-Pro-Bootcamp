# %% [markdown]
# # Day 40 Challenges — Mini Project: Markdown to HTML Parser
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. convert_line ⭐⭐
#
# Write `convert_line(line)` — convert a single Markdown line to HTML.
# Handle: headings (h1-h6), **bold**, *italic*, `code`, [link](url), - list items.

# %%
import re

def convert_line(line: str) -> str:
    # write your solution
    pass

# %% [markdown]
# ## 2. convert_markdown ⭐⭐
#
# Write `convert_markdown(text)` — convert a full Markdown string to HTML.
# Group consecutive `<li>` items inside `<ul>...</ul>`.
# Wrap paragraph lines in `<p>...</p>`.

# %%
def convert_markdown(text: str) -> str:
    # write your solution
    pass

# %% [markdown]
# ## 3. File converter ⭐
#
# Write `convert_file(input_path, output_path)` — read a .md file, convert it, write .html file.

# %%
def convert_file(input_path: str, output_path: str):
    # write your solution
    pass

# %% [markdown]
# ## 4. Add HTML wrapper ⭐
#
# Write `wrap_html(body, title='Document')` — wrap the HTML body in a full HTML document with `<html>`, `<head>`, `<body>` tags.

# %%
def wrap_html(body: str, title: str = 'Document') -> str:
    # write your solution
    pass

# %% [markdown]
# ## 5. Test your parser ⭐⭐⭐
#
# Write at least 5 assertions that verify your parser handles edge cases correctly.

# %%
# Write your own test cases here
# Test headings, bold, italic, links, lists, empty lines

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
import re

assert convert_line('# Hello') == '<h1>Hello</h1>'
assert convert_line('## Sub') == '<h2>Sub</h2>'
assert '<strong>bold</strong>' in convert_line('**bold** text')
assert '<em>italic</em>' in convert_line('*italic* text')
assert '<code>x</code>' in convert_line('Use `x` here')
assert '<a href=' in convert_line('[Google](https://google.com)')
assert '<li>' in convert_line('- list item')

md = '# Title\n\nHello **world**\n\n- item 1\n- item 2'
html = convert_markdown(md)
assert '<h1>Title</h1>' in html
assert '<strong>world</strong>' in html
assert '<ul>' in html
print('✅ All tests passed!')
