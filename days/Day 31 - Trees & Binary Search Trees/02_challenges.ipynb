# %% [markdown]
# # Day 31 Challenges — Trees & Binary Search Trees
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Build BST ⭐⭐
#
# Write `insert(root, val)` — insert a value into a BST. Return root.
# Write `search(root, val)` — return True if val exists.

# %%
class TreeNode:
    def __init__(self, val):
        self.val=val; self.left=self.right=None

def insert(root, val):
    pass

def search(root, val):
    pass

# %% [markdown]
# ## 2. Tree traversals ⭐⭐
#
# Write `inorder(root)`, `preorder(root)`, `postorder(root)` — each returns a list.

# %%
def inorder(root): pass
def preorder(root): pass
def postorder(root): pass

# %% [markdown]
# ## 3. Max depth ⭐
#
# Write `max_depth(root)` — return the height of the tree.

# %%
def max_depth(root): pass

# %% [markdown]
# ## 4. Is balanced ⭐⭐
#
# Write `is_balanced(root)` — return True if no subtree differs in depth by more than 1.

# %%
def is_balanced(root): pass

# %% [markdown]
# ## 5. Level order traversal ⭐⭐
#
# Write `level_order(root)` — return list of lists, one per level.
# ```
# level_order(root) → [[5],[3,7],[1,4]]
# ```

# %%
from collections import deque
def level_order(root): pass

# %% [markdown]
# ## 6. Lowest common ancestor ⭐⭐⭐
#
# Write `lca(root, p, q)` — return the value of the lowest common ancestor of nodes with values p and q in a BST.

# %%
def lca(root, p, q): pass

# %% [markdown]
# ## 7. Is valid BST ⭐⭐⭐
#
# Write `is_valid_bst(root)` — return True if the tree is a valid BST.

# %%
def is_valid_bst(root, lo=float('-inf'), hi=float('inf')): pass

# %% [markdown]
# ## 8. Right side view ⭐⭐⭐
#
# Write `right_side_view(root)` — return values visible from the right side (rightmost node per level).
# ```
# [5,3,7,1,4] tree → [5,7,4]
# ```

# %%
from collections import deque
def right_side_view(root): pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
def make_bst(vals):
    root=None
    for v in vals: root=insert(root,v)
    return root

root=make_bst([5,3,7,1,4,6,8])
assert search(root,4)==True
assert search(root,9)==False
assert inorder(root)==[1,3,4,5,6,7,8]
assert preorder(root)==[5,3,1,4,7,6,8]
assert max_depth(root)==3
assert is_balanced(root)==True
ll=make_bst([1,2,3,4,5])
assert is_balanced(ll)==False
lo=level_order(root)
assert lo[0]==[5]
assert lo[1]==[3,7]
assert lca(root,1,4)==3
assert lca(root,1,8)==5
assert is_valid_bst(root)==True
bad=TreeNode(5); bad.left=TreeNode(6)
assert is_valid_bst(bad)==False
print('✅ All tests passed!')
