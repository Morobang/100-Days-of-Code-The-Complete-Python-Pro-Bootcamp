# %% [markdown]
# # Day 11 Challenges — Dictionaries
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Phone book ⭐
#
# Create a `phonebook` dict with 3 contacts.
# Write `lookup(book, name)` → number or `'Not found'`.

# %%
phonebook = {
    # add 3 entries
}

def lookup(book: dict, name: str) -> str:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 2 — Word frequency ⭐⭐
#
# Write `word_count(sentence)` → dict of word → count. Lowercase, strip `.,!?`.
# ```
# word_count('the cat sat on the mat') → {'the':2, 'cat':1, ...}
# ```

# %%
def word_count(sentence: str) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 3 — Deep merge ⭐⭐⭐
#
# Write `deep_merge(d1, d2)` — merge two dicts. For nested dict values recurse. d2 wins on conflict.
# ```
# deep_merge({'a':1,'b':{'x':1}}, {'b':{'y':2},'c':3})
# → {'a':1,'b':{'x':1,'y':2},'c':3}
# ```

# %%
def deep_merge(d1: dict, d2: dict) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests

# %%
book = {'Rocket':'083-111-2222','Alice':'072-333-4444'}
assert lookup(book, 'Rocket') == '083-111-2222'
assert lookup(book, 'Unknown') == 'Not found'

wc = word_count('the cat sat on the mat')
assert wc['the'] == 2
assert wc['cat'] == 1

merged = deep_merge({'a':1,'b':{'x':1}},{'b':{'y':2},'c':3})
assert merged == {'a':1,'b':{'x':1,'y':2},'c':3}
print('✅ All tests passed!')
