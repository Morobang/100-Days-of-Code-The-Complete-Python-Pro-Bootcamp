# %% [markdown]
# # Day 63 Challenges — Pandas Basics
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Read CSV and explore ⭐
#
# Write `explore(df)` — return dict with shape, columns, dtypes, and null counts.

# %%
import pandas as pd

def explore(df):
    pass

# %% [markdown]
# ## 2. Filter and sort ⭐
#
# Write `top_scorers(df, n)` — filter rows where score > 80, sort by score desc, return top n.

# %%
def top_scorers(df, n):
    pass

# %% [markdown]
# ## 3. Add computed column ⭐⭐
#
# Write `add_bmi(df)` — add a 'bmi' column (weight/height²) to a df with 'weight_kg' and 'height_m' columns.

# %%
def add_bmi(df):
    pass

# %% [markdown]
# ## 4. Handle missing values ⭐⭐
#
# Write `clean(df)` — drop rows where 'name' is null, fill numeric nulls with column median.

# %%
def clean(df):
    pass

# %% [markdown]
# ## 5. Group and aggregate ⭐⭐
#
# Write `genre_summary(df)` — group a games df by 'genre', return count and mean price per genre.

# %%
def genre_summary(df):
    pass

# %% [markdown]
# ## 6. Pivot table ⭐⭐⭐
#
# Write `monthly_sales(df)` — pivot a sales df (date, product, amount) to show total sales per product per month.

# %%
def monthly_sales(df):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
print('Run each challenge cell — check output manually')
print('✅ Complete!')
