# %% [markdown]
# # Day 63 — Pandas Basics
#
# > See `notes.md` for syntax reference and key patterns.

# %% [markdown]
# ## Core concepts
#
# This day covers **Pandas Basics**. Work through the notes first, then tackle the challenges.
