# %% [markdown]
# # Day 19 Challenges — OOP: Inheritance & Dunder Methods
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Shape hierarchy ⭐⭐⭐
#
# Build:
# - `Shape(color='white')` base — `area()` raises NotImplementedError, `describe()` → `'A white Circle with area 78.54'`
# - `Circle(radius, color='white')`
# - `Rectangle(width, height, color='white')`
# - `Square(side)` extends Rectangle
# - `__gt__`/`__lt__`/`__eq__` compare by area (so `sorted()` works)

# %%
import math

class Shape:
    def __init__(self, color='white'):
        # write your solution
        pass

class Circle(Shape):
    def __init__(self, radius, color='white'):
        # write your solution
        pass

class Rectangle(Shape):
    def __init__(self, width, height, color='white'):
        # write your solution
        pass

class Square(Rectangle):
    def __init__(self, side, color='white'):
        # write your solution
        pass

# %% [markdown]
# ## ✅ Tests

# %%
c = Circle(5, 'blue')
assert round(c.area(),2) == 78.54
assert 'blue' in c.describe()
assert 'Circle' in c.describe()

r = Rectangle(4, 3)
assert r.area() == 12

s = Square(4)
assert s.area() == 16
assert isinstance(s, Rectangle)
assert isinstance(s, Shape)

shapes = [Circle(5), Rectangle(4,3), Square(4)]
ss = sorted(shapes)
assert ss[0].area() <= ss[1].area() <= ss[2].area()
print('✅ All tests passed!')
