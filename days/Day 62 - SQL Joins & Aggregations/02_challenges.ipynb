# %% [markdown]
# # Day 62 Challenges — SQL Joins & Aggregations
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Setup schema ⭐
#
# Create a DB with `products`, `customers`, `orders`, `order_items` tables. Insert sample data.

# %%
import sqlite3

def setup_schema():
    conn=sqlite3.connect(':memory:')
    # write your solution
    return conn

# %% [markdown]
# ## 2. Customer order totals ⭐⭐
#
# Write `customer_totals(conn)` — total order value per customer (name, total), ordered by total desc.

# %%
def customer_totals(conn):
    pass

# %% [markdown]
# ## 3. Top n customers ⭐⭐
#
# Write `top_customers(conn, n)` — n customers with highest total spend.

# %%
def top_customers(conn, n):
    pass

# %% [markdown]
# ## 4. Products never ordered ⭐⭐
#
# Write `unordered_products(conn)` — products with no orders at all.

# %%
def unordered_products(conn):
    pass

# %% [markdown]
# ## 5. Monthly revenue ⭐⭐⭐
#
# Write `monthly_revenue(conn)` — total revenue per month (YYYY-MM), ordered by month.

# %%
def monthly_revenue(conn):
    pass

# %% [markdown]
# ## 6. Second highest spender ⭐⭐⭐
#
# Write `second_highest_spender(conn)` — customer name with second highest total spend.

# %%
def second_highest_spender(conn):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
conn=setup_schema()
totals=customer_totals(conn)
assert len(totals)>0
top=top_customers(conn,2)
assert len(top)==2
print('✅ Tests passed!')
