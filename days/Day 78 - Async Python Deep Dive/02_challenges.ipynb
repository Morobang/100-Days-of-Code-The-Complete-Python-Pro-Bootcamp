# %% [markdown]
# # Day 78 Challenges — Async Python Deep Dive
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.

# %% [markdown]
# ## 1. Async generator range ⭐⭐
#
# Write `async_range(start, stop, step=1)` — an async generator that yields values like range().

# %%
import asyncio

async def async_range(start, stop, step=1):
    pass

# %% [markdown]
# ## 2. Async map and filter ⭐⭐
#
# Write `async_map(fn, aiterable)` and `async_filter(pred, aiterable)` — async versions of map and filter.

# %%
async def async_map(fn, aiterable):
    pass

async def async_filter(pred, aiterable):
    pass

# %% [markdown]
# ## 3. Async pipeline ⭐⭐⭐
#
# Build a pipeline: producer puts numbers in a queue, worker squares them, collector gathers results.

# %%
import asyncio

async def pipeline(numbers):
    # write your solution using asyncio.Queue
    pass

# %% [markdown]
# ## 4. Async timeout ⭐⭐
#
# Write `with_timeout(coro, seconds)` — run a coroutine with a timeout. Return result or raise TimeoutError.

# %%
import asyncio

async def with_timeout(coro, seconds):
    pass

# %% [markdown]
# ## 5. Gather with error handling ⭐⭐
#
# Write `safe_gather(*coros)` — run all coroutines, return list of (result, None) or (None, error) tuples.

# %%
import asyncio

async def safe_gather(*coros):
    pass

# %% [markdown]
# ## ✅ Tests

# %%
import asyncio

result=asyncio.run(async_map(lambda x:x**2, async_range(5)))
assert result==[0,1,4,9,16]

result=asyncio.run(async_filter(lambda x:x%2==0, async_range(10)))
assert result==[0,2,4,6,8]

result=asyncio.run(pipeline([1,2,3,4,5]))
assert sorted(result)==[1,4,9,16,25]

async def slow(): await asyncio.sleep(0.01); return 'done'
assert asyncio.run(with_timeout(slow(),1))=='done'
print('✅ All tests passed!')
