# %% [markdown]
# # Day 33 Challenges — Dynamic Programming
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Climbing stairs ⭐
#
# Write `climb_stairs(n)` — how many ways to climb n stairs taking 1 or 2 steps at a time?

# %%
def climb_stairs(n: int) -> int:
    pass

# %% [markdown]
# ## 2. House robber ⭐⭐
#
# Write `rob(houses)` — max money from non-adjacent houses.
# ```
# rob([2,7,9,3,1]) → 12
# ```

# %%
def rob(houses: list) -> int:
    pass

# %% [markdown]
# ## 3. Coin change ⭐⭐
#
# Write `coin_change(coins, amount)` — min coins to make amount. Return -1 if impossible.
# ```
# coin_change([1,5,11],15) → 3  (5+5+5)
# ```

# %%
def coin_change(coins: list, amount: int) -> int:
    pass

# %% [markdown]
# ## 4. Longest common subsequence ⭐⭐
#
# Write `lcs(s1, s2)` — length of longest common subsequence.
# ```
# lcs('abcde','ace') → 3
# ```

# %%
def lcs(s1: str, s2: str) -> int:
    pass

# %% [markdown]
# ## 5. 0/1 Knapsack ⭐⭐⭐
#
# Write `knapsack(weights, values, capacity)` — max value with weight limit. Each item used at most once.

# %%
def knapsack(weights: list, values: list, capacity: int) -> int:
    pass

# %% [markdown]
# ## 6. Word break ⭐⭐⭐
#
# Write `word_break(s, word_dict)` — can s be segmented into words from the dictionary?
# ```
# word_break('leetcode',['leet','code']) → True
# ```

# %%
def word_break(s: str, word_dict: list) -> bool:
    pass

# %% [markdown]
# ## 7. Unique paths ⭐⭐
#
# Write `unique_paths(m, n)` — how many paths from top-left to bottom-right of m×n grid (only right/down moves)?

# %%
def unique_paths(m: int, n: int) -> int:
    pass

# %% [markdown]
# ## 8. Maximum product subarray ⭐⭐⭐
#
# Write `max_product(lst)` — find the contiguous subarray with the largest product.
# ```
# max_product([2,3,-2,4]) → 6
# ```

# %%
def max_product(lst: list) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert climb_stairs(2)==2
assert climb_stairs(3)==3
assert climb_stairs(5)==8

assert rob([2,7,9,3,1])==12
assert rob([1,2,3,1])==4

assert coin_change([1,5,11],15)==3
assert coin_change([2],3)==-1

assert lcs('abcde','ace')==3
assert lcs('abc','abc')==3
assert lcs('abc','def')==0

assert knapsack([1,3,4,5],[1,4,5,7],7)==9

assert word_break('leetcode',['leet','code'])==True
assert word_break('catsandog',['cats','dog','sand','and','cat'])==False

assert unique_paths(3,7)==28
assert unique_paths(1,1)==1

assert max_product([2,3,-2,4])==6
assert max_product([-2,0,-1])==0
print('✅ All tests passed!')
