# %% [markdown]
# # Day 12 Challenges — Tuples & Sets
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Deduplicate preserving order ⭐⭐
#
# Write `unique(lst)` — remove duplicates keeping first-seen order.
# Can't just do `list(set(lst))` — that loses order.

# %%
def unique(lst: list) -> list:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 2 — Common & exclusive friends ⭐⭐
#
# Given two sets, print:
# - Friends they share
# - Friends only in the first set
# - Friends only in the second set

# %%
rocket_friends = {'Alice','Bob','Charlie','Dave'}
alice_friends  = {'Bob','Charlie','Eve','Frank'}
# write your solution

# %% [markdown]
# ## Challenge 3 — Top scorer from tuples ⭐⭐⭐
#
# Write `top_scorer(players)` — given a list of `(name, score)` tuples, return the name with the highest score.

# %%
def top_scorer(players: list) -> str:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests

# %%
assert unique([1,2,2,3,1,4]) == [1,2,3,4]
assert unique(['a','b','a']) == ['a','b']

players = [('Rocket',9500),('Alice',8700),('Bob',10200)]
assert top_scorer(players) == 'Bob'
print('✅ All tests passed!')
