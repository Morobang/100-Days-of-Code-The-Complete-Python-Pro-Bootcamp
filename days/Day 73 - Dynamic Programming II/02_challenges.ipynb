# %% [markdown]
# # Day 73 Challenges — Dynamic Programming II
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.

# %% [markdown]
# ## 1. Palindrome partitioning min cuts ⭐⭐⭐
#
# Write `min_cut(s)` — minimum cuts to partition s so each part is a palindrome.
# ```
# min_cut('aab') → 1  (aa|b)
# ```

# %%
def min_cut(s):
    pass

# %% [markdown]
# ## 2. Egg drop problem ⭐⭐⭐
#
# Write `egg_drop(eggs, floors)` — minimum trials to find critical floor with given eggs.

# %%
def egg_drop(eggs, floors):
    pass

# %% [markdown]
# ## 3. Dungeon game ⭐⭐⭐
#
# Write `min_health(dungeon)` — minimum initial health to reach bottom-right of grid.
# Negative cells drain health, positive cells add health. Must stay > 0.

# %%
def min_health(dungeon):
    pass

# %% [markdown]
# ## 4. Paint fence ⭐⭐
#
# Write `paint_fence(n, k)` — count ways to paint n fence posts with k colors so at most 2 adjacent posts have same color.

# %%
def paint_fence(n, k):
    pass

# %% [markdown]
# ## 5. Longest valid parentheses ⭐⭐⭐
#
# Write `longest_valid_parens(s)` — length of longest valid parentheses substring.
# ```
# longest_valid_parens(')()())') → 4
# ```

# %%
def longest_valid_parens(s):
    pass

# %% [markdown]
# ## 6. Jump game III ⭐⭐
#
# Write `can_reach_zero(lst, start)` — True if you can reach any index with value 0, jumping ±lst[i] each step.

# %%
def can_reach_zero(lst, start):
    pass

# %% [markdown]
# ## 7. Count ways to tile ⭐⭐⭐
#
# Write `tiling_ways(n)` — count ways to tile a 2×n board with 2×1 dominoes.

# %%
def tiling_ways(n):
    pass

# %% [markdown]
# ## 8. Minimum cost to cut a stick ⭐⭐⭐
#
# Write `min_cost_cuts(n, cuts)` — minimum cost to make all cuts in a stick of length n (cost = length of stick being cut).

# %%
def min_cost_cuts(n, cuts):
    pass

# %% [markdown]
# ## ✅ Tests

# %%
assert min_cut('aab')==1
assert min_cut('a')==0
assert min_cut('ab')==1

assert egg_drop(1,10)==10
assert egg_drop(2,10)==4

assert min_health([[-2,-3,3],[-5,-10,1],[10,30,-5]])==7

assert paint_fence(3,2)==6
assert paint_fence(1,1)==1

assert longest_valid_parens(')()())')==4
assert longest_valid_parens('(()')==2

assert can_reach_zero([4,2,3,0,3,1,2],5)==True
assert can_reach_zero([3,0,2,1,2],2)==False

assert tiling_ways(1)==1
assert tiling_ways(3)==3
assert tiling_ways(4)==5

assert min_cost_cuts(7,[1,3,4,5])==16
print('✅ All tests passed!')
