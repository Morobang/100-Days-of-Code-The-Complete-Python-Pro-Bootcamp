# %% [markdown]
# # Day 67 — APIs with requests
#
# > See `notes.md` for syntax reference and key patterns.

# %% [markdown]
# ## Core concepts
#
# This day covers **APIs with requests**. Work through the notes first, then tackle the challenges.
