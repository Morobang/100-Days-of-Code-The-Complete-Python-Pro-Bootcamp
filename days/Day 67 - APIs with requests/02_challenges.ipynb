# %% [markdown]
# # Day 67 Challenges — APIs with requests
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. GET request ⭐
#
# Write `get_json(url)` — fetch and return JSON from a URL. Return None on error.

# %%
import requests

def get_json(url):
    pass

# %% [markdown]
# ## 2. POST request ⭐⭐
#
# Write `post_json(url, data, headers=None)` — POST JSON data and return response dict.

# %%
def post_json(url, data, headers=None):
    pass

# %% [markdown]
# ## 3. API client class ⭐⭐
#
# Write `APIClient(base_url, api_key)` with `get(endpoint, params=None)` and `post(endpoint, data)`.

# %%
class APIClient:
    def __init__(self, base_url, api_key):
        pass

    def get(self, endpoint, params=None):
        pass

    def post(self, endpoint, data):
        pass

# %% [markdown]
# ## 4. Rate-limited requester ⭐⭐⭐
#
# Write `rate_limited_get(urls, delay=0.5)` — fetch list of URLs sequentially with a delay between requests.

# %%
import time

def rate_limited_get(urls, delay=0.5):
    pass

# %% [markdown]
# ## 5. Retry with backoff ⭐⭐⭐
#
# Write `get_with_retry(url, retries=3, backoff=2)` — retry failed requests with exponential backoff.

# %%
import time

def get_with_retry(url, retries=3, backoff=2):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
print('Run each challenge cell — check output manually')
print('✅ Complete!')
