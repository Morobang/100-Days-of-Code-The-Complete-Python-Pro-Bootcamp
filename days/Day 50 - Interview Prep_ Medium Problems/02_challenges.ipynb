# %% [markdown]
# # Day 50 Challenges — Interview Prep: Medium Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Longest substring without repeating ⭐⭐
#
# Write `length_of_longest(s)` → length of longest substring with no repeating characters.

# %%
def length_of_longest(s):
    pass

# %% [markdown]
# ## 2. Container with most water ⭐⭐
#
# Write `max_water(heights)` → max water between two lines.

# %%
def max_water(heights):
    pass

# %% [markdown]
# ## 3. Three sum ⭐⭐
#
# Write `three_sum(lst)` → all unique triplets summing to 0.

# %%
def three_sum(lst):
    pass

# %% [markdown]
# ## 4. Coin change ⭐⭐
#
# Write `coin_change(coins, amount)` → minimum coins to make amount. -1 if impossible.

# %%
def coin_change(coins, amount):
    pass

# %% [markdown]
# ## 5. Kth largest in stream ⭐⭐
#
# Write `KthLargest(k, initial)` class with `add(val)` → returns kth largest after each add.

# %%
import heapq

class KthLargest:
    def __init__(self, k, initial):
        pass

    def add(self, val):
        pass

# %% [markdown]
# ## 6. Reorder list ⭐⭐⭐
#
# Write `reorder_list(head)` — reorder L0→L1→...→Ln to L0→Ln→L1→Ln-1→... in-place.

# %%
class Node:
    def __init__(self,v): self.val=v; self.next=None

def reorder_list(head):
    pass

# %% [markdown]
# ## 7. Find all duplicates in array ⭐⭐
#
# Write `find_duplicates(lst)` → all elements that appear twice. O(n) time, O(1) extra space.

# %%
def find_duplicates(lst):
    pass

# %% [markdown]
# ## 8. Number of islands ⭐⭐
#
# Write `num_islands(grid)` → count islands in a '1'/'0' grid.

# %%
def num_islands(grid):
    pass

# %% [markdown]
# ## 9. Decode string ⭐⭐
#
# Write `decode_string(s)` → decode k[encoded] format.
# ```
# decode_string('3[a2[c]]') → 'accaccacc'
# ```

# %%
def decode_string(s):
    pass

# %% [markdown]
# ## 10. Time-based key-value store ⭐⭐⭐
#
# Write `TimeMap` class with `set(key,value,timestamp)` and `get(key,timestamp)` → value with largest timestamp ≤ given.

# %%
from collections import defaultdict
import bisect

class TimeMap:
    def __init__(self):
        pass

    def set(self, key, value, timestamp):
        pass

    def get(self, key, timestamp):
        pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert length_of_longest('abcabcbb')==3
assert length_of_longest('bbbbb')==1

assert max_water([1,8,6,2,5,4,8,3,7])==49

result=three_sum([-1,0,1,2,-1,-4])
assert [-1,-1,2] in result and [-1,0,1] in result

assert coin_change([1,5,11],15)==3
assert coin_change([2],3)==-1

kth=KthLargest(3,[4,5,8,2])
assert kth.add(3)==4
assert kth.add(5)==5

assert sorted(find_duplicates([4,3,2,7,8,2,3,1]))==[2,3]

grid=[['1','1','0'],['0','1','0'],['0','0','1']]
assert num_islands(grid)==2

assert decode_string('3[a]2[bc]')=='aaabcbc'
assert decode_string('3[a2[c]]')=='accaccacc'

tm=TimeMap()
tm.set('foo','bar',1); tm.set('foo','bar2',4)
assert tm.get('foo',4)=='bar2'
assert tm.get('foo',3)=='bar'
print('✅ All tests passed!')
