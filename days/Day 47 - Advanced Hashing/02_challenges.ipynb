# %% [markdown]
# # Day 47 Challenges — Advanced Hashing
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Anagram groups ⭐⭐
#
# Write `group_anagrams(words)` — group words that are anagrams of each other.

# %%
from collections import defaultdict
def group_anagrams(words: list) -> list:
    pass

# %% [markdown]
# ## 2. Isomorphic strings ⭐⭐
#
# Write `is_isomorphic(s, t)` — True if chars in s can be mapped 1-to-1 to chars in t.
# ```
# is_isomorphic('egg','add') → True
# is_isomorphic('foo','bar') → False
# ```

# %%
def is_isomorphic(s: str, t: str) -> bool:
    pass

# %% [markdown]
# ## 3. Word pattern ⭐⭐
#
# Write `word_pattern(pattern, s)` — True if s follows the pattern.
# ```
# word_pattern('abba','dog cat cat dog') → True
# ```

# %%
def word_pattern(pattern: str, s: str) -> bool:
    pass

# %% [markdown]
# ## 4. Contiguous array ⭐⭐⭐
#
# Write `max_equal_01(lst)` — longest contiguous subarray with equal 0s and 1s.
# ```
# max_equal_01([0,1,0,0,1,1]) → 6
# ```

# %%
def max_equal_01(lst: list) -> int:
    pass

# %% [markdown]
# ## 5. Longest arithmetic subsequence ⭐⭐⭐
#
# Write `longest_arith_seq(lst)` — length of longest arithmetic subsequence.

# %%
def longest_arith_seq(lst: list) -> int:
    pass

# %% [markdown]
# ## 6. Subarray sum equals k ⭐⭐
#
# Write `subarray_sum_count(lst, k)` — count subarrays summing to exactly k.

# %%
def subarray_sum_count(lst: list, k: int) -> int:
    pass

# %% [markdown]
# ## 7. Brick wall ⭐⭐
#
# Write `least_bricks(wall)` — find the minimum number of bricks crossed by a vertical line.
# ```
# least_bricks([[1,2,2,1],[3,1,2],[1,3,2]]) → 2
# ```

# %%
from collections import Counter
def least_bricks(wall: list) -> int:
    pass

# %% [markdown]
# ## 8. Max points on a line ⭐⭐⭐
#
# Write `max_points(points)` — max number of points on the same straight line.

# %%
from collections import defaultdict
from math import gcd
def max_points(points: list) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
groups=group_anagrams(['eat','tea','tan','ate','nat','bat'])
assert len(groups)==3

assert is_isomorphic('egg','add')==True
assert is_isomorphic('foo','bar')==False
assert is_isomorphic('paper','title')==True

assert word_pattern('abba','dog cat cat dog')==True
assert word_pattern('abba','dog cat cat fish')==False

assert max_equal_01([0,1,0,0,1,1])==6
assert max_equal_01([0,1])==2

assert subarray_sum_count([1,1,1],2)==2
assert subarray_sum_count([1,2,3],3)==2

assert least_bricks([[1,2,2,1],[3,1,2],[1,3,2]])==2

assert max_points([[1,1],[2,2],[3,3]])==3
assert max_points([[1,1],[3,2],[5,3],[4,1],[2,3],[1,4]])==4
print('✅ All tests passed!')
