# %% [markdown]
# # Day 48 Challenges — String Compression & Encoding
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Run-length encode/decode ⭐⭐
#
# Write `rle_encode(s)` and `rle_decode(s)`.
# ```
# rle_encode('aaabbbcc') → '3a3b2c'
# rle_decode('3a3b2c')   → 'aaabbbcc'
# ```

# %%
def rle_encode(s: str) -> str:
    pass

def rle_decode(s: str) -> str:
    pass

# %% [markdown]
# ## 2. String compression ⭐⭐
#
# Write `compress(s)` — compress using counts (aabcccccaaa → a2b1c5a3). Return original if compressed isn't shorter.

# %%
def compress(s: str) -> str:
    pass

# %% [markdown]
# ## 3. Encode/decode strings ⭐⭐
#
# Write `encode(strs)` and `decode(s)` — encode a list of strings to a single string and back. Handle any characters including delimiters.

# %%
def encode(strs: list) -> str:
    pass

def decode(s: str) -> list:
    pass

# %% [markdown]
# ## 4. Base conversion ⭐⭐
#
# Write `to_base(n, base)` — convert integer n to string in given base (2-16).
# Write `from_base(s, base)` — convert string in given base back to integer.

# %%
def to_base(n: int, base: int) -> str:
    pass

def from_base(s: str, base: int) -> int:
    pass

# %% [markdown]
# ## 5. Serialize/deserialize binary tree ⭐⭐⭐
#
# Write `serialize(root)` and `deserialize(data)` — convert a binary tree to a string and back.

# %%
class TreeNode:
    def __init__(self,val): self.val=val; self.left=self.right=None

def serialize(root) -> str:
    pass

def deserialize(data: str):
    pass

# %% [markdown]
# ## 6. Count and say ⭐⭐
#
# Write `count_and_say(n)` — generate the nth term.
# ```
# 1 → '1'
# 2 → '11'  (one 1)
# 3 → '21'  (two 1s)
# 4 → '1211'
# ```

# %%
def count_and_say(n: int) -> str:
    pass

# %% [markdown]
# ## 7. Decode ways ⭐⭐⭐
#
# Write `decode_ways(s)` — number of ways to decode a string of digits to letters (A=1..Z=26).
# ```
# decode_ways('226') → 3  (2,2,6 or 22,6 or 2,26)
# ```

# %%
def decode_ways(s: str) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert rle_encode('aaabbbcc')=='3a3b2c'
assert rle_encode('abc')=='abc'
assert rle_decode('3a3b2c')=='aaabbbcc'
assert rle_decode('abc')=='abc'

assert compress('aabcccccaaa')=='a2b1c5a3'

strs=['hello','world','','python']
assert decode(encode(strs))==strs

assert to_base(255,16)=='ff'
assert to_base(10,2)=='1010'
assert from_base('ff',16)==255
assert from_base('1010',2)==10

assert count_and_say(1)=='1'
assert count_and_say(4)=='1211'

assert decode_ways('226')==3
assert decode_ways('06')==0
assert decode_ways('12')==2
print('✅ All tests passed!')
