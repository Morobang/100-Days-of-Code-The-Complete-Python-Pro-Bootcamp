# %% [markdown]
# # Day 15 — Error Handling
#
# > Handle errors gracefully — your program should never crash unexpectedly.

# %% [markdown]
# ## try / except

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print('Cannot divide by zero!')

try:
    number = int('hello')
except ValueError as e:
    print(f'Error: {e}')

# %% [markdown]
# ## else and finally
#
# - `else` — runs only if NO exception occurred
# - `finally` — ALWAYS runs (cleanup)

# %%
try:
    x = int('42')
except ValueError:
    print('Not a number')
else:
    print(f'Got: {x}')    # only if no exception
finally:
    print('Done')         # always runs

# %% [markdown]
# ## Common exceptions
#
# | Exception | When |
# |-----------|------|
# | `ValueError` | Wrong value (`int('hi')`) |
# | `TypeError` | Wrong type (`'a' + 1`) |
# | `KeyError` | Dict key missing |
# | `IndexError` | List index out of range |
# | `ZeroDivisionError` | Division by zero |
# | `FileNotFoundError` | File doesn't exist |

# %%
def safe_divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return None
    except TypeError:
        return None

print(safe_divide(10, 2))    # 5.0
print(safe_divide(10, 0))    # None
print(safe_divide('a', 2))   # None

# %% [markdown]
# ## Raising exceptions

# %%
def set_age(age):
    if age < 0:
        raise ValueError(f'Age cannot be negative: {age}')
    return age

try:
    set_age(-5)
except ValueError as e:
    print(e)

# %% [markdown]
# ## Custom exceptions

# %%
class InsufficientFundsError(Exception):
    def __init__(self, balance, amount):
        self.balance = balance
        self.amount  = amount
        super().__init__(f'Cannot withdraw R{amount} — balance is R{balance}')

try:
    raise InsufficientFundsError(100, 500)
except InsufficientFundsError as e:
    print(e)
