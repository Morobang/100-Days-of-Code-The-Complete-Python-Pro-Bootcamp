# %% [markdown]
# # Day 15 Challenges — Error Handling
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Safe input loop ⭐⭐
#
# Write `get_positive_int(prompt)` — keeps asking until the user enters a valid positive integer.

# %%
def get_positive_int(prompt: str) -> int:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 2 — Safe dict lookup ⭐
#
# Write `safe_get(d, key, default=None)` — return `d[key]` or default if any error. Never crash.

# %%
def safe_get(d, key, default=None):
    # write your solution
    pass

# %% [markdown]
# ## Challenge 3 — BankAccount with validation ⭐⭐⭐
#
# Build a `BankAccount` class with `deposit(amount)` and `withdraw(amount)`.
# Raise `ValueError` for negative amounts, raise `InsufficientFundsError` for overdraft.

# %%
class InsufficientFundsError(Exception):
    pass

class BankAccount:
    def __init__(self, owner, balance=0):
        # write your solution
        pass

    def deposit(self, amount):
        pass

    def withdraw(self, amount):
        pass

    def balance(self):
        pass

# %% [markdown]
# ## ✅ Tests

# %%
assert safe_get({'a':1}, 'a') == 1
assert safe_get({'a':1}, 'b') is None
assert safe_get({'a':1}, 'b', 0) == 0

acc = BankAccount('Rocket', 1000)
acc.deposit(500)
assert acc.balance() == 1500
acc.withdraw(200)
assert acc.balance() == 1300
try:
    acc.withdraw(9999)
    assert False
except InsufficientFundsError:
    pass
try:
    acc.deposit(-100)
    assert False
except ValueError:
    pass
print('✅ All tests passed!')
