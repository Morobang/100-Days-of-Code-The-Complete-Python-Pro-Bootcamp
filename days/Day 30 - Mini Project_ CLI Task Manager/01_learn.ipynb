# %% [markdown]
# # Day 30 — Mini Project: CLI Task Manager
#
# > Combine everything from Days 21–29 into one working app.

# %% [markdown]
# ## What you're building
#
# A command-line task manager that:
# - Adds tasks with a title, priority, and due date
# - Lists tasks sorted by priority
# - Marks tasks as done
# - Deletes tasks
# - Persists to JSON between runs

# %% [markdown]
# ## Plan first
#
# ```
# Task class — holds title, priority, due_date, done
# TaskManager class — stores tasks, save/load JSON
# main() — CLI loop
# ```

# %% [markdown]
# ## Starter architecture

# %%
# Priority values
PRIORITIES = {'low': 1, 'medium': 2, 'high': 3}

# Menu options
MENU = '''
=== Task Manager ===
1. Add task
2. List tasks
3. Complete task
4. Delete task
5. Exit
'''
