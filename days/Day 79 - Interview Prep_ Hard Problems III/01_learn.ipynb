# %% [markdown]
# # Day 79 — Interview Prep: Hard Problems III

# %% [markdown]
# ## Hard problem strategies
#
# 1. **Reduction**: convert to a known problem
# 2. **Invariant**: what stays true at each step?
# 3. **Backwards**: solve from the end state
# 4. **DP on a graph**: shortest path with states
# 5. **Two heaps**: median, kth element
# 6. **Segment tree**: range queries with updates
