# %% [markdown]
# # Day 79 Challenges — Interview Prep: Hard Problems III
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.

# %% [markdown]
# ## 1. Longest increasing path in matrix ⭐⭐⭐
#
# Write `lip(matrix)` — length of longest strictly increasing path in any direction.

# %%
def lip(matrix):
    pass

# %% [markdown]
# ## 2. Maximum profit job scheduling ⭐⭐⭐
#
# Write `job_scheduling(startTime, endTime, profit)` — max profit with non-overlapping jobs.
# ```
# job_scheduling([1,2,3,3],[3,4,5,6],[50,10,40,70]) → 120
# ```

# %%
import bisect

def job_scheduling(startTime, endTime, profit):
    pass

# %% [markdown]
# ## 3. Number of ways to reorder array ⭐⭐⭐
#
# Write `count_reorders(nums)` — count ways to reorder so BST built from it is identical to the original. Return result mod 10^9+7.

# %%
from math import comb

def count_reorders(nums):
    pass

# %% [markdown]
# ## 4. Minimum cost to connect all points ⭐⭐⭐
#
# Write `min_cost_connect(points)` — minimum cost MST using Manhattan distance. Prim's or Kruskal's.

# %%
import heapq

def min_cost_connect(points):
    pass

# %% [markdown]
# ## 5. Find all anagrams in string ⭐⭐
#
# Write `find_anagrams(s, p)` — return all start indices of p's anagrams in s.
# ```
# find_anagrams('cbaebabacd','abc') → [0,6]
# ```

# %%
from collections import Counter

def find_anagrams(s, p):
    pass

# %% [markdown]
# ## 6. Minimum path sum in triangle ⭐⭐
#
# Write `min_path_triangle(triangle)` — minimum path sum from top to bottom.
# ```
# min_path_triangle([[2],[3,4],[6,5,7],[4,1,8,3]]) → 11
# ```

# %%
def min_path_triangle(triangle):
    pass

# %% [markdown]
# ## 7. Stone game ⭐⭐⭐
#
# Write `stone_game(piles)` — True if Alice wins optimally (alternating picks from ends, Alice goes first).

# %%
def stone_game(piles):
    pass

# %% [markdown]
# ## 8. Expression add operators ⭐⭐⭐
#
# Write `add_operators(num, target)` — return all ways to insert +,-,* between digits to reach target.
# ```
# add_operators('123',6) → ['1+2+3','1*2*3']
# ```

# %%
def add_operators(num, target):
    pass

# %% [markdown]
# ## ✅ Tests

# %%
assert lip([[9,9,4],[6,6,8],[2,1,1]])==4
assert lip([[3,4,5],[3,2,6],[2,2,1]])==4

assert job_scheduling([1,2,3,3],[3,4,5,6],[50,10,40,70])==120

assert min_cost_connect([[0,0],[2,2],[3,10],[5,2],[7,0]])==20

assert find_anagrams('cbaebabacd','abc')==[0,6]
assert find_anagrams('baa','aa')==[1]

assert min_path_triangle([[2],[3,4],[6,5,7],[4,1,8,3]])==11

assert stone_game([5,3,4,5])==True

ops=add_operators('123',6)
assert '1+2+3' in ops
assert '1*2*3' in ops
print('✅ All tests passed!')
