# %% [markdown]
# # Day 70 Challenges — Mini Project: Data Pipeline
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Fetch data ⭐⭐
#
# Write `fetch_data(url)` — download JSON data from a public API and return as a list of dicts.

# %%
import requests

def fetch_data(url):
    pass

# %% [markdown]
# ## 2. Transform data ⭐⭐
#
# Write `transform(records)` — clean records: lowercase all string keys, strip whitespace, parse numeric fields.

# %%
def transform(records):
    pass

# %% [markdown]
# ## 3. Load to SQLite ⭐⭐
#
# Write `load_to_db(records, db_path, table_name)` — create table from records schema and insert all rows.

# %%
import sqlite3

def load_to_db(records, db_path, table_name):
    pass

# %% [markdown]
# ## 4. Export to CSV ⭐
#
# Write `export_csv(db_path, table_name, output_path)` — read table from SQLite and save as CSV.

# %%
import sqlite3, csv

def export_csv(db_path, table_name, output_path):
    pass

# %% [markdown]
# ## 5. Full pipeline ⭐⭐⭐
#
# Write `run_pipeline(url, db_path, csv_path)` — orchestrate all steps with logging. Return summary dict.

# %%
import logging

logging.basicConfig(level=logging.INFO)

def run_pipeline(url, db_path, csv_path):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
print('Run each challenge cell — check output manually')
print('✅ Complete!')
