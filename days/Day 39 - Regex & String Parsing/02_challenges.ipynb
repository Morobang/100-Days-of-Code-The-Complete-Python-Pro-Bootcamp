# %% [markdown]
# # Day 39 Challenges — Regex & String Parsing
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Validate email ⭐
#
# Write `is_valid_email(s)` using regex — must have exactly one @, a domain, and a TLD.

# %%
import re
def is_valid_email(s: str) -> bool:
    pass

# %% [markdown]
# ## 2. Extract all numbers ⭐
#
# Write `extract_numbers(text)` — return a list of all integers and floats found in the text.

# %%
import re
def extract_numbers(text: str) -> list:
    pass

# %% [markdown]
# ## 3. Validate phone number ⭐⭐
#
# Write `is_valid_phone(s)` — match formats: `083-111-2222`, `0831112222`, `+27831112222`.

# %%
import re
def is_valid_phone(s: str) -> bool:
    pass

# %% [markdown]
# ## 4. Extract URLs ⭐⭐
#
# Write `extract_urls(text)` — return all http/https URLs found in the text.

# %%
import re
def extract_urls(text: str) -> list:
    pass

# %% [markdown]
# ## 5. Censor words ⭐⭐
#
# Write `censor(text, words)` — replace each word in `words` with `****`. Case-insensitive.

# %%
import re
def censor(text: str, words: list) -> str:
    pass

# %% [markdown]
# ## 6. Parse key=value ⭐⭐
#
# Write `parse_config(text)` — extract all `key=value` pairs into a dict.
# ```
# parse_config('host=localhost port=5432') → {'host':'localhost','port':'5432'}
# ```

# %%
import re
def parse_config(text: str) -> dict:
    pass

# %% [markdown]
# ## 7. Tokenise expression ⭐⭐⭐
#
# Write `tokenise(expr)` — split a math expression into tokens (numbers, operators, brackets).
# ```
# tokenise('3.14*(x+2)') → ['3.14','*','(','x','+','2',')']
# ```

# %%
import re
def tokenise(expr: str) -> list:
    pass

# %% [markdown]
# ## 8. Markdown bold to HTML ⭐⭐
#
# Write `md_bold(text)` — convert `**bold**` to `<strong>bold</strong>`.

# %%
import re
def md_bold(text: str) -> str:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
import re

assert is_valid_email('rocket@nexcade.co.za')==True
assert is_valid_email('noemail.com')==False
assert is_valid_email('two@@domain.com')==False

nums=extract_numbers('I have 3 cats and 1.5 kg of food')
assert 3 in nums and 1.5 in nums

assert is_valid_phone('083-111-2222')==True
assert is_valid_phone('0831112222')==True
assert is_valid_phone('12345')==False

urls=extract_urls('Visit https://nexcade.co.za or http://example.com')
assert len(urls)==2

result=censor('the bad word is bad','bad')
assert 'bad' not in result.lower()

cfg=parse_config('host=localhost port=5432 debug=true')
assert cfg['host']=='localhost' and cfg['port']=='5432'

assert tokenise('3.14*(x+2)')==['3.14','*','(','x','+','2',')']

assert md_bold('This is **bold** text')=='This is <strong>bold</strong> text'
print('✅ All tests passed!')
