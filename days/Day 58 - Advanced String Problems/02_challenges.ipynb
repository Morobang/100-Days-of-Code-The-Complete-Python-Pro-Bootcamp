# %% [markdown]
# # Day 58 Challenges — Advanced String Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Longest palindromic substring ⭐⭐⭐
#
# Write `longest_palindrome(s)` — return the longest palindromic substring.
# ```
# longest_palindrome('babad') → 'bab'
# ```

# %%
def longest_palindrome(s: str) -> str:
    pass

# %% [markdown]
# ## 2. Edit distance ⭐⭐⭐
#
# Write `edit_distance(s1, s2)` — minimum operations (insert, delete, replace) to transform s1 to s2.
# ```
# edit_distance('horse','ros') → 3
# ```

# %%
def edit_distance(s1: str, s2: str) -> int:
    pass

# %% [markdown]
# ## 3. Wildcard matching ⭐⭐⭐
#
# Write `wildcard_match(s, pattern)` — match where `?` matches any single char and `*` matches any sequence.
# ```
# wildcard_match('aa','*') → True
# wildcard_match('cb','?a') → False
# ```

# %%
def wildcard_match(s: str, pattern: str) -> bool:
    pass

# %% [markdown]
# ## 4. Longest palindromic subsequence ⭐⭐⭐
#
# Write `lps(s)` — length of longest palindromic subsequence.
# ```
# lps('bbbab') → 4  (bbbb)
# ```

# %%
def lps(s: str) -> int:
    pass

# %% [markdown]
# ## 5. Shortest palindrome ⭐⭐⭐
#
# Write `shortest_palindrome(s)` — add the fewest chars to the FRONT to make s a palindrome.
# ```
# shortest_palindrome('aacecaaa') → 'aaacecaaa'
# ```

# %%
def shortest_palindrome(s: str) -> str:
    pass

# %% [markdown]
# ## 6. Count distinct subsequences ⭐⭐⭐
#
# Write `count_subsequences(s, t)` — count distinct ways t appears as a subsequence of s.
# ```
# count_subsequences('rabbbit','rabbit') → 3
# ```

# %%
def count_subsequences(s: str, t: str) -> int:
    pass

# %% [markdown]
# ## 7. String interleaving ⭐⭐⭐
#
# Write `is_interleave(s1, s2, s3)` — True if s3 is formed by interleaving s1 and s2.

# %%
def is_interleave(s1: str, s2: str, s3: str) -> bool:
    pass

# %% [markdown]
# ## 8. Scramble string ⭐⭐⭐
#
# Write `is_scramble(s1, s2)` — True if s2 is a scrambled version of s1 (recursive splits and optional swaps).

# %%
from functools import lru_cache

def is_scramble(s1: str, s2: str) -> bool:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert longest_palindrome('babad') in ('bab','aba')
assert longest_palindrome('cbbd')=='bb'

assert edit_distance('horse','ros')==3
assert edit_distance('intention','execution')==5

assert wildcard_match('aa','*')==True
assert wildcard_match('cb','?a')==False
assert wildcard_match('adceb','*a*b')==True

assert lps('bbbab')==4
assert lps('cbbd')==2

assert count_subsequences('rabbbit','rabbit')==3
assert count_subsequences('babgbag','bag')==5

assert is_interleave('aabcc','dbbca','aadbbcbcac')==True
assert is_interleave('aabcc','dbbca','aadbbbaccc')==False
print('✅ All tests passed!')
