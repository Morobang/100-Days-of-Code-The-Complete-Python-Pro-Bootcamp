# %% [markdown]
# # Day 32 Challenges — Stacks, Queues & Deques
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Valid brackets ⭐
#
# Write `is_valid(s)` — True if all brackets `()[]{}` are correctly matched.

# %%
def is_valid(s: str) -> bool:
    pass

# %% [markdown]
# ## 2. Min stack ⭐⭐
#
# Implement `MinStack` — push, pop, and `get_min()` all in O(1).

# %%
class MinStack:
    def __init__(self): self._data=[]; self._mins=[]
    def push(self, val): pass
    def pop(self): pass
    def get_min(self): pass

# %% [markdown]
# ## 3. Evaluate RPN ⭐⭐
#
# Write `eval_rpn(tokens)` — evaluate a Reverse Polish Notation expression.
# ```
# eval_rpn(['2','1','+','3','*']) → 9
# ```

# %%
def eval_rpn(tokens: list) -> int:
    pass

# %% [markdown]
# ## 4. Daily temperatures ⭐⭐
#
# Write `daily_temps(temps)` — for each day, how many days until a warmer temperature? 0 if none.
# ```
# daily_temps([73,74,75,71,69,72,76,73]) → [1,1,4,2,1,1,0,0]
# ```

# %%
def daily_temps(temps: list) -> list:
    pass

# %% [markdown]
# ## 5. Sliding window maximum ⭐⭐⭐
#
# Write `sliding_max(lst, k)` — return the max of each window of size k.
# ```
# sliding_max([1,3,-1,-3,5,3,6,7],3) → [3,3,5,5,6,7]
# ```

# %%
from collections import deque
def sliding_max(lst: list, k: int) -> list:
    pass

# %% [markdown]
# ## 6. Largest rectangle in histogram ⭐⭐⭐
#
# Write `largest_rectangle(heights)` — find the largest rectangle area in a histogram.
# ```
# largest_rectangle([2,1,5,6,2,3]) → 10
# ```

# %%
def largest_rectangle(heights: list) -> int:
    pass

# %% [markdown]
# ## 7. Decode string ⭐⭐⭐
#
# Write `decode_string(s)` — decode `k[encoded]` format.
# ```
# decode_string('3[a]2[bc]') → 'aaabcbc'
# decode_string('3[a2[c]]') → 'accaccacc'
# ```

# %%
def decode_string(s: str) -> str:
    pass

# %% [markdown]
# ## 8. BFS shortest path ⭐⭐
#
# Write `shortest_path(grid, start, end)` — find shortest path length in a 0/1 grid (0=open,1=wall). Return -1 if no path.

# %%
from collections import deque
def shortest_path(grid, start, end):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert is_valid('()[]{}') == True
assert is_valid('([)]') == False
assert is_valid('{[]}') == True
assert is_valid('') == True

ms=MinStack()
ms.push(3);ms.push(1);ms.push(2)
assert ms.get_min()==1
ms.pop(); assert ms.get_min()==1
ms.pop(); assert ms.get_min()==3

assert eval_rpn(['2','1','+','3','*'])==9
assert eval_rpn(['4','13','5','/','+']==6)

assert daily_temps([73,74,75,71,69,72,76,73])==[1,1,4,2,1,1,0,0]

assert sliding_max([1,3,-1,-3,5,3,6,7],3)==[3,3,5,5,6,7]

assert largest_rectangle([2,1,5,6,2,3])==10
assert largest_rectangle([2,4])==4

assert decode_string('3[a]2[bc]')=='aaabcbc'
assert decode_string('3[a2[c]]')=='accaccacc'
print('✅ All tests passed!')
