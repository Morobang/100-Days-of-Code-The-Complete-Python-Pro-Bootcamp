# %% [markdown]
# # Day 34 Challenges — Two Pointers & Sliding Window
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Two sum (sorted) ⭐
#
# Write `two_sum_sorted(lst, target)` — return indices of two numbers summing to target in a SORTED list.

# %%
def two_sum_sorted(lst, target):
    pass

# %% [markdown]
# ## 2. Three sum ⭐⭐
#
# Write `three_sum(lst)` — find all unique triplets summing to 0.
# ```
# three_sum([-1,0,1,2,-1,-4]) → [[-1,-1,2],[-1,0,1]]
# ```

# %%
def three_sum(lst: list) -> list:
    pass

# %% [markdown]
# ## 3. Container with most water ⭐⭐
#
# Write `max_water(heights)` — find two lines that form the container holding the most water.
# ```
# max_water([1,8,6,2,5,4,8,3,7]) → 49
# ```

# %%
def max_water(heights: list) -> int:
    pass

# %% [markdown]
# ## 4. Minimum window substring ⭐⭐⭐
#
# Write `min_window(s, t)` — smallest window in s containing all chars of t.
# ```
# min_window('ADOBECODEBANC','ABC') → 'BANC'
# ```

# %%
def min_window(s: str, t: str) -> str:
    pass

# %% [markdown]
# ## 5. Longest substring with k distinct chars ⭐⭐
#
# Write `longest_k_distinct(s, k)` — length of longest substring with at most k distinct characters.
# ```
# longest_k_distinct('eceba', 2) → 3
# ```

# %%
def longest_k_distinct(s: str, k: int) -> int:
    pass

# %% [markdown]
# ## 6. Remove duplicates from sorted array II ⭐⭐
#
# Write `remove_dups_ii(lst)` — allow each element at most twice, in-place. Return new length.

# %%
def remove_dups_ii(lst: list) -> int:
    pass

# %% [markdown]
# ## 7. Trapping rain water ⭐⭐⭐
#
# Write `trap(heights)` — compute total water trapped.
# ```
# trap([0,1,0,2,1,0,1,3,2,1,2,1]) → 6
# ```

# %%
def trap(heights: list) -> int:
    pass

# %% [markdown]
# ## 8. Fruit into baskets ⭐⭐
#
# Write `total_fruit(fruits)` — max number of fruits collectible with 2 baskets (each holds 1 type).
# ```
# total_fruit([1,2,1]) → 3
# ```

# %%
def total_fruit(fruits: list) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert two_sum_sorted([2,7,11,15],9)==(0,1)
assert two_sum_sorted([2,3,4],6)==(0,2)

result=three_sum([-1,0,1,2,-1,-4])
assert [-1,-1,2] in result and [-1,0,1] in result

assert max_water([1,8,6,2,5,4,8,3,7])==49
assert max_water([1,1])==1

assert min_window('ADOBECODEBANC','ABC')=='BANC'
assert min_window('a','a')=='a'

assert longest_k_distinct('eceba',2)==3
assert longest_k_distinct('aa',1)==2

lst=[1,1,1,2,2,3]; n=remove_dups_ii(lst)
assert n==5 and lst[:5]==[1,1,2,2,3]

assert trap([0,1,0,2,1,0,1,3,2,1,2,1])==6
assert trap([4,2,0,3,2,5])==9

assert total_fruit([1,2,1])==3
assert total_fruit([0,1,2,2])==3
print('✅ All tests passed!')
