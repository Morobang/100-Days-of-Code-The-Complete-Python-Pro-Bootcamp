# %% [markdown]
# # Day 47 Challenges — Tries
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Build Trie ⭐⭐
#
# Build a complete `Trie` class with:
# - `insert(word)`
# - `search(word)` → exact match
# - `starts_with(prefix)` → True if any word starts with prefix
# - `delete(word)` → remove a word

# %%
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False

class Trie:
    def __init__(self): self.root = TrieNode()

    def insert(self, word):
        pass

    def search(self, word) -> bool:
        pass

    def starts_with(self, prefix) -> bool:
        pass

    def delete(self, word):
        pass

# %% [markdown]
# ## 2. Count words with prefix ⭐⭐
#
# Add `count_words_with_prefix(prefix)` to Trie — count how many inserted words start with the given prefix.

# %%
# Extend your Trie class from above:
def count_words_with_prefix(self, prefix: str) -> int:
    pass

# %% [markdown]
# ## 3. Longest common prefix ⭐⭐
#
# Write `longest_common_prefix(words)` using a Trie.

# %%
def longest_common_prefix(words: list) -> str:
    pass

# %% [markdown]
# ## 4. Word search II ⭐⭐⭐
#
# Write `find_words(board, words)` — find all words from the list that exist in the board (like word search, but multiple words).
# ```
# find_words([['o','a'],['e','t']],['eat','tea','tan','ate','nat','bat']) → ['eat','tea','ate']
# ```

# %%
def find_words(board: list, words: list) -> list:
    pass

# %% [markdown]
# ## 5. Replace words ⭐⭐
#
# Write `replace_words(dictionary, sentence)` — replace each word in sentence with its shortest root from dictionary.
# ```
# replace_words(['cat','bat','rat'],'the cattle was rattled') → 'the cat was rat'
# ```

# %%
def replace_words(dictionary: list, sentence: str) -> str:
    pass

# %% [markdown]
# ## 6. Magic dictionary ⭐⭐⭐
#
# Implement `MagicDictionary` with `build(words)` and `search(word)` — True if word exists after changing exactly one letter.

# %%
class MagicDictionary:
    def __init__(self):
        pass

    def build(self, words):
        pass

    def search(self, word) -> bool:
        pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
trie=Trie()
for w in ['apple','app','application','apply']: trie.insert(w)
assert trie.search('apple')==True
assert trie.search('appl')==False
assert trie.starts_with('app')==True
assert trie.starts_with('xyz')==False
trie.delete('apple')
assert trie.search('apple')==False
assert trie.search('app')==True

assert longest_common_prefix(['flower','flow','flight'])=='fl'
assert longest_common_prefix(['dog','racecar','car'])==''

board=[['o','a','a','n'],['e','t','a','e'],['i','h','k','r'],['i','f','l','v']]
words=['oath','pea','eat','rain']
found=find_words(board,words)
assert 'eat' in found and 'oath' in found

assert replace_words(['cat','bat','rat'],'the cattle was rattled')=='the cat was rat'

md=MagicDictionary()
md.build(['hello','leetcode'])
assert md.search('hello')==False
assert md.search('hhllo')==True
assert md.search('hell')==False
print('✅ All tests passed!')
