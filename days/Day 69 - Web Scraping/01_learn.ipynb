# %% [markdown]
# # Day 69 — Web Scraping
#
# > See `notes.md` for syntax reference and key patterns.

# %% [markdown]
# ## Core concepts
#
# This day covers **Web Scraping**. Work through the notes first, then tackle the challenges.
