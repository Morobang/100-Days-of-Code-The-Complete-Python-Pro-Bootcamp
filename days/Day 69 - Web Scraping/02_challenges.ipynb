# %% [markdown]
# # Day 69 Challenges — Web Scraping
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Fetch and parse HTML ⭐⭐
#
# Write `get_soup(url)` — fetch a URL and return a BeautifulSoup object. Return None on error.

# %%
from bs4 import BeautifulSoup
import requests

def get_soup(url):
    pass

# %% [markdown]
# ## 2. Extract links ⭐⭐
#
# Write `extract_links(html, base_url='')` — extract all absolute links from HTML string.

# %%
from bs4 import BeautifulSoup

def extract_links(html, base_url=''):
    pass

# %% [markdown]
# ## 3. Scrape table ⭐⭐
#
# Write `scrape_table(html)` — parse first HTML table into a list of dicts.

# %%
from bs4 import BeautifulSoup

def scrape_table(html):
    pass

# %% [markdown]
# ## 4. Clean scraped text ⭐⭐
#
# Write `clean_text(html)` — strip all HTML tags and normalise whitespace.

# %%
from bs4 import BeautifulSoup
import re

def clean_text(html):
    pass

# %% [markdown]
# ## 5. Respect rate limits ⭐⭐
#
# Write `polite_scraper(urls, delay=1)` — scrape list of URLs with delay, return list of (url, soup or None).

# %%
import time
from bs4 import BeautifulSoup
import requests

def polite_scraper(urls, delay=1):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
print('Run each challenge cell — check output manually')
print('✅ Complete!')
