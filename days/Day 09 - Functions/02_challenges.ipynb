# %% [markdown]
# # Day 09 Challenges — Functions
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Area functions ⭐
#
# Write `area_circle(r)`, `area_rectangle(w,h)`, `area_triangle(b,h)`. Each rounded to 2dp.

# %%
import math

def area_circle(r):
    pass

def area_rectangle(w, h):
    pass

def area_triangle(b, h):
    pass

# %% [markdown]
# ## Challenge 2 — Password validator ⭐⭐
#
# Write `is_valid_password(p)` → True if: 8+ chars, has a digit, has an uppercase letter.

# %%
def is_valid_password(p: str) -> bool:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 3 — Caesar cipher ⭐⭐⭐
#
# Write `caesar(text, shift)` — shift each letter, wrap z→a.
# ```
# caesar('hello', 3) → 'khoor'
# ```

# %%
def caesar(text: str, shift: int) -> str:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests

# %%
assert area_circle(5) == 78.54
assert area_rectangle(4, 3) == 12.0
assert area_triangle(6, 4) == 12.0

assert is_valid_password('Rocket123') == True
assert is_valid_password('short') == False
assert is_valid_password('nouppercase1') == False
assert is_valid_password('NoNumbers!!') == False

assert caesar('hello', 3) == 'khoor'
assert caesar('xyz', 2) == 'zab'
assert caesar('Hello!', 1) == 'Ifmmp!'
print('✅ All tests passed!')
