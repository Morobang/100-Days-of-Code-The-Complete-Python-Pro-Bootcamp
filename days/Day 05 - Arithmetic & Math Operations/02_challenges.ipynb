# %% [markdown]
# # Day 05 Challenges — Arithmetic & Math Operations
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Tip calculator ⭐⭐
#
# Ask for bill total, tip%, and number of people.
# Print each person's share rounded to 2dp.

# %%
# write your solution

# %% [markdown]
# ## Challenge 2 — Even or odd ⭐
#
# Ask for a number. Print 'Even' or 'Odd' using `%`.

# %%
# write your solution

# %% [markdown]
# ## Challenge 3 — Compound interest ⭐⭐⭐
#
# Ask for principal, annual rate (%), and years.
# Formula: `A = P * (1 + r/100) ** t`
# Print final amount rounded to 2dp.

# %%
# write your solution

# %% [markdown]
# ## ✅ Tests

# %%
def tip(bill, pct, people): return round(bill * (1 + pct/100) / people, 2)
assert tip(100, 10, 2) == 55.0
assert tip(150, 20, 3) == 60.0

def compound(p, r, t): return round(p * (1 + r/100) ** t, 2)
assert compound(1000, 10, 1) == 1100.0
assert compound(1000, 10, 2) == 1210.0
print('✅ Tests passed!')
