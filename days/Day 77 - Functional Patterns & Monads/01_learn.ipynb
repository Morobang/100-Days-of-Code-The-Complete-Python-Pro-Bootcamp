# %% [markdown]
# # Day 77 — Functional Patterns & Monads

# %% [markdown]
# ## Maybe monad — handle None gracefully
# ```python
# class Maybe:
#     def __init__(self, value): self._value = value
#     def bind(self, fn): return Maybe(fn(self._value)) if self._value is not None else self
#     def get_or(self, default): return self._value if self._value is not None else default
#     def __repr__(self): return f'Maybe({self._value})'
# ```
#
# ## Result monad — handle errors
# ```python
# class Ok:
#     def __init__(self, value): self.value = value
#     def bind(self, fn): return fn(self.value)
#     def map(self, fn): return Ok(fn(self.value))
#     def get_or(self, default): return self.value
#
# class Err:
#     def __init__(self, error): self.error = error
#     def bind(self, fn): return self
#     def map(self, fn): return self
#     def get_or(self, default): return default
# ```
