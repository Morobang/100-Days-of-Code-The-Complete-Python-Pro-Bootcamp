# %% [markdown]
# # Day 44 Challenges — Greedy Algorithms
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Jump game ⭐⭐
#
# Write `can_jump(nums)` — True if you can reach the last index. Each element is max jump length.
# ```
# can_jump([2,3,1,1,4]) → True
# can_jump([3,2,1,0,4]) → False
# ```

# %%
def can_jump(nums: list) -> bool:
    pass

# %% [markdown]
# ## 2. Jump game II ⭐⭐
#
# Write `min_jumps(nums)` — minimum jumps to reach the last index.

# %%
def min_jumps(nums: list) -> int:
    pass

# %% [markdown]
# ## 3. Gas station ⭐⭐
#
# Write `can_complete_circuit(gas, cost)` — return starting station index to complete the circuit, or -1.
# ```
# can_complete_circuit([1,2,3,4,5],[3,4,5,1,2]) → 3
# ```

# %%
def can_complete_circuit(gas: list, cost: list) -> int:
    pass

# %% [markdown]
# ## 4. Assign cookies ⭐
#
# Write `assign_cookies(children, cookies)` — max children satisfied. Each child needs g[i] size, each cookie is s[j] size.
# ```
# assign_cookies([1,2,3],[1,1]) → 1
# ```

# %%
def assign_cookies(children: list, cookies: list) -> int:
    pass

# %% [markdown]
# ## 5. Non-overlapping intervals ⭐⭐
#
# Write `erase_overlap(intervals)` — minimum intervals to remove so none overlap.
# ```
# erase_overlap([[1,2],[2,3],[3,4],[1,3]]) → 1
# ```

# %%
def erase_overlap(intervals: list) -> int:
    pass

# %% [markdown]
# ## 6. Partition labels ⭐⭐
#
# Write `partition_labels(s)` — partition s so each letter appears in at most one part. Return sizes.
# ```
# partition_labels('ababcbacadefegdehijhklij') → [9,7,8]
# ```

# %%
def partition_labels(s: str) -> list:
    pass

# %% [markdown]
# ## 7. Queue reconstruction by height ⭐⭐⭐
#
# Write `reconstruct_queue(people)` — each person is `[h, k]` (height, people in front taller/equal). Reconstruct the queue.
# ```
# reconstruct_queue([[7,0],[4,4],[7,1],[5,0],[6,1],[5,2]]) → [[5,0],[7,0],[5,2],[6,1],[4,4],[7,1]]
# ```

# %%
def reconstruct_queue(people: list) -> list:
    pass

# %% [markdown]
# ## 8. Minimum number of arrows ⭐⭐
#
# Write `min_arrows(points)` — minimum arrows to burst all balloons (each `[start,end]` is a balloon range).

# %%
def min_arrows(points: list) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert can_jump([2,3,1,1,4])==True
assert can_jump([3,2,1,0,4])==False

assert min_jumps([2,3,1,1,4])==2
assert min_jumps([2,3,0,1,4])==2

assert can_complete_circuit([1,2,3,4,5],[3,4,5,1,2])==3
assert can_complete_circuit([2,3,4],[3,4,3])==-1

assert assign_cookies([1,2,3],[1,1])==1
assert assign_cookies([1,2],[1,2,3])==2

assert erase_overlap([[1,2],[2,3],[3,4],[1,3]])==1
assert erase_overlap([[1,2],[1,2],[1,2]])==2

assert partition_labels('ababcbacadefegdehijhklij')==[9,7,8]

assert reconstruct_queue([[7,0],[4,4],[7,1],[5,0],[6,1],[5,2]])==[[5,0],[7,0],[5,2],[6,1],[4,4],[7,1]]

assert min_arrows([[10,16],[2,8],[1,6],[7,12]])==2
print('✅ All tests passed!')
