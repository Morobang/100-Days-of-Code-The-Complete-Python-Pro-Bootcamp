# %% [markdown]
# # Day 49 — Interview Prep: Easy Problems
#
# > Speed round. These should take under 5 minutes each.
# > If you're spending more than 10 minutes on one — move on, come back.

# %% [markdown]
# ## Strategy for easy problems
#
# 1. Read once
# 2. Identify pattern (two pointers? hash map? sorting?)
# 3. Write code
# 4. Check edge cases (empty, single element, negatives)
