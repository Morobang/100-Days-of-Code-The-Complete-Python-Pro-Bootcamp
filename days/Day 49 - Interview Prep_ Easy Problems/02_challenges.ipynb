# %% [markdown]
# # Day 49 Challenges — Interview Prep: Easy Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Two sum ⭐
#
# Write `two_sum(lst, target)` → indices of two numbers summing to target. O(n).

# %%
def two_sum(lst, target):
    pass

# %% [markdown]
# ## 2. Valid anagram ⭐
#
# Write `is_anagram(s, t)` → True if s and t are anagrams.

# %%
def is_anagram(s, t):
    pass

# %% [markdown]
# ## 3. Contains duplicate ⭐
#
# Write `has_duplicate(lst)` → True if any value appears at least twice.

# %%
def has_duplicate(lst):
    pass

# %% [markdown]
# ## 4. Best time to buy stock ⭐
#
# Write `max_profit(prices)` → max profit from one buy and one sell.
# ```
# max_profit([7,1,5,3,6,4]) → 5
# ```

# %%
def max_profit(prices):
    pass

# %% [markdown]
# ## 5. Palindrome linked list ⭐
#
# Write `is_palindrome_list(head)` → True if linked list is a palindrome.

# %%
class Node:
    def __init__(self,v): self.val=v; self.next=None

def is_palindrome_list(head):
    pass

# %% [markdown]
# ## 6. Merge sorted arrays ⭐
#
# Write `merge_sorted(nums1, m, nums2, n)` — merge nums2 into nums1 in-place. nums1 has extra space.

# %%
def merge_sorted(nums1, m, nums2, n):
    pass

# %% [markdown]
# ## 7. Climbing stairs ⭐
#
# Write `climb_stairs(n)` → ways to climb n stairs (1 or 2 steps).

# %%
def climb_stairs(n):
    pass

# %% [markdown]
# ## 8. Reverse linked list ⭐
#
# Write `reverse_list(head)` → reverse a linked list, return new head.

# %%
class Node:
    def __init__(self,v): self.val=v; self.next=None

def reverse_list(head):
    pass

# %% [markdown]
# ## 9. Balanced parentheses ⭐
#
# Write `is_balanced(s)` → True if all parentheses are balanced.

# %%
def is_balanced(s):
    pass

# %% [markdown]
# ## 10. Maximum depth binary tree ⭐
#
# Write `max_depth(root)` → height of binary tree.

# %%
class Node:
    def __init__(self,v): self.val=v; self.left=self.right=None

def max_depth(root):
    pass

# %% [markdown]
# ## 11. Move zeros ⭐
#
# Write `move_zeros(lst)` — move all zeros to end, maintain order of non-zeros, in-place.

# %%
def move_zeros(lst):
    pass

# %% [markdown]
# ## 12. Intersection of two arrays ⭐
#
# Write `intersect(a, b)` → intersection including duplicates.
# ```
# intersect([1,2,2,1],[2,2]) → [2,2]
# ```

# %%
def intersect(a, b):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert two_sum([2,7,11,15],9)==(0,1)
assert is_anagram('anagram','nagaram')==True
assert is_anagram('rat','car')==False
assert has_duplicate([1,2,3,1])==True
assert has_duplicate([1,2,3])==False
assert max_profit([7,1,5,3,6,4])==5
assert max_profit([7,6,4,3,1])==0

def make_list(vals):
    if not vals: return None
    head=Node(vals[0]); cur=head
    for v in vals[1:]: cur.next=Node(v); cur=cur.next
    return head
assert is_palindrome_list(make_list([1,2,2,1]))==True
assert is_palindrome_list(make_list([1,2]))==False

nums1=[1,2,3,0,0,0]; merge_sorted(nums1,3,[2,5,6],3)
assert nums1==[1,2,2,3,5,6]

assert climb_stairs(3)==3
assert climb_stairs(5)==8

head=make_list([1,2,3,4,5])
rh=reverse_list(head)
cur=rh; vals=[]
while cur: vals.append(cur.val); cur=cur.next
assert vals==[5,4,3,2,1]

assert is_balanced('()[]{}')==True
assert is_balanced('([)]')==False

root=Node(3); root.left=Node(9); root.right=Node(20)
root.right.left=Node(15); root.right.right=Node(7)
assert max_depth(root)==3

lst=[0,1,0,3,12]; move_zeros(lst)
assert lst==[1,3,12,0,0]

assert sorted(intersect([1,2,2,1],[2,2]))==[2,2]
print('✅ All tests passed!')
