# %% [markdown]
# # Day 29 Challenges — Linked Lists
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Build LinkedList ⭐⭐
#
# Complete the `LinkedList` class with:
# - `append(val)` — add to end
# - `prepend(val)` — add to front
# - `delete(val)` — remove first occurrence
# - `to_list()` — return as Python list
# - `__len__` and `__str__`

# %%
class Node:
    def __init__(self, val):
        self.val = val
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, val):
        pass

    def prepend(self, val):
        pass

    def delete(self, val):
        pass

    def to_list(self):
        pass

    def __len__(self):
        pass

    def __str__(self):
        pass

# %% [markdown]
# ## 2. Reverse a linked list ⭐⭐
#
# Write `reverse_ll(head)` — reverse a linked list in-place, return new head.

# %%
def reverse_ll(head):
    pass

# %% [markdown]
# ## 3. Find middle node ⭐⭐
#
# Write `find_middle(head)` — return the value of the middle node.
# For even length, return the second middle.
# ```
# 1→2→3→4→5 → 3
# 1→2→3→4   → 3
# ```

# %%
def find_middle(head):
    pass

# %% [markdown]
# ## 4. Has cycle ⭐⭐⭐
#
# Write `has_cycle(head)` — return True if the linked list has a cycle. Use Floyd's algorithm (slow/fast pointer).

# %%
def has_cycle(head):
    pass

# %% [markdown]
# ## 5. Remove nth from end ⭐⭐⭐
#
# Write `remove_nth_from_end(head, n)` — remove the nth node from the end. Return new head.

# %%
def remove_nth_from_end(head, n):
    pass

# %% [markdown]
# ## 6. Merge two sorted lists ⭐⭐⭐
#
# Write `merge_sorted_ll(l1, l2)` — merge two sorted linked lists into one sorted list. Return new head.

# %%
def merge_sorted_ll(l1, l2):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
ll=LinkedList()
ll.append(1);ll.append(2);ll.append(3)
ll.prepend(0)
assert ll.to_list()==[0,1,2,3]
assert len(ll)==4
ll.delete(2)
assert ll.to_list()==[0,1,3]

# reverse
ll2=LinkedList()
for v in [1,2,3,4,5]: ll2.append(v)
new_head=reverse_ll(ll2.head)
cur=new_head; vals=[]
while cur: vals.append(cur.val); cur=cur.next
assert vals==[5,4,3,2,1]

# middle
ll3=LinkedList()
for v in [1,2,3,4,5]: ll3.append(v)
assert find_middle(ll3.head)==3
ll4=LinkedList()
for v in [1,2,3,4]: ll4.append(v)
assert find_middle(ll4.head)==3

# cycle
ll5=LinkedList()
for v in [1,2,3]: ll5.append(v)
assert has_cycle(ll5.head)==False

print('✅ All tests passed!')
