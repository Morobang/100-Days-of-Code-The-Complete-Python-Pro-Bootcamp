# %% [markdown]
# # Day 45 Challenges — Interval Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Merge intervals ⭐⭐
#
# Write `merge_intervals(intervals)` — merge all overlapping intervals.

# %%
def merge_intervals(intervals: list) -> list:
    pass

# %% [markdown]
# ## 2. Insert interval ⭐⭐
#
# Write `insert_interval(intervals, new)` — insert `new` into a sorted non-overlapping list, merge if needed.
# ```
# insert_interval([[1,3],[6,9]],[2,5]) → [[1,5],[6,9]]
# ```

# %%
def insert_interval(intervals: list, new: list) -> list:
    pass

# %% [markdown]
# ## 3. Meeting rooms I ⭐
#
# Write `can_attend(intervals)` — True if a person can attend all meetings (no overlaps).

# %%
def can_attend(intervals: list) -> bool:
    pass

# %% [markdown]
# ## 4. Meeting rooms II ⭐⭐
#
# Write `min_rooms(intervals)` — minimum meeting rooms required.
# ```
# min_rooms([[0,30],[5,10],[15,20]]) → 2
# ```

# %%
def min_rooms(intervals: list) -> int:
    pass

# %% [markdown]
# ## 5. Employee free time ⭐⭐⭐
#
# Write `employee_free_time(schedules)` — find free intervals for all employees combined.
# ```
# employee_free_time([[[1,3],[6,7]],[[2,4]],[[2,5],[9,12]]]) → [[5,6],[7,9]]
# ```

# %%
def employee_free_time(schedules: list) -> list:
    pass

# %% [markdown]
# ## 6. Range module ⭐⭐⭐
#
# Implement `RangeModule` class:
# - `add_range(left, right)` — track range [left,right)
# - `query_range(left, right)` — True if entire range is tracked
# - `remove_range(left, right)` — stop tracking range

# %%
class RangeModule:
    def __init__(self):
        self.ranges = []

    def add_range(self, left, right):
        pass

    def query_range(self, left, right) -> bool:
        pass

    def remove_range(self, left, right):
        pass

# %% [markdown]
# ## 7. Number of overlapping pairs ⭐⭐
#
# Write `count_overlapping(intervals)` — count the total number of overlapping pairs.

# %%
def count_overlapping(intervals: list) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert merge_intervals([[1,3],[2,6],[8,10],[15,18]])==[[1,6],[8,10],[15,18]]
assert merge_intervals([[1,4],[4,5]])==[[1,5]]

assert insert_interval([[1,3],[6,9]],[2,5])==[[1,5],[6,9]]
assert insert_interval([[1,2],[3,5],[6,7],[8,10],[12,16]],[4,8])==[[1,2],[3,10],[12,16]]

assert can_attend([[0,30],[5,10]])==False
assert can_attend([[5,10],[15,20]])==True

assert min_rooms([[0,30],[5,10],[15,20]])==2
assert min_rooms([[7,10],[2,4]])==1

ft=employee_free_time([[[1,3],[6,7]],[[2,4]],[[2,5],[9,12]]])
assert [5,6] in ft or [5,6] in [list(x) for x in ft]

rm=RangeModule()
rm.add_range(10,20); rm.add_range(30,40)
assert rm.query_range(10,14)==True
assert rm.query_range(13,25)==False
rm.remove_range(14,16)
assert rm.query_range(10,14)==True
assert rm.query_range(10,20)==False
print('✅ All tests passed!')
