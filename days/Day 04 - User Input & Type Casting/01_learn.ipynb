# %% [markdown]
# # Day 04 — User Input & Type Casting
#
# > `input()` always returns a string. Always.

# %% [markdown]
# ## The `input()` function
#
# `input()` pauses the program, waits for typing, returns what was typed — as a **string**.

# %%
name = input("What is your name? ")
print(f"Hello {name}!")

# %% [markdown]
# ## input() always returns a string
#
# ```python
# age = input("Age: ")   # returns "23" — a string
# age + 1               # ❌ TypeError
# int(age) + 1          # ✅ 24
# ```

# %%
# Always convert before doing math
age = int(input("Your age: "))
print(f"Next year you will be {age + 1}")

# %% [markdown]
# ## Integer division and modulo
#
# ```python
# 17 // 5   # → 3   (how many times 5 fits)
# 17 % 5    # → 2   (remainder)
# ```
#
# Use case — convert seconds to hours/minutes/seconds:

# %%
total = 3661
hours   = total // 3600
minutes = (total % 3600) // 60
seconds = total % 60
print(f"{hours}h {minutes}m {seconds}s")   # 1h 1m 1s

# %% [markdown]
# ## Safe conversion with try/except

# %%
def safe_int(value):
    try:
        return int(value)
    except ValueError:
        return None

print(safe_int("42"))    # 42
print(safe_int("hello")) # None
