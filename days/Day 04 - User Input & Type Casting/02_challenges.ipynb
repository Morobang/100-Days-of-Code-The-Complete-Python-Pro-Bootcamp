# %% [markdown]
# # Day 04 Challenges — User Input & Type Casting
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — BMI Calculator ⭐⭐
#
# Ask for weight (kg) and height (m). Print BMI = weight / height² rounded to 1dp.

# %%
weight = float(input('Weight (kg): '))
height = float(input('Height (m): '))
# write your solution

# %% [markdown]
# ## Challenge 2 — Seconds converter ⭐⭐
#
# Ask for a number of seconds. Print hours, minutes, seconds.
# ```
# 3661 → 1h 1m 1s
# ```

# %%
total = int(input('Enter seconds: '))
# write your solution

# %% [markdown]
# ## Challenge 3 — Name formatter ⭐⭐⭐
#
# Ask for first and last name separately.
# Print: `Full name: LAST, First`

# %%
# write your solution

# %% [markdown]
# ## ✅ Tests

# %%
def bmi(w, h): return round(w / h**2, 1)
assert bmi(70, 1.75) == 22.9
assert bmi(90, 1.80) == 27.8

def to_hms(s):
    return s//3600, (s%3600)//60, s%60
assert to_hms(3661) == (1, 1, 1)
assert to_hms(7200) == (2, 0, 0)
print('✅ Tests passed!')
