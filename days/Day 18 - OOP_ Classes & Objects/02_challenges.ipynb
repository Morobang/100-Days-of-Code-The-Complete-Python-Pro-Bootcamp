# %% [markdown]
# # Day 18 Challenges — OOP: Classes & Objects
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Student class ⭐⭐
#
# Build a `Student` class:
# - `__init__(name, student_id)`
# - `grades` list (start empty)
# - `add_grade(score)`
# - `average()` → 0 if no grades
# - `__str__` → `'Student(Rocket, ID:12345, avg:85.0)'`

# %%
class Student:
    def __init__(self, name: str, student_id: str):
        # write your solution
        pass

# %% [markdown]
# ## Challenge 2 — Counter class ⭐⭐
#
# Build a `Counter` with `increment(by=1)`, `decrement(by=1)`, `reset()`, and a `value` property.

# %%
class Counter:
    def __init__(self, start: int = 0):
        # write your solution
        pass

# %% [markdown]
# ## Challenge 3 — Temperature class ⭐⭐⭐
#
# Build `Temperature(celsius)` with:
# - `to_fahrenheit()`, `to_kelvin()`
# - `@classmethod from_fahrenheit(cls, f)`
# - `__str__` → `'37.0°C'`
# - `__eq__`, `__lt__` (enables sorting)

# %%
class Temperature:
    def __init__(self, celsius: float):
        # write your solution
        pass

# %% [markdown]
# ## ✅ Tests

# %%
s = Student('Rocket','12345')
assert s.average() == 0
s.add_grade(85); s.add_grade(90); s.add_grade(80)
assert s.average() == 85.0
assert '12345' in str(s) and 'Rocket' in str(s)

c = Counter()
c.increment(); c.increment(); c.increment(by=3)
assert c.value == 5
c.decrement(2); assert c.value == 3
c.reset(); assert c.value == 0

t = Temperature(100)
assert str(t) == '100.0°C'
assert t.to_fahrenheit() == 212.0
t2 = Temperature.from_fahrenheit(32)
assert t2.celsius == 0.0
assert Temperature(0) < Temperature(100)
print('✅ All tests passed!')
