# %% [markdown]
# # Day 49 Challenges — Advanced Sorting & Searching
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Quickselect kth smallest ⭐⭐
#
# Write `kth_smallest(lst, k)` using quickselect — O(n) average.

# %%
def kth_smallest(lst: list, k: int) -> int:
    pass

# %% [markdown]
# ## 2. Counting sort ⭐⭐
#
# Write `counting_sort(lst)` — sort non-negative integers using counting sort.

# %%
def counting_sort(lst: list) -> list:
    pass

# %% [markdown]
# ## 3. Dutch national flag ⭐⭐
#
# Write `sort_colors(lst)` — sort a list containing only 0s, 1s, and 2s in-place in one pass.
# ```
# sort_colors([2,0,2,1,1,0]) → [0,0,1,1,2,2]
# ```

# %%
def sort_colors(lst: list):
    pass

# %% [markdown]
# ## 4. Sort characters by frequency ⭐⭐
#
# Write `sort_by_freq(s)` — return characters sorted by frequency descending.
# ```
# sort_by_freq('tree') → 'eert' or 'eetr'
# ```

# %%
from collections import Counter
def sort_by_freq(s: str) -> str:
    pass

# %% [markdown]
# ## 5. Wiggle sort ⭐⭐
#
# Write `wiggle_sort(lst)` — rearrange so `lst[0]<=lst[1]>=lst[2]<=lst[3]...` in-place.

# %%
def wiggle_sort(lst: list):
    pass

# %% [markdown]
# ## 6. Top k frequent words ⭐⭐
#
# Write `top_k_words(words, k)` — return k most frequent words, sorted by freq desc then alpha.
# ```
# top_k_words(['i','love','code','i','love','coding'],2) → ['i','love']
# ```

# %%
from collections import Counter
def top_k_words(words: list, k: int) -> list:
    pass

# %% [markdown]
# ## 7. Find the kth largest in stream ⭐⭐⭐
#
# Implement `KthLargest(k, nums)` with `add(val)` — return kth largest after each add.

# %%
import heapq

class KthLargest:
    def __init__(self, k: int, nums: list):
        pass

    def add(self, val: int) -> int:
        pass

# %% [markdown]
# ## 8. Sort a nearly sorted array ⭐⭐
#
# Write `sort_k_sorted(lst, k)` — sort an array where each element is at most k positions away from its sorted position. O(n log k).

# %%
import heapq
def sort_k_sorted(lst: list, k: int) -> list:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert kth_smallest([3,2,1,5,6,4],2)==2
assert kth_smallest([3,2,3,1,2,4,5,5,6],4)==3

assert counting_sort([4,2,2,8,3,3,1])==[1,2,2,3,3,4,8]
assert counting_sort([])==[]

lst=[2,0,2,1,1,0]; sort_colors(lst)
assert lst==[0,0,1,1,2,2]

result=sort_by_freq('tree')
assert result.count('e')==2
assert result.index('e')<result.index('t') or result.index('e')<result.index('r')

lst2=[3,5,2,1,6,4]; wiggle_sort(lst2)
for i in range(1,len(lst2)):
    if i%2==1: assert lst2[i]>=lst2[i-1]
    else: assert lst2[i]<=lst2[i-1]

assert top_k_words(['i','love','code','i','love','coding'],2)==['i','love']

kl=KthLargest(3,[4,5,8,2])
assert kl.add(3)==4
assert kl.add(5)==5
assert kl.add(10)==5

assert sort_k_sorted([6,5,3,2,8,10,9],3)==[2,3,5,6,8,9,10]
print('✅ All tests passed!')
