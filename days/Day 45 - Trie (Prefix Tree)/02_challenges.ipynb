# %% [markdown]
# # Day 45 Challenges — Trie (Prefix Tree)
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Implement Trie ⭐⭐
#
# Implement `Trie` with `insert(word)`, `search(word)`, `starts_with(prefix)`.

# %%
class TrieNode:
    def __init__(self):
        self.children={}
        self.is_end=False

class Trie:
    def __init__(self):
        self.root=TrieNode()

    def insert(self, word: str):
        pass

    def search(self, word: str) -> bool:
        pass

    def starts_with(self, prefix: str) -> bool:
        pass

# %% [markdown]
# ## 2. Words with given prefix ⭐⭐
#
# Add `get_words_with_prefix(prefix)` to Trie — return all words starting with prefix.

# %%
# Add this method to your Trie class:
def get_words_with_prefix(self, prefix: str) -> list:
    pass

# %% [markdown]
# ## 3. Word search II ⭐⭐⭐
#
# Write `find_words(board, words)` — find all words from the list that exist in the board. Use a Trie for efficiency.

# %%
def find_words(board: list, words: list) -> list:
    pass

# %% [markdown]
# ## 4. Replace words ⭐⭐
#
# Write `replace_words(dictionary, sentence)` — replace words in sentence with their shortest root from the dictionary.
# ```
# replace_words(['cat','bat','rat'],'the cattle was rattled') → 'the cat was rat'
# ```

# %%
def replace_words(dictionary: list, sentence: str) -> str:
    pass

# %% [markdown]
# ## 5. Longest word in dictionary ⭐⭐
#
# Write `longest_word(words)` — find the longest word built one char at a time from other words in the list.

# %%
def longest_word(words: list) -> str:
    pass

# %% [markdown]
# ## 6. Count words with prefix ⭐
#
# Write `count_prefix(words, prefix)` — count how many words start with prefix.

# %%
def count_prefix(words: list, prefix: str) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
t=Trie()
t.insert('apple'); t.insert('app'); t.insert('banana')
assert t.search('apple')==True
assert t.search('app')==True
assert t.search('ap')==False
assert t.starts_with('app')==True
assert t.starts_with('ban')==True
assert t.starts_with('xyz')==False

result=replace_words(['cat','bat','rat'],'the cattle was rattled')
assert result=='the cat was rat'

assert longest_word(['w','wo','wor','worl','world'])=='world'

words=['apple','app','application','apply','banana']
assert count_prefix(words,'app')==3
print('✅ All tests passed!')
