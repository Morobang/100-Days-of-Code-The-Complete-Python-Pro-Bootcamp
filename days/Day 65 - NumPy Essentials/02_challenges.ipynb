# %% [markdown]
# # Day 65 Challenges — NumPy Essentials
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Array creation ⭐
#
# Write `create_arrays()` — create: zeros(3x4), ones(2x3), identity(4x4), linspace(0,1,10), arange(0,20,2).

# %%
import numpy as np

def create_arrays():
    pass

# %% [markdown]
# ## 2. Array operations ⭐⭐
#
# Write `array_stats(arr)` — return dict with mean, std, min, max, sum for a 2D array (computed along axis=0).

# %%
def array_stats(arr):
    pass

# %% [markdown]
# ## 3. Broadcasting ⭐⭐
#
# Write `normalise(matrix)` — subtract the mean of each column and divide by its std (z-score normalisation).

# %%
def normalise(matrix):
    pass

# %% [markdown]
# ## 4. Boolean indexing ⭐⭐
#
# Write `replace_negatives(arr, fill=0)` — replace all negative values with fill using boolean indexing.

# %%
def replace_negatives(arr, fill=0):
    pass

# %% [markdown]
# ## 5. Matrix operations ⭐⭐
#
# Write `matrix_ops(A, B)` — return dict with: dot product, element-wise multiply, A transposed, A inverse (if square).

# %%
def matrix_ops(A, B):
    pass

# %% [markdown]
# ## 6. Vectorised function ⭐⭐⭐
#
# Write `batch_bmi(weights, heights)` — compute BMI for arrays of weights/heights without any Python loops.

# %%
def batch_bmi(weights, heights):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
print('Run each challenge cell — check output manually')
print('✅ Complete!')
