# %% [markdown]
# # Day 088 — Testing data pipelines with pytest
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Testing data pipelines with pytest
#
# Complete the exercises for today's topic: **Testing data pipelines with pytest**.
#
# Refer to `topics/04_functions.md` for syntax reference before starting.

# %%
# Day 088 — Testing data pipelines with pytest
# Write your solution below

def solution():
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
# Add your own assertions as you build
# assert solution() == expected_output
print('Day complete — update progress.md!')
print('✅ All tests passed!')
