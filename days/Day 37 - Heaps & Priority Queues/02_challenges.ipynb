# %% [markdown]
# # Day 37 Challenges — Heaps & Priority Queues
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Kth largest element ⭐⭐
#
# Write `kth_largest(lst, k)` — return the kth largest element. O(n log k).

# %%
import heapq
def kth_largest(lst: list, k: int) -> int:
    pass

# %% [markdown]
# ## 2. Kth smallest element ⭐⭐
#
# Write `kth_smallest(lst, k)` — return the kth smallest element.

# %%
import heapq
def kth_smallest(lst: list, k: int) -> int:
    pass

# %% [markdown]
# ## 3. K closest points to origin ⭐⭐
#
# Write `k_closest(points, k)` — return k points closest to origin (0,0).
# ```
# k_closest([[1,3],[-2,2]],1) → [[-2,2]]
# ```

# %%
import heapq
def k_closest(points: list, k: int) -> list:
    pass

# %% [markdown]
# ## 4. Top k frequent elements ⭐⭐
#
# Write `top_k_frequent(lst, k)` — return k most frequent elements.
# ```
# top_k_frequent([1,1,1,2,2,3],2) → [1,2]
# ```

# %%
import heapq
from collections import Counter
def top_k_frequent(lst: list, k: int) -> list:
    pass

# %% [markdown]
# ## 5. Merge k sorted lists ⭐⭐⭐
#
# Write `merge_k_sorted(lists)` — merge k sorted lists into one sorted list.
# ```
# merge_k_sorted([[1,4,5],[1,3,4],[2,6]]) → [1,1,2,3,4,4,5,6]
# ```

# %%
import heapq
def merge_k_sorted(lists: list) -> list:
    pass

# %% [markdown]
# ## 6. Find median from data stream ⭐⭐⭐
#
# Write `MedianFinder` class with `add_num(n)` and `find_median()` — median of all numbers seen so far.

# %%
import heapq

class MedianFinder:
    def __init__(self):
        self.low = []   # max-heap (negate)
        self.high = []  # min-heap

    def add_num(self, num: int):
        pass

    def find_median(self) -> float:
        pass

# %% [markdown]
# ## 7. Task scheduler ⭐⭐⭐
#
# Write `least_interval(tasks, n)` — minimum intervals to execute all tasks with cooldown n between same tasks.
# ```
# least_interval(['A','A','A','B','B','B'],2) → 8
# ```

# %%
from collections import Counter
def least_interval(tasks: list, n: int) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert kth_largest([3,2,1,5,6,4],2)==5
assert kth_largest([3,2,3,1,2,4,5,5,6],4)==4

assert kth_smallest([3,2,1,5,6,4],2)==2

result=k_closest([[1,3],[-2,2]],1)
assert result==[[-2,2]]

assert sorted(top_k_frequent([1,1,1,2,2,3],2))==[1,2]

assert merge_k_sorted([[1,4,5],[1,3,4],[2,6]])==[1,1,2,3,4,4,5,6]

mf=MedianFinder()
mf.add_num(1);mf.add_num(2)
assert mf.find_median()==1.5
mf.add_num(3)
assert mf.find_median()==2.0

assert least_interval(['A','A','A','B','B','B'],2)==8
print('✅ All tests passed!')
