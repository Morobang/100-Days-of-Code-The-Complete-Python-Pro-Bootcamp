# %% [markdown]
# # Day 02 Challenges — Variables & Data Types
#
# > Write your solution in each cell, then run the test cell at the end.

# %% [markdown]
# ## Challenge 1 — Your player card ⭐
#
# Create variables for: `name` (str), `age` (int), `win_rate` (float), `is_ranked` (bool).
# Print each with its type: `name is a <class 'str'>`.

# %%
# write your solution
name = "Rocket"
age = 26
win_rate = 23.6
is_ranked = True

print(f"name is {type(name)}")
print(f"age is {type(age)}")
print(f"win_rate is {type(win_rate)}")
print(f"is_ranked is {type(is_ranked)}")
# Out:
# name is <class 'str'>
# age is <class 'int'>
# win_rate is <class 'float'>
# is_ranked is <class 'bool'>

# %% [markdown]
# ## Challenge 2 — Type conversion ⭐⭐
#
# The variable `score = "9500"` is a string.
# Convert it to an int, add a 500 bonus, then print `'Final score: 10000'`.

# %%
score = "9500"
# write your solution
Final_score = int(score) + 500
print(f"'Final_score: {Final_score}'")
# Out:
# 'Final_score: 10000'

# %% [markdown]
# ## Challenge 3 — Predict the output ⭐⭐
#
# Before running, predict what each line prints. Write your prediction as a comment.
# Then run and check.

# %%
x = "3"
y = 3
z = int(3.9)
w = bool("False")

# Prediction: type(x) = ?
# Prediction: type(z) = ? and z = ?
# Prediction: w = ?

print(type(x), type(y), type(z), type(w))
print(z, w)
# Out:
# <class 'str'> <class 'int'> <class 'int'> <class 'bool'>
# 3 True

# %% [markdown]
# ## Challenge 4 — Swap ⭐⭐⭐
#
# Given `a = 'PS5'` and `b = 'Xbox'`, swap their values **without** using a third variable.
# Print both before and after.

# %%
a = 'PS5'
b = 'Xbox'
# write your solution
a , b = b , a

print(a)
print(b)
# Out:
# Xbox
# PS5

# %% [markdown]
# ## ✅ Tests

# %%
score = '9500'
final = int(score) + 500
assert final == 10000, f'Expected 10000, got {final}'
assert type(final) == int

a, b = 'PS5', 'Xbox'
a, b = b, a
assert a == 'Xbox' and b == 'PS5'

# The bool('False') surprise:
assert bool("False") == True   # non-empty string = truthy!

print('✅ All tests passed!')
# Out:
# ✅ All tests passed!
