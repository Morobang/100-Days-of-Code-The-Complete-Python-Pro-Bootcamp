# %% [markdown]
# # Day 60 Challenges — Hard Interview Problems II
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Buy/sell stock with k transactions ⭐⭐⭐
#
# Write `max_profit_k(k, prices)` — max profit with at most k buy-sell transactions.

# %%
def max_profit_k(k, prices):
    pass

# %% [markdown]
# ## 2. Regular expression matching ⭐⭐⭐
#
# Write `regex_match(s, p)` — match where `.` matches any char and `*` matches zero or more of the preceding.
# ```
# regex_match('aa','a*') → True
# regex_match('ab','.*') → True
# ```

# %%
def regex_match(s, p):
    pass

# %% [markdown]
# ## 3. Maximum sum rectangle ⭐⭐⭐
#
# Write `max_sum_rectangle(matrix)` — find the rectangle in the matrix with the maximum sum.

# %%
def max_sum_rectangle(matrix):
    pass

# %% [markdown]
# ## 4. Number of ways to decode ⭐⭐⭐
#
# Write `num_decodings(s)` — number of ways to decode a digit string where A=1..Z=26.

# %%
def num_decodings(s):
    pass

# %% [markdown]
# ## 5. Critical connections ⭐⭐⭐
#
# Write `critical_connections(n, connections)` — find all bridges (removing them disconnects graph).

# %%
from collections import defaultdict

def critical_connections(n, connections):
    pass

# %% [markdown]
# ## 6. Longest increasing path matrix ⭐⭐⭐
#
# Write `longest_increasing_path(matrix)` — length of longest strictly increasing path in matrix (4 directions).

# %%
def longest_increasing_path(matrix):
    pass

# %% [markdown]
# ## 7. Count of range sum ⭐⭐⭐
#
# Write `count_range_sum(nums, lower, upper)` — count pairs (i,j) where lower <= sum(nums[i..j]) <= upper.

# %%
def count_range_sum(nums, lower, upper):
    pass

# %% [markdown]
# ## 8. Burst balloons ⭐⭐⭐
#
# Write `max_coins(nums)` — burst all balloons to maximise coins. Bursting i gives nums[i-1]*nums[i]*nums[i+1].

# %%
def max_coins(nums):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert max_profit_k(2,[3,2,6,5,0,3])==7
assert max_profit_k(2,[1,2,3,4,5])==4

assert regex_match('aa','a*')==True
assert regex_match('ab','.*')==True
assert regex_match('aab','c*a*b')==True
assert regex_match('mississippi','mis*is*p*.')==False

assert num_decodings('12')==2
assert num_decodings('226')==3
assert num_decodings('06')==0

n=4; conns=[[0,1],[1,2],[2,0],[1,3]]
bridges=critical_connections(n,conns)
assert [1,3] in bridges or [3,1] in bridges

matrix=[[9,9,4],[6,6,8],[2,1,1]]
assert longest_increasing_path(matrix)==4

assert max_coins([3,1,5,8])==167
assert max_coins([1,5])==10
print('✅ All tests passed!')
