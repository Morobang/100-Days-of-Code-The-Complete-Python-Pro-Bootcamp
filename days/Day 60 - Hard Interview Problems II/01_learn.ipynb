# %% [markdown]
# # Day 60 — Hard Interview Problems II
#
# > Final hard problem day. Build your confidence here.

# %% [markdown]
# ## Reminder: The approach
#
# For every problem:
# 1. State the brute force
# 2. State the optimised approach and why it works
# 3. Code it
# 4. Walk through with an example
# 5. Discuss edge cases
