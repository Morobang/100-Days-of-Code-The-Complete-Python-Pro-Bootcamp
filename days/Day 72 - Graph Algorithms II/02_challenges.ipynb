# %% [markdown]
# # Day 72 Challenges — Graph Algorithms II
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.

# %% [markdown]
# ## 1. Dijkstra shortest path ⭐⭐⭐
#
# Write `dijkstra(graph, start)` — return shortest distances from start to all reachable nodes.

# %%
import heapq

def dijkstra(graph, start):
    pass

# %% [markdown]
# ## 2. Shortest path between two nodes ⭐⭐
#
# Write `shortest_path(graph, start, end)` — return (distance, path) between start and end.

# %%
import heapq

def shortest_path(graph, start, end):
    pass

# %% [markdown]
# ## 3. Union-Find ⭐⭐
#
# Implement `UnionFind(n)` with `find(x)` and `union(x,y)` — path compression and union by rank.

# %%
class UnionFind:
    def __init__(self, n):
        self.parent=list(range(n))
        self.rank=[0]*n

    def find(self, x):
        pass

    def union(self, x, y):
        pass

# %% [markdown]
# ## 4. Kruskal's MST ⭐⭐⭐
#
# Write `kruskal(n, edges)` — find minimum spanning tree. Edges: (weight, u, v).

# %%
def kruskal(n, edges):
    pass

# %% [markdown]
# ## 5. Network delay time ⭐⭐⭐
#
# Write `network_delay(times, n, k)` — min time for signal from k to reach ALL nodes. -1 if impossible.
# ```
# network_delay([[2,1,1],[2,3,1],[3,4,1]],4,2) → 2
# ```

# %%
import heapq

def network_delay(times, n, k):
    pass

# %% [markdown]
# ## 6. Cheapest flights with k stops ⭐⭐⭐
#
# Write `cheapest_flights(n, flights, src, dst, k)` — cheapest price from src to dst with at most k stops.

# %%
from collections import defaultdict

def cheapest_flights(n, flights, src, dst, k):
    pass

# %% [markdown]
# ## 7. Course schedule (cycle detection) ⭐⭐
#
# Write `can_finish(n_courses, prerequisites)` — True if all courses can be completed (no cycles).

# %%
from collections import defaultdict, deque

def can_finish(n_courses, prerequisites):
    pass

# %% [markdown]
# ## 8. Reconstruct itinerary ⭐⭐⭐
#
# Write `find_itinerary(tickets)` — reconstruct flight itinerary starting from JFK. Use each ticket once, return lexicographically smallest.
# ```
# find_itinerary([['JFK','SFO'],['JFK','ATL'],['SFO','ATL']]) → ['JFK','ATL','JFK','SFO','ATL']
# ```

# %%
from collections import defaultdict

def find_itinerary(tickets):
    pass

# %% [markdown]
# ## ✅ Tests

# %%
g={'A':[('B',4),('C',2)],'B':[('D',5)],'C':[('B',1),('D',8)],'D':[]}
dist=dijkstra(g,'A')
assert dist['A']==0
assert dist['B']==3  # A->C->B: 2+1
assert dist['D']==8  # A->C->B->D: 2+1+5

uf=UnionFind(5)
uf.union(0,1); uf.union(1,2)
assert uf.find(0)==uf.find(2)
assert uf.find(3)!=uf.find(0)

edges=[(1,0,1),(2,0,2),(3,1,2),(4,2,3)]
mst=kruskal(4,edges)
assert sum(w for w,u,v in mst)==6
assert len(mst)==3

assert network_delay([[2,1,1],[2,3,1],[3,4,1]],4,2)==2
assert network_delay([[1,2,1]],2,2)==-1

assert can_finish(2,[[1,0]])==True
assert can_finish(2,[[1,0],[0,1]])==False

result=find_itinerary([['MUC','LHR'],['JFK','MUC'],['SFO','SJC'],['LHR','SFO']])
assert result[0]=='JFK'
print('✅ All tests passed!')
