# %% [markdown]
# # Day 21 Challenges — Recursion
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Sum of list ⭐
#
# Write `rsum(lst)` — sum a list using recursion. No `sum()` built-in.

# %%
def rsum(lst: list) -> int:
    pass

# %% [markdown]
# ## 2. Power ⭐
#
# Write `power(base, exp)` — compute `base ** exp` recursively.

# %%
def power(base, exp: int) -> float:
    pass

# %% [markdown]
# ## 3. Reverse a string ⭐
#
# Write `reverse(s)` — reverse a string recursively. No slicing shortcut.

# %%
def reverse(s: str) -> str:
    pass

# %% [markdown]
# ## 4. Count occurrences ⭐⭐
#
# Write `count(lst, target)` — count how many times `target` appears in `lst` recursively.

# %%
def count(lst: list, target) -> int:
    pass

# %% [markdown]
# ## 5. Fibonacci ⭐⭐
#
# Write `fib(n)` with memoization so `fib(50)` runs instantly.

# %%
from functools import lru_cache

@lru_cache(maxsize=None)
def fib(n: int) -> int:
    pass

# %% [markdown]
# ## 6. Deep flatten ⭐⭐
#
# Write `flatten(lst)` — flatten any depth of nesting.
# ```
# flatten([1,[2,[3,[4]]]]) → [1,2,3,4]
# ```

# %%
def flatten(lst: list) -> list:
    pass

# %% [markdown]
# ## 7. Binary search (recursive) ⭐⭐⭐
#
# Write `binary_search(lst, target, lo=0, hi=None)` — return index or -1.

# %%
def binary_search(lst, target, lo=0, hi=None):
    if hi is None: hi = len(lst) - 1
    # write your solution
    pass

# %% [markdown]
# ## 8. Tower of Hanoi ⭐⭐⭐
#
# Write `hanoi(n, source, target, auxiliary)` — print all moves to move n disks.
# ```
# hanoi(2,'A','C','B') →
# Move disk 1 from A to B
# Move disk 2 from A to C
# Move disk 1 from B to C
# ```

# %%
def hanoi(n, source, target, auxiliary):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert rsum([1,2,3,4,5]) == 15
assert rsum([]) == 0
assert power(2,10) == 1024
assert power(3,0) == 1
assert reverse('hello') == 'olleh'
assert reverse('a') == 'a'
assert count([1,2,1,3,1],1) == 3
assert count([],5) == 0
assert fib(0)==0 and fib(1)==1 and fib(10)==55
assert fib(50) == 12586269025
assert flatten([1,[2,[3,[4]]]]) == [1,2,3,4]
assert flatten([1,2,3]) == [1,2,3]
lst = list(range(1,21))
assert binary_search(lst,7) == 6
assert binary_search(lst,99) == -1
print('✅ All tests passed!')
