# %% [markdown]
# # Day 46 Challenges — Interval Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Merge intervals ⭐⭐
#
# Write `merge_intervals(intervals)` — merge all overlapping intervals.

# %%
def merge_intervals(intervals: list) -> list:
    pass

# %% [markdown]
# ## 2. Insert interval ⭐⭐
#
# Write `insert_interval(intervals, new)` — insert new interval into sorted non-overlapping list and merge.

# %%
def insert_interval(intervals: list, new: list) -> list:
    pass

# %% [markdown]
# ## 3. Interval intersection ⭐⭐
#
# Write `interval_intersection(a, b)` — return intersection of two sorted interval lists.

# %%
def interval_intersection(a: list, b: list) -> list:
    pass

# %% [markdown]
# ## 4. Non-overlapping count ⭐⭐
#
# Write `count_non_overlapping(intervals)` — count max number of non-overlapping intervals.

# %%
def count_non_overlapping(intervals: list) -> int:
    pass

# %% [markdown]
# ## 5. Meeting schedule ⭐⭐
#
# Write `free_slots(busy_times, day_start, day_end)` — find all free time slots.

# %%
def free_slots(busy_times: list, day_start: int, day_end: int) -> list:
    pass

# %% [markdown]
# ## 6. Employee free time ⭐⭐⭐
#
# Write `employee_free_time(schedules)` — given schedules as list of list of intervals, find all free time common to everyone.

# %%
def employee_free_time(schedules: list) -> list:
    pass

# %% [markdown]
# ## 7. Minimum interval to include query ⭐⭐⭐
#
# Write `min_interval(intervals, queries)` — for each query, find the size of smallest interval containing it.
# ```
# min_interval([[1,4],[2,4],[3,6],[4,4]],[2,3,4,5]) → [3,3,1,4]
# ```

# %%
import heapq
def min_interval(intervals: list, queries: list) -> list:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert merge_intervals([[1,3],[2,6],[8,10],[15,18]])==[[1,6],[8,10],[15,18]]
assert merge_intervals([[1,4],[4,5]])==[[1,5]]

assert insert_interval([[1,3],[6,9]],[2,5])==[[1,5],[6,9]]
assert insert_interval([[1,2],[3,5],[6,7],[8,10],[12,16]],[4,8])==[[1,2],[3,10],[12,16]]

a=[[0,2],[5,10],[13,23],[24,25]]
b=[[1,5],[8,12],[15,24],[25,26]]
assert interval_intersection(a,b)==[[1,2],[5,5],[8,10],[15,23],[24,24],[25,25]]

assert count_non_overlapping([[1,2],[2,3],[3,4],[1,3]])==3

fs=free_slots([[9,12],[13,15]],9,17)
assert [12,13] in fs

assert min_interval([[1,4],[2,4],[3,6],[4,4]],[2,3,4,5])==[3,3,1,4]
print('✅ All tests passed!')
