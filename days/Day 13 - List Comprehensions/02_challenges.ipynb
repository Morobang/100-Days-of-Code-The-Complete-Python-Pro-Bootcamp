# %% [markdown]
# # Day 13 Challenges — List Comprehensions
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — Filtered Celsius to Fahrenheit ⭐⭐
#
# Given a list of Celsius temps, use a comprehension to get Fahrenheit values above 100°F.
# Formula: `F = C * 9/5 + 32`

# %%
celsius = [0, 50, 100, 25, 37, 200, -10]
# write your solution — result should be a list of floats above 100

# %% [markdown]
# ## Challenge 2 — Count chars ⭐⭐
#
# Write `count_chars(s)` using a dict comprehension.
# ```
# count_chars('hello') → {'h':1,'e':1,'l':2,'o':1}
# ```

# %%
def count_chars(s: str) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 3 — Flatten & deduplicate ⭐⭐⭐
#
# Write `unique_flatten(lst_of_lsts)` — flatten and return only unique values preserving first-seen order.
# ```
# unique_flatten([[1,2,3],[2,3,4],[3,4,5]]) → [1,2,3,4,5]
# ```

# %%
def unique_flatten(lst_of_lsts: list) -> list:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests

# %%
celsius = [0, 50, 100, 25, 37, 200, -10]
hot = [round(c*9/5+32,1) for c in celsius if c*9/5+32 > 100]
assert 212.0 in hot
assert 32.0 not in hot

assert count_chars('hello') == {'h':1,'e':1,'l':2,'o':1}

assert unique_flatten([[1,2,3],[2,3,4],[3,4,5]]) == [1,2,3,4,5]
print('✅ All tests passed!')
