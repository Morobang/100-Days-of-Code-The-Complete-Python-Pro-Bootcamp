# %% [markdown]
# # Day 38 Challenges — Searching & Binary Search
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Classic binary search ⭐
#
# Write `binary_search(lst, target)` — return index or -1.

# %%
def binary_search(lst: list, target: int) -> int:
    pass

# %% [markdown]
# ## 2. Find first and last position ⭐⭐
#
# Write `search_range(lst, target)` — return (first, last) index of target, or (-1,-1) if not found.
# ```
# search_range([5,7,7,8,8,10],8) → (3,4)
# ```

# %%
def search_range(lst: list, target: int) -> tuple:
    pass

# %% [markdown]
# ## 3. Search in rotated sorted array ⭐⭐
#
# Write `search_rotated(lst, target)` — binary search in a rotated sorted array.
# ```
# search_rotated([4,5,6,7,0,1,2],0) → 4
# ```

# %%
def search_rotated(lst: list, target: int) -> int:
    pass

# %% [markdown]
# ## 4. Find minimum in rotated array ⭐⭐
#
# Write `find_min_rotated(lst)` — find minimum in a rotated sorted array.

# %%
def find_min_rotated(lst: list) -> int:
    pass

# %% [markdown]
# ## 5. Guess number higher or lower ⭐
#
# Write `guess_game(secret, n)` — simulate the guess game. Return number of guesses to find secret in range 1..n.

# %%
def guess_game(secret: int, n: int) -> int:
    pass

# %% [markdown]
# ## 6. Find peak element ⭐⭐
#
# Write `find_peak(lst)` — return index of a peak element (greater than neighbors). O(log n).

# %%
def find_peak(lst: list) -> int:
    pass

# %% [markdown]
# ## 7. Median of two sorted arrays ⭐⭐⭐
#
# Write `median_sorted_arrays(a, b)` — find the median of two sorted arrays. O(log(min(m,n))).

# %%
def median_sorted_arrays(a: list, b: list) -> float:
    pass

# %% [markdown]
# ## 8. Koko eating bananas ⭐⭐⭐
#
# Write `min_eating_speed(piles, h)` — minimum bananas per hour so Koko eats all in h hours.
# ```
# min_eating_speed([3,6,7,11],8) → 4
# ```

# %%
import math
def min_eating_speed(piles: list, h: int) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert binary_search([1,3,5,7,9],7)==3
assert binary_search([1,3,5,7,9],4)==-1

assert search_range([5,7,7,8,8,10],8)==(3,4)
assert search_range([5,7,7,8,8,10],6)==(-1,-1)

assert search_rotated([4,5,6,7,0,1,2],0)==4
assert search_rotated([4,5,6,7,0,1,2],3)==-1

assert find_min_rotated([3,4,5,1,2])==1
assert find_min_rotated([4,5,6,7,0,1,2])==0

assert guess_game(6,10)<=10

peak=find_peak([1,2,3,1])
assert peak==2

assert median_sorted_arrays([1,3],[2])==2.0
assert median_sorted_arrays([1,2],[3,4])==2.5

assert min_eating_speed([3,6,7,11],8)==4
assert min_eating_speed([30,11,23,4,20],5)==30
print('✅ All tests passed!')
