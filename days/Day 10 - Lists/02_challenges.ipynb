# %% [markdown]
# # Day 10 Challenges — Lists
#
# > Attempt every exercise before running the test cell.

# %% [markdown]
# ## Challenge 1 — List stats ⭐
#
# Write `stats(numbers)` → dict with `min`, `max`, `sum`, `average` (2dp).

# %%
def stats(numbers: list) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 2 — Remove duplicates ⭐⭐
#
# Write `unique(lst)` — remove duplicates preserving order. No `set()` shortcut.

# %%
def unique(lst: list) -> list:
    # write your solution
    pass

# %% [markdown]
# ## Challenge 3 — Rotate list ⭐⭐⭐
#
# Write `rotate(lst, n)` — rotate right by n positions.
# ```
# rotate([1,2,3,4,5], 2) → [4,5,1,2,3]
# ```

# %%
def rotate(lst: list, n: int) -> list:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests

# %%
s = stats([10, 20, 30, 40])
assert s['min'] == 10
assert s['max'] == 40
assert s['sum'] == 100
assert s['average'] == 25.0

assert unique([1,2,2,3,1,4]) == [1,2,3,4]
assert unique(['a','b','a']) == ['a','b']

assert rotate([1,2,3,4,5], 2) == [4,5,1,2,3]
assert rotate([1,2,3], 1) == [3,1,2]
assert rotate([1,2,3], 0) == [1,2,3]
print('✅ All tests passed!')
