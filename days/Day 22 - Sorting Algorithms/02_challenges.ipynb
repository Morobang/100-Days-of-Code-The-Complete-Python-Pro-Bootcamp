# %% [markdown]
# # Day 22 Challenges — Sorting Algorithms
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Bubble sort ⭐⭐
#
# Implement `bubble_sort(lst)` — sort a list in ascending order in-place.

# %%
def bubble_sort(lst: list) -> list:
    pass

# %% [markdown]
# ## 2. Selection sort ⭐⭐
#
# Implement `selection_sort(lst)` — find the minimum each pass and place it at the front.

# %%
def selection_sort(lst: list) -> list:
    pass

# %% [markdown]
# ## 3. Insertion sort ⭐⭐
#
# Implement `insertion_sort(lst)` — build sorted portion one element at a time.

# %%
def insertion_sort(lst: list) -> list:
    pass

# %% [markdown]
# ## 4. Merge two sorted lists ⭐⭐
#
# Write `merge_sorted(a, b)` — merge two already-sorted lists into one sorted list.

# %%
def merge_sorted(a: list, b: list) -> list:
    pass

# %% [markdown]
# ## 5. Merge sort ⭐⭐⭐
#
# Implement `merge_sort(lst)` — divide and conquer, O(n log n).

# %%
def merge_sort(lst: list) -> list:
    pass

# %% [markdown]
# ## 6. Sort by multiple keys ⭐⭐
#
# Write `sort_players(players)` — sort a list of `(name, score, level)` tuples by score descending, then by name ascending on tie.

# %%
def sort_players(players: list) -> list:
    pass

# %% [markdown]
# ## 7. Count inversions ⭐⭐⭐
#
# Write `count_inversions(lst)` — count pairs `(i,j)` where `i<j` but `lst[i]>lst[j]`.
# ```
# count_inversions([3,1,2]) → 2
# ```

# %%
def count_inversions(lst: list) -> int:
    pass

# %% [markdown]
# ## 8. Is sorted? ⭐
#
# Write `is_sorted(lst, reverse=False)` — return True if list is sorted.

# %%
def is_sorted(lst: list, reverse: bool = False) -> bool:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
import random
def check(fn, lst):
    result = fn(lst[:])
    return result == sorted(lst)

test_cases = [[64,34,25,12],[1],[],[5,4,3,2,1],[1,1,1]]
for tc in test_cases:
    assert check(bubble_sort,tc), f'bubble_sort failed on {tc}'
    assert check(selection_sort,tc), f'selection_sort failed on {tc}'
    assert check(insertion_sort,tc), f'insertion_sort failed on {tc}'
    assert check(merge_sort,tc), f'merge_sort failed on {tc}'

assert merge_sorted([1,3,5],[2,4,6]) == [1,2,3,4,5,6]
assert merge_sorted([],[1,2]) == [1,2]

players=[('Bob',90,5),('Alice',90,3),('Eve',95,2)]
sp = sort_players(players)
assert sp[0][0]=='Eve'
assert sp[1][0]=='Alice'  # same score, alphabetical

assert count_inversions([3,1,2]) == 2
assert count_inversions([1,2,3]) == 0

assert is_sorted([1,2,3]) == True
assert is_sorted([3,2,1], reverse=True) == True
assert is_sorted([1,3,2]) == False
print('✅ All tests passed!')
