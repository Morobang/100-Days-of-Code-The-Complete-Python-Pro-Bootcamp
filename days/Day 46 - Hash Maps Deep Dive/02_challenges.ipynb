# %% [markdown]
# # Day 46 Challenges — Hash Maps Deep Dive
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Design HashMap ⭐⭐
#
# Implement `MyHashMap` with `put(key, val)`, `get(key)` → val or -1, `remove(key)`.
# Use chaining for collision resolution.

# %%
class MyHashMap:
    def __init__(self):
        self.capacity = 1000
        self.buckets = [[] for _ in range(self.capacity)]

    def _hash(self, key): return key % self.capacity

    def put(self, key, val):
        pass

    def get(self, key) -> int:
        pass

    def remove(self, key):
        pass

# %% [markdown]
# ## 2. Design HashSet ⭐⭐
#
# Implement `MyHashSet` with `add(key)`, `contains(key)` → bool, `remove(key)`.

# %%
class MyHashSet:
    def __init__(self):
        self.capacity = 1000
        self.buckets = [[] for _ in range(self.capacity)]

    def _hash(self, key): return key % self.capacity

    def add(self, key): pass
    def contains(self, key) -> bool: pass
    def remove(self, key): pass

# %% [markdown]
# ## 3. LRU Cache (full) ⭐⭐⭐
#
# Implement `LRUCache(capacity)` with `get(key)` and `put(key,val)` both O(1).
# Use a doubly linked list + hash map.

# %%
class LRUCache:
    def __init__(self, capacity: int):
        pass

    def get(self, key: int) -> int:
        pass

    def put(self, key: int, value: int):
        pass

# %% [markdown]
# ## 4. Isomorphic strings ⭐
#
# Write `is_isomorphic(s, t)` — True if s and t have the same structure.
# ```
# is_isomorphic('egg','add') → True
# is_isomorphic('foo','bar') → False
# ```

# %%
def is_isomorphic(s: str, t: str) -> bool:
    pass

# %% [markdown]
# ## 5. Word pattern ⭐
#
# Write `word_pattern(pattern, s)` — True if s follows the pattern.
# ```
# word_pattern('abba','dog cat cat dog') → True
# ```

# %%
def word_pattern(pattern: str, s: str) -> bool:
    pass

# %% [markdown]
# ## 6. Longest consecutive sequence ⭐⭐
#
# Write `longest_consecutive(lst)` — O(n) solution using a hash set.
# ```
# longest_consecutive([100,4,200,1,3,2]) → 4
# ```

# %%
def longest_consecutive(lst: list) -> int:
    pass

# %% [markdown]
# ## 7. Ransom note ⭐
#
# Write `can_construct(ransom, magazine)` — True if ransom can be built from magazine letters.

# %%
def can_construct(ransom: str, magazine: str) -> bool:
    pass

# %% [markdown]
# ## 8. Subarray sum equals k ⭐⭐
#
# Write `subarray_sum(lst, k)` — count subarrays that sum to k. O(n).

# %%
def subarray_sum(lst: list, k: int) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
hm=MyHashMap()
hm.put(1,1); hm.put(2,2)
assert hm.get(1)==1
assert hm.get(3)==-1
hm.put(2,1)
assert hm.get(2)==1
hm.remove(2)
assert hm.get(2)==-1

hs=MyHashSet()
hs.add(1); hs.add(2)
assert hs.contains(1)==True
assert hs.contains(3)==False
hs.remove(2)
assert hs.contains(2)==False

lru=LRUCache(2)
lru.put(1,1); lru.put(2,2)
assert lru.get(1)==1
lru.put(3,3)
assert lru.get(2)==-1

assert is_isomorphic('egg','add')==True
assert is_isomorphic('foo','bar')==False

assert word_pattern('abba','dog cat cat dog')==True
assert word_pattern('abba','dog cat cat fish')==False

assert longest_consecutive([100,4,200,1,3,2])==4

assert can_construct('aa','aab')==True
assert can_construct('aa','ab')==False

assert subarray_sum([1,1,1],2)==2
assert subarray_sum([1,2,3],3)==2
print('✅ All tests passed!')
