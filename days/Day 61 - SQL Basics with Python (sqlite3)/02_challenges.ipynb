# %% [markdown]
# # Day 61 Challenges — SQL Basics with Python (sqlite3)
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Create and insert ⭐
#
# Create an in-memory SQLite DB with a `games` table (id, title, genre, price). Insert 5 games.

# %%
import sqlite3

def setup_db():
    conn=sqlite3.connect(':memory:')
    cur=conn.cursor()
    # write your solution
    return conn

# %% [markdown]
# ## 2. Query and filter ⭐
#
# Write `get_games_by_genre(conn, genre)` — return games matching genre.

# %%
def get_games_by_genre(conn, genre):
    pass

# %% [markdown]
# ## 3. Update and delete ⭐⭐
#
# Write `update_price(conn, title, new_price)` and `delete_game(conn, title)`.

# %%
def update_price(conn, title, new_price):
    pass

def delete_game(conn, title):
    pass

# %% [markdown]
# ## 4. Aggregation queries ⭐⭐
#
# Write `genre_stats(conn)` — return (genre, count, avg_price) per genre, ordered by count desc.

# %%
def genre_stats(conn):
    pass

# %% [markdown]
# ## 5. Search safely ⭐⭐
#
# Write `search_games(conn, keyword)` — search games where title LIKE keyword. Use parameterised query.

# %%
def search_games(conn, keyword):
    pass

# %% [markdown]
# ## 6. Context manager for DB ⭐⭐⭐
#
# Write `database(filepath)` context manager — opens connection, yields cursor, commits or rollbacks.

# %%
from contextlib import contextmanager
import sqlite3

@contextmanager
def database(filepath):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
conn=setup_db()
results=get_games_by_genre(conn,'Fighting')
assert len(results)>0

update_price(conn,'Tekken 8',999)
cur=conn.cursor()
cur.execute('SELECT price FROM games WHERE title=?',('Tekken 8',))
row=cur.fetchone()
assert row[0]==999

print('✅ Tests passed!')
