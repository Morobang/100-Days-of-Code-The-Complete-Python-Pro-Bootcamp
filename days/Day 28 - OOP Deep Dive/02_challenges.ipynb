# %% [markdown]
# # Day 28 Challenges — OOP Deep Dive
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Stack class ⭐⭐
#
# Build a `Stack` class with `push(item)`, `pop()`, `peek()`, `is_empty()`, `size()`.
# Raise `IndexError` on pop/peek from empty stack.
# `__str__` → `'Stack([1,2,3])'`

# %%
class Stack:
    def __init__(self):
        self._data = []
    # write all methods

# %% [markdown]
# ## 2. Queue class ⭐⭐
#
# Build a `Queue` with `enqueue(item)`, `dequeue()`, `front()`, `is_empty()`, `size()`.

# %%
class Queue:
    def __init__(self):
        self._data = []
    # write all methods

# %% [markdown]
# ## 3. LRU Cache class ⭐⭐⭐
#
# Build `LRUCache(capacity)` with `get(key)` → value or -1, and `put(key,value)` — evicts least recently used when full.

# %%
class LRUCache:
    def __init__(self, capacity: int):
        pass

    def get(self, key: int) -> int:
        pass

    def put(self, key: int, value: int):
        pass

# %% [markdown]
# ## 4. MinStack class ⭐⭐⭐
#
# Build `MinStack` — same as Stack but `get_min()` returns the minimum in O(1).

# %%
class MinStack:
    def __init__(self):
        pass

    def push(self, val):
        pass

    def pop(self):
        pass

    def get_min(self):
        pass

# %% [markdown]
# ## 5. Iterator class ⭐⭐
#
# Make `NumberRange(start, end)` iterable — implement `__iter__` and `__next__`.
# ```python
# for n in NumberRange(1,5): print(n)  # 1 2 3 4 5
# ```

# %%
class NumberRange:
    def __init__(self, start, end):
        pass

    def __iter__(self):
        pass

    def __next__(self):
        pass

# %% [markdown]
# ## 6. Context manager class ⭐⭐
#
# Write `Timer` as a context manager using `__enter__` and `__exit__`.
# ```python
# with Timer() as t:
#     sum(range(1000000))
# print(t.elapsed)  # seconds
# ```

# %%
import time

class Timer:
    def __enter__(self):
        pass

    def __exit__(self, *args):
        pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
s=Stack()
s.push(1);s.push(2);s.push(3)
assert s.peek()==3
assert s.pop()==3
assert s.size()==2
assert not s.is_empty()
try: Stack().pop(); assert False
except IndexError: pass

q=Queue()
q.enqueue('a');q.enqueue('b');q.enqueue('c')
assert q.front()=='a'
assert q.dequeue()=='a'
assert q.size()==2

lru=LRUCache(2)
lru.put(1,1);lru.put(2,2)
assert lru.get(1)==1
lru.put(3,3)  # evicts key 2
assert lru.get(2)==-1

ms=MinStack()
ms.push(3);ms.push(1);ms.push(2)
assert ms.get_min()==1
ms.pop()
assert ms.get_min()==1
ms.pop()
assert ms.get_min()==3

assert list(NumberRange(1,5))==[1,2,3,4,5]

import time
with Timer() as t:
    time.sleep(0.01)
assert t.elapsed>=0.01
print('✅ All tests passed!')
