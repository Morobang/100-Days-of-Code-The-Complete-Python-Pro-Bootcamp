# %% [markdown]
# # Day 01 — Printing & Output
#
# > **Goal:** Understand how Python outputs text to the screen.

# %% [markdown]
# ## 📖 What is `print()`?
#
# `print()` is a built-in Python function that displays output on the screen.
#
# ```python
# print("Hello, World!")
# ```
#
# Run the cell below to see it in action:

# %%
print("Hello, World!")

# %% [markdown]
# ## 📖 Printing multiple things
#
# You can pass multiple values to `print()` separated by commas.
# Python puts a space between them by default.
#
# ```python
# print("Hello", "Rocket")
# ```

# %%
print("Hello", "Rocket")
print("I", "am", "learning", "Python")

# %% [markdown]
# ## 📖 The `sep` and `end` parameters
#
# - `sep` — what goes **between** values (default is a space)
# - `end` — what goes at the **end** of the line (default is `\n` — a new line)
#
# ```python
# print("a", "b", "c", sep="-")   # a-b-c
# print("Hello", end=" ")         # no newline after
# print("World")                  # prints on same line
# ```

# %%
print("a", "b", "c", sep="-")
print("Hello", end=" ")
print("World")

# %% [markdown]
# ## ✏️ Exercises
#
# ### Exercise 1
# Print your name, your city, and your favourite language on **three separate lines** using a single `print()` call.

# %%
# write your solution

# %% [markdown]
# ### Exercise 2
# Print the following pattern using `sep`:
#
# ```
# Python*is*awesome
# ```

# %%
# write your solution

# %% [markdown]
# ### Exercise 3
# Print these two lines so they appear on the **same line** in the output:
#
# ```
# Hello World!
# ```
#
# Using two separate `print()` calls.

# %%
# write your solution

# %% [markdown]
# ## ✅ Tests

# %%
# Manual check — run and visually confirm the output looks right
print("--- Exercise 1 ---")
# your Exercise 1 code here

print("--- Exercise 2 ---")
# your Exercise 2 code here

print("--- Exercise 3 ---")
# your Exercise 3 code here
