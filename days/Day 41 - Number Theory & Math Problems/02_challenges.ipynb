# %% [markdown]
# # Day 41 Challenges — Number Theory & Math Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. GCD of list ⭐
#
# Write `gcd_list(lst)` — return the GCD of all numbers in the list.

# %%
from math import gcd
from functools import reduce
def gcd_list(lst: list) -> int:
    pass

# %% [markdown]
# ## 2. LCM of list ⭐
#
# Write `lcm_list(lst)` — return the LCM of all numbers in the list.

# %%
from math import gcd
def lcm_list(lst: list) -> int:
    pass

# %% [markdown]
# ## 3. Is prime ⭐
#
# Write `is_prime(n)` — return True if n is prime.

# %%
def is_prime(n: int) -> bool:
    pass

# %% [markdown]
# ## 4. Count primes below n ⭐⭐
#
# Write `count_primes(n)` — count primes strictly less than n using the Sieve of Eratosthenes.

# %%
def count_primes(n: int) -> int:
    pass

# %% [markdown]
# ## 5. Prime factorisation ⭐⭐
#
# Write `prime_factors(n)` — return sorted list of prime factors (with repetition).
# ```
# prime_factors(360) → [2,2,2,3,3,5]
# ```

# %%
def prime_factors(n: int) -> list:
    pass

# %% [markdown]
# ## 6. Happy number ⭐⭐
#
# Write `is_happy(n)` — a happy number repeatedly replaces itself with the sum of squares of its digits until it reaches 1 (happy) or cycles (not happy).
# ```
# is_happy(19) → True  (1²+9²=82, 8²+2²=68, ...→1)
# ```

# %%
def is_happy(n: int) -> bool:
    pass

# %% [markdown]
# ## 7. Excel column title ⭐⭐
#
# Write `col_title(n)` — convert column number to Excel title.
# ```
# col_title(1)→'A'  col_title(28)→'AB'  col_title(701)→'ZY'
# ```

# %%
def col_title(n: int) -> str:
    pass

# %% [markdown]
# ## 8. Ugly numbers ⭐⭐
#
# Write `is_ugly(n)` — True if n's only prime factors are 2, 3, 5.
# Write `nth_ugly(n)` — return the nth ugly number.

# %%
def is_ugly(n: int) -> bool:
    pass

def nth_ugly(n: int) -> int:
    pass

# %% [markdown]
# ## 9. Integer to Roman ⭐⭐
#
# Write `to_roman(n)` — convert integer (1–3999) to Roman numeral.
# ```
# to_roman(1994) → 'MCMXCIV'
# ```

# %%
def to_roman(n: int) -> str:
    pass

# %% [markdown]
# ## 10. Roman to integer ⭐⭐
#
# Write `from_roman(s)` — convert Roman numeral to integer.
# ```
# from_roman('MCMXCIV') → 1994
# ```

# %%
def from_roman(s: str) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
from math import gcd
assert gcd_list([12,8,16]) == 4
assert lcm_list([4,6,8]) == 24
assert is_prime(7) == True
assert is_prime(9) == False
assert is_prime(2) == True
assert count_primes(10) == 4  # 2,3,5,7
assert prime_factors(360) == [2,2,2,3,3,5]
assert is_happy(19) == True
assert is_happy(4) == False
assert col_title(1) == 'A'
assert col_title(26) == 'Z'
assert col_title(28) == 'AB'
assert is_ugly(6) == True
assert is_ugly(14) == False
assert nth_ugly(10) == 12
assert to_roman(1994) == 'MCMXCIV'
assert to_roman(3) == 'III'
assert from_roman('MCMXCIV') == 1994
assert from_roman('III') == 3
print('✅ All tests passed!')
