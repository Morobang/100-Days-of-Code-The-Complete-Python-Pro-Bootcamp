# %% [markdown]
# # Day 66 Challenges — Data Visualisation with Matplotlib
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Line chart ⭐
#
# Write `plot_trend(dates, values, title)` — create a line chart with grid, labels, and title.

# %%
import matplotlib.pyplot as plt

def plot_trend(dates, values, title):
    fig,ax=plt.subplots(figsize=(10,4))
    # write your solution
    plt.tight_layout()
    return fig

# %% [markdown]
# ## 2. Bar chart ⭐
#
# Write `plot_bar(categories, values, title)` — horizontal bar chart sorted by value.

# %%
def plot_bar(categories, values, title):
    fig,ax=plt.subplots(figsize=(8,5))
    # write your solution
    return fig

# %% [markdown]
# ## 3. Scatter plot ⭐⭐
#
# Write `plot_scatter(x, y, labels=None)` — scatter plot with optional point labels and a trend line.

# %%
def plot_scatter(x, y, labels=None):
    fig,ax=plt.subplots(figsize=(8,6))
    # write your solution
    return fig

# %% [markdown]
# ## 4. Subplots ⭐⭐
#
# Write `four_charts(data)` — 2x2 grid of subplots: line, bar, scatter, histogram.

# %%
def four_charts(data):
    fig,axes=plt.subplots(2,2,figsize=(12,10))
    # write your solution
    return fig

# %% [markdown]
# ## 5. Save figure ⭐
#
# Write `save_chart(fig, filepath)` — save figure as PNG with 150 DPI.

# %%
def save_chart(fig, filepath):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
print('Run each challenge cell — check output manually')
print('✅ Complete!')
