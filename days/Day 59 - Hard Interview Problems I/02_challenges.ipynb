# %% [markdown]
# # Day 59 Challenges — Hard Interview Problems I
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Median of stream ⭐⭐⭐
#
# Implement `MedianFinder` with `add_num(n)` and `find_median()` — O(log n) add, O(1) find.

# %%
import heapq

class MedianFinder:
    def __init__(self):
        self.low = []   # max-heap (negate)
        self.high = []  # min-heap

    def add_num(self, num):
        pass

    def find_median(self):
        pass

# %% [markdown]
# ## 2. Trapping rain water ⭐⭐⭐
#
# Write `trap(heights)` — total water trapped. O(n) time, O(1) space.

# %%
def trap(heights):
    pass

# %% [markdown]
# ## 3. Largest rectangle histogram ⭐⭐⭐
#
# Write `largest_rectangle(heights)` — largest rectangle in a histogram.

# %%
def largest_rectangle(heights):
    pass

# %% [markdown]
# ## 4. Serialize/deserialize BST ⭐⭐⭐
#
# Write `serialize(root)` and `deserialize(data)` for a BST efficiently.

# %%
class TreeNode:
    def __init__(self,v): self.val=v; self.left=self.right=None

def serialize(root) -> str:
    pass

def deserialize(data: str):
    pass

# %% [markdown]
# ## 5. Word ladder ⭐⭐⭐
#
# Write `word_ladder(begin, end, word_list)` — min transformations (change one letter each step) from begin to end.
# ```
# word_ladder('hit','cog',['hot','dot','dog','lot','log','cog']) → 5
# ```

# %%
from collections import deque

def word_ladder(begin, end, word_list):
    pass

# %% [markdown]
# ## 6. Alien dictionary ⭐⭐⭐
#
# Write `alien_order(words)` — determine order of characters in alien language from sorted word list. Return '' if invalid.

# %%
from collections import defaultdict, deque

def alien_order(words):
    pass

# %% [markdown]
# ## 7. Max profit with cooldown ⭐⭐⭐
#
# Write `max_profit_cooldown(prices)` — max profit with 1-day cooldown after selling.

# %%
def max_profit_cooldown(prices):
    pass

# %% [markdown]
# ## 8. Minimum window with all chars ⭐⭐⭐
#
# Write `min_window(s, t)` — minimum window substring containing all of t.

# %%
from collections import defaultdict

def min_window(s, t):
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
import heapq

mf=MedianFinder()
mf.add_num(1); mf.add_num(2)
assert mf.find_median()==1.5
mf.add_num(3)
assert mf.find_median()==2.0

assert trap([0,1,0,2,1,0,1,3,2,1,2,1])==6
assert trap([4,2,0,3,2,5])==9

assert largest_rectangle([2,1,5,6,2,3])==10
assert largest_rectangle([2,4])==4

assert word_ladder('hit','cog',['hot','dot','dog','lot','log','cog'])==5
assert word_ladder('hit','cog',['hot','dot','dog','lot','log'])==0

assert max_profit_cooldown([1,2,3,0,2])==3
assert max_profit_cooldown([1])==0

assert min_window('ADOBECODEBANC','ABC')=='BANC'
assert min_window('a','a')=='a'
print('✅ All tests passed!')
