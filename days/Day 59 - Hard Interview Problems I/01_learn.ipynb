# %% [markdown]
# # Day 59 — Hard Interview Problems I
#
# > These require combining techniques. Read carefully, think first.
# > State your approach out loud before writing a single line.

# %% [markdown]
# ## Approach for hard problems
#
# 1. Understand the problem completely
# 2. Work through 2-3 examples by hand
# 3. Identify the pattern (DP? Graph? Segment tree?)
# 4. Code the solution
# 5. Test edge cases
