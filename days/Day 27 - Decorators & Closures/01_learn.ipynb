# %% [markdown]
# # Day 27 — Decorators & Closures
#
# > Add behaviour to functions without changing them. Used everywhere in real codebases.

# %% [markdown]
# ## Closures — inner function remembers outer scope

# %%
def make_adder(n):
    def add(x):
        return x + n   # n is remembered from outer scope
    return add

add5  = make_adder(5)
add10 = make_adder(10)
print(add5(3))   # 8
print(add10(3))  # 13

# %% [markdown]
# ## Basic decorator

# %%
from functools import wraps

def logger(func):
    @wraps(func)    # preserves func name & docstring
    def wrapper(*args, **kwargs):
        print(f'Calling {func.__name__}')
        result = func(*args, **kwargs)
        print(f'Done')
        return result
    return wrapper

@logger
def greet(name):
    return f'Hello {name}'

print(greet('Rocket'))

# %% [markdown]
# ## Decorator with arguments

# %%
def repeat(n):
    def decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            for _ in range(n):
                result = func(*args, **kwargs)
            return result
        return wrapper
    return decorator

@repeat(3)
def say_hi(): print('Hi!')

say_hi()
