# %% [markdown]
# # Day 41 Challenges — Number & Math Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. FizzBuzz (classic) ⭐
#
# Write `fizzbuzz(n)` — return list of strings 1..n. Multiples of 3→Fizz, 5→Buzz, both→FizzBuzz.

# %%
def fizzbuzz(n: int) -> list:
    pass

# %% [markdown]
# ## 2. Count digits ⭐
#
# Write `count_digits(n)` — return a dict of each digit and how many times it appears in n.
# ```
# count_digits(12231) → {'1':2,'2':2,'3':1}
# ```

# %%
def count_digits(n: int) -> dict:
    pass

# %% [markdown]
# ## 3. Is palindrome number ⭐
#
# Write `is_palindrome_num(n)` — True if n reads the same forwards and backwards. No string conversion.

# %%
def is_palindrome_num(n: int) -> bool:
    pass

# %% [markdown]
# ## 4. Prime factors ⭐⭐
#
# Write `prime_factors(n)` — return sorted list of all prime factors.
# ```
# prime_factors(12) → [2,2,3]
# prime_factors(7)  → [7]
# ```

# %%
def prime_factors(n: int) -> list:
    pass

# %% [markdown]
# ## 5. GCD and LCM ⭐
#
# Write `my_gcd(a,b)` using Euclidean algorithm (no `math.gcd`).
# Write `my_lcm(a,b)` using your gcd.

# %%
def my_gcd(a: int, b: int) -> int:
    pass

def my_lcm(a: int, b: int) -> int:
    pass

# %% [markdown]
# ## 6. Power of three ⭐⭐
#
# Write `is_power_of_three(n)` — True if n is a power of 3. O(1) solution.

# %%
def is_power_of_three(n: int) -> bool:
    pass

# %% [markdown]
# ## 7. Roman to integer ⭐⭐
#
# Write `roman_to_int(s)` — convert a Roman numeral string to an integer.
# ```
# roman_to_int('XIV') → 14
# roman_to_int('IX')  → 9
# ```

# %%
def roman_to_int(s: str) -> int:
    pass

# %% [markdown]
# ## 8. Integer to Roman ⭐⭐
#
# Write `int_to_roman(n)` — convert an integer (1-3999) to Roman numerals.

# %%
def int_to_roman(n: int) -> str:
    pass

# %% [markdown]
# ## 9. Square root without sqrt ⭐⭐
#
# Write `int_sqrt(n)` — return the integer square root of n (floor). No `math.sqrt`.

# %%
def int_sqrt(n: int) -> int:
    pass

# %% [markdown]
# ## 10. Happy number ⭐⭐
#
# Write `is_happy(n)` — a happy number eventually reaches 1 when replaced by the sum of squares of digits.
# ```
# is_happy(19) → True  (19→82→68→100→1)
# ```

# %%
def is_happy(n: int) -> bool:
    pass

# %% [markdown]
# ## 11. Count primes ⭐⭐⭐
#
# Write `count_primes(n)` — count primes less than n. Use Sieve of Eratosthenes.

# %%
def count_primes(n: int) -> int:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
fb=fizzbuzz(15)
assert fb[2]=='Fizz' and fb[4]=='Buzz' and fb[14]=='FizzBuzz'

assert count_digits(12231)=={'1':2,'2':2,'3':1}

assert is_palindrome_num(121)==True
assert is_palindrome_num(-121)==False
assert is_palindrome_num(10)==False

assert prime_factors(12)==[2,2,3]
assert prime_factors(7)==[7]

assert my_gcd(48,18)==6
assert my_lcm(4,6)==12

assert is_power_of_three(27)==True
assert is_power_of_three(0)==False
assert is_power_of_three(45)==False

assert roman_to_int('XIV')==14
assert roman_to_int('IX')==9
assert roman_to_int('MCMXCIV')==1994

assert int_to_roman(14)=='XIV'
assert int_to_roman(1994)=='MCMXCIV'

assert int_sqrt(8)==2
assert int_sqrt(9)==3

assert is_happy(19)==True
assert is_happy(2)==False

assert count_primes(10)==4
assert count_primes(100)==25
print('✅ All tests passed!')
