# %% [markdown]
# # Day 50 Challenges — Mini Project: Algorithm Visualiser CLI
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Step generators ⭐⭐
#
# Write step generators for bubble sort AND insertion sort. Each yields `(list_state, highlighted_indices)` at each meaningful step.

# %%
def bubble_sort_steps(lst: list):
    """Yield (state, (i,j)) at each comparison."""
    pass

def insertion_sort_steps(lst: list):
    """Yield (state, (i,j)) at each comparison."""
    pass

# %% [markdown]
# ## 2. Renderer ⭐
#
# Write `render(state, highlighted=())` — print the list with `^` markers under highlighted indices.
# ```
# state=[3,1,2], highlighted=(1,2)
# → [3, 1, 2]
#       ^  ^
# ```

# %%
def render(state: list, highlighted: tuple = ()):
    pass

# %% [markdown]
# ## 3. Stats tracker ⭐⭐
#
# Write `run_with_stats(algo_steps, lst)` — run the step generator, count steps and return `(sorted_list, steps, comparisons)`.

# %%
def run_with_stats(algo_steps, lst: list) -> tuple:
    pass

# %% [markdown]
# ## 4. Compare algorithms ⭐⭐
#
# Write `compare_sorts(lst)` — run bubble, insertion, and merge sort on the same list, print a comparison table of steps.
# ```
# Algorithm      Steps
# Bubble Sort    20
# Insertion Sort 12
# Merge Sort     15
# ```

# %%
def compare_sorts(lst: list):
    pass

# %% [markdown]
# ## 5. 50-day reflection ⭐
#
# In the cell below, answer:
# 1. What's the hardest topic so far?
# 2. What pattern have you seen most?
# 3. What will you focus on next?

# %%
# Write your reflection here as comments
# 1. Hardest topic:
# 2. Most common pattern:
# 3. Focus for next 50 days:

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
steps=list(bubble_sort_steps([3,1,2]))
assert steps[-1][0]==[1,2,3]
assert len(steps)>1

steps2=list(insertion_sort_steps([5,3,1,4,2]))
assert steps2[-1][0]==[1,2,3,4,5]

# render — visual check
render([3,1,2],(1,2))

sorted_lst,steps,cmps=run_with_stats(bubble_sort_steps,[4,3,2,1])
assert sorted_lst==[1,2,3,4]
assert steps>0 and cmps>0

compare_sorts([5,3,8,1,9,2,7,4,6])
print('✅ Day 50 complete! Halfway there!')
