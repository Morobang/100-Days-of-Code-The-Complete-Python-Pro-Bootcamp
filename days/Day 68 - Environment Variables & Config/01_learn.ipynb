# %% [markdown]
# # Day 68 — Environment Variables & Config
#
# > See `notes.md` for syntax reference and key patterns.

# %% [markdown]
# ## Core concepts
#
# This day covers **Environment Variables & Config**. Work through the notes first, then tackle the challenges.
