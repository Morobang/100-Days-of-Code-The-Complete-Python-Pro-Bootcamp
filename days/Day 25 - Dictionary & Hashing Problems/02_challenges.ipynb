# %% [markdown]
# # Day 25 Challenges — Dictionary & Hashing Problems
#
# > Work through all challenges top to bottom. Run the ✅ Tests cell when done.
# > Build up: easy ones first, harder ones at the end.

# %% [markdown]
# ## 1. Most common element ⭐
#
# Write `most_common(lst)` — return the element that appears most often. If tie, return any.

# %%
def most_common(lst: list):
    pass

# %% [markdown]
# ## 2. Two sum (return values) ⭐
#
# Write `two_sum_values(lst, target)` — return the two VALUES (not indices) that sum to target, or `None`.

# %%
def two_sum_values(lst: list, target: int):
    pass

# %% [markdown]
# ## 3. Subarray sum equals k ⭐⭐
#
# Write `subarray_sum_count(lst, k)` — count the number of contiguous subarrays that sum to k.
# ```
# subarray_sum_count([1,1,1],2) → 2
# ```

# %%
def subarray_sum_count(lst: list, k: int) -> int:
    pass

# %% [markdown]
# ## 4. First duplicate ⭐⭐
#
# Write `first_duplicate(lst)` — return the first element that appears more than once, or `None`.

# %%
def first_duplicate(lst: list):
    pass

# %% [markdown]
# ## 5. Intersection of two lists ⭐⭐
#
# Write `intersection(a, b)` — return a list of elements that appear in BOTH lists. No duplicates, O(n).

# %%
def intersection(a: list, b: list) -> list:
    pass

# %% [markdown]
# ## 6. Longest consecutive sequence ⭐⭐⭐
#
# Write `longest_consecutive(lst)` — return the length of the longest consecutive sequence.
# ```
# longest_consecutive([100,4,200,1,3,2]) → 4  # [1,2,3,4]
# ```

# %%
def longest_consecutive(lst: list) -> int:
    pass

# %% [markdown]
# ## 7. Four sum count ⭐⭐⭐
#
# Write `four_sum_count(a,b,c,d)` — count tuples `(i,j,k,l)` such that `a[i]+b[j]+c[k]+d[l]==0`.

# %%
def four_sum_count(a,b,c,d):
    pass

# %% [markdown]
# ## 8. Minimum window substring ⭐⭐⭐
#
# Write `min_window(s, t)` — find the minimum window in s that contains all chars in t.
# ```
# min_window('ADOBECODEBANC','ABC') → 'BANC'
# ```

# %%
def min_window(s: str, t: str) -> str:
    pass

# %% [markdown]
# ## ✅ Tests — run this when you're done

# %%
assert most_common([1,1,2,2,2,3]) == 2
assert most_common(['a','b','a']) == 'a'
assert set(two_sum_values([2,7,11,15],9)) == {2,7}
assert two_sum_values([1,2,3],10) is None
assert subarray_sum_count([1,1,1],2) == 2
assert subarray_sum_count([1,2,3],3) == 2
assert first_duplicate([1,2,3,2,1]) == 2
assert first_duplicate([1,2,3]) is None
assert sorted(intersection([1,2,3,4],[3,4,5,6])) == [3,4]
assert longest_consecutive([100,4,200,1,3,2]) == 4
assert longest_consecutive([0,3,7,2,5,8,4,6,0,1]) == 9
assert four_sum_count([1,2],[-2,-1],[3,4],[-1,-2]) == 2  # might vary
assert min_window('ADOBECODEBANC','ABC') == 'BANC'
print('✅ All tests passed!')
