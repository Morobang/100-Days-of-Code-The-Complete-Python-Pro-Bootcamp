# %% [markdown]
# # Day 014 — OOP: Dunder / magic methods
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Vector class with operator overloading
#
# Build `Vector2D(x, y)` supporting:
# - `__add__`, `__sub__`, `__mul__` (scalar)
# - `__len__` → always 2
# - `__eq__` → compare by values
# - `__str__` → `'Vector2D(3, 4)'`
# - `magnitude()` → `sqrt(x²+y²)`

# %%
import math

class Vector2D:
    def __init__(self, x, y):
        # write your solution
        pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
v1 = Vector2D(1, 2)
v2 = Vector2D(3, 4)
assert v1 + v2 == Vector2D(4, 6)
assert v1 - v2 == Vector2D(-2, -2)
assert v1 * 3 == Vector2D(3, 6)
assert len(v1) == 2
assert round(Vector2D(3,4).magnitude(), 2) == 5.0
assert str(v1) == 'Vector2D(1, 2)'
print('✅ All tests passed!')
