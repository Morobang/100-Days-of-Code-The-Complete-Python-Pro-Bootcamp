# %% [markdown]
# # Day 011 — OOP: Classes & Objects
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Your first class
#
# Build a `Person` class:
# - `__init__(name, age)`
# - `greet()` → `'Hi, I am Rocket and I am 23 years old'`
# - `is_adult()` → True if age >= 18
# - `__str__` → `'Person(Rocket, 23)'`

# %%
class Person:
    def __init__(self, name: str, age: int):
        # write your solution
        pass

    def greet(self) -> str:
        pass

    def is_adult(self) -> bool:
        pass

    def __str__(self) -> str:
        pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
p = Person('Rocket', 23)
assert p.name == 'Rocket'
assert p.age == 23
assert p.greet() == 'Hi, I am Rocket and I am 23 years old'
assert p.is_adult() == True
assert str(p) == 'Person(Rocket, 23)'
assert Person('Kid', 10).is_adult() == False
print('✅ All tests passed!')
