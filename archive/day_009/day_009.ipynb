# %% [markdown]
# # Day 009 — Functions: basics & scope
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Function basics & scope
#
# Write `make_counter(start=0)` — returns a function that increments and returns a counter each call.
# Write `apply_twice(fn, x)` — applies `fn` to `x` twice.

# %%
def make_counter(start: int = 0):
    # write your solution — use closure
    pass

def apply_twice(fn, x):
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Scope rules
#
# Predict and then verify what each snippet prints. Write `demonstrate_scope()` that returns a tuple of three values showing how local, enclosing, and global scope work.

# %%
x = 'global'

def demonstrate_scope():
    x = 'enclosing'
    def inner():
        x = 'local'
        return x
    inner_val = inner()
    # return (global x, enclosing x, inner_val)
    # write your solution — what does each scope see?
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
counter = make_counter()
assert counter() == 1
assert counter() == 2
assert counter() == 3
c2 = make_counter(10)
assert c2() == 11
assert apply_twice(lambda x: x*2, 3) == 12
result = demonstrate_scope()
assert result == ('global', 'enclosing', 'local'), f'Got {result}'
print('✅ All tests passed!')
