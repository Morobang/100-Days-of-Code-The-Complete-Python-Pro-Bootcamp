# %% [markdown]
# # Day 016 — OOP: Polymorphism
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Animal sound polymorphism
#
# Create `Animal` base with `speak()`. Subclasses `Dog`, `Cat`, `Duck` each override `speak()`. Write `make_sounds(animals)` → list of each animal's sound.

# %%
class Animal:
    def speak(self) -> str:
        raise NotImplementedError

class Dog(Animal):
    # write your solution
    pass

class Cat(Animal):
    # write your solution
    pass

class Duck(Animal):
    # write your solution
    pass

def make_sounds(animals: list) -> list:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
sounds = make_sounds([Dog(), Cat(), Duck()])
assert sounds == ['Woof!', 'Meow!', 'Quack!']
print('✅ All tests passed!')
