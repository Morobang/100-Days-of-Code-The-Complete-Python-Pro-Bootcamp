# %% [markdown]
# # Day 010 — Functions: *args, **kwargs & returns
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: *args and **kwargs
#
# Write `total(*args)` — sum any number of numeric args.
# Write `describe(**kwargs)` — return a string like `'name=Rocket age=23'` (sorted keys).
# Write `flexible(required, *args, **kwargs)` — return a dict with keys `required`, `extras` (list), `options` (dict).

# %%
def total(*args) -> float:
    # write your solution
    pass

def describe(**kwargs) -> str:
    # write your solution
    pass

def flexible(required, *args, **kwargs) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Docstrings & type hints
#
# Rewrite the `bmi(weight_kg, height_m)` function with proper type hints and a Google-style docstring. Return the BMI as a float rounded to 1 decimal place.

# %%
def bmi(weight_kg: float, height_m: float) -> float:
    """
    # write a proper Google-style docstring here
    """
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert total(1,2,3) == 6
assert total(1.5, 2.5) == 4.0
assert total() == 0
assert describe(name='Rocket', age=23) == 'age=23 name=Rocket'
result = flexible('hello', 1, 2, x=10, y=20)
assert result == {'required':'hello','extras':[1,2],'options':{'x':10,'y':20}}
assert bmi(70, 1.75) == 22.9
assert bmi(90, 1.80) == 27.8
assert bmi.__doc__ is not None, 'Add a docstring!'
print('✅ All tests passed!')
