# %% [markdown]
# # Day 003 — Lists
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Second largest
#
# Write `second_largest(lst)` — return the second largest **unique** value. Raise `ValueError` if fewer than 2 unique values.

# %%
def second_largest(lst: list) -> int:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Rotate list
#
# Write `rotate(lst, n)` — rotate the list **right** by n positions.

# %%
def rotate(lst: list, n: int) -> list:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 3: Chunk list
#
# Write `chunk(lst, size)` — split into sublists of given size. Last chunk may be smaller.

# %%
def chunk(lst: list, size: int) -> list:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert second_largest([3,1,4,1,5,9]) == 5
assert second_largest([5,3]) == 3
try:
    second_largest([1,1,1])
    assert False
except ValueError:
    pass
assert rotate([1,2,3,4,5], 2) == [4,5,1,2,3]
assert rotate([1,2,3], 1) == [3,1,2]
assert rotate([1,2,3], 0) == [1,2,3]
assert chunk([1,2,3,4,5,6,7], 3) == [[1,2,3],[4,5,6],[7]]
assert chunk([1,2], 5) == [[1,2]]
print('✅ All tests passed!')
