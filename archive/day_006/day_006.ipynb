# %% [markdown]
# # Day 006 — Dictionaries
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Group by key
#
# Write `group_by(lst, key_fn)` — group items by the result of `key_fn`.

# %%
def group_by(lst: list, key_fn) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Invert dict
#
# Write `invert_dict(d)` — swap keys and values. Raise `ValueError` if values aren't unique.

# %%
def invert_dict(d: dict) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 3: Most common element
#
# Write `most_common(lst)` — return the element that appears most often.

# %%
def most_common(lst: list):
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
result = group_by(['hi','hello','hey','ok','wow'], lambda w: w[0])
assert result['h'] == ['hi','hello','hey']
assert result['o'] == ['ok']
assert invert_dict({'a':1,'b':2}) == {1:'a',2:'b'}
try:
    invert_dict({'a':1,'b':1})
    assert False
except ValueError:
    pass
assert most_common([1,1,2,2,2,3]) == 2
assert most_common(['a','b','a']) == 'a'
print('✅ All tests passed!')
