# %% [markdown]
# # Day 002 — String Methods
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Caesar cipher
#
# Write `caesar_encrypt(text, shift)` and `caesar_decrypt(text, shift)`.
# Only shift alphabetic characters. Wrap around: z+1 → a.

# %%
def caesar_encrypt(text: str, shift: int) -> str:
    # write your solution
    pass

def caesar_decrypt(text: str, shift: int) -> str:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Word frequency
#
# Write `word_frequency(text)` → dict of word → count. Lowercase everything, strip `.,!?` from each word.

# %%
def word_frequency(text: str) -> dict:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 3: Run-length encoding
#
# Write `compress(s)` — encode consecutive repeated chars as `charN`. Single chars stay as-is.

# %%
def compress(s: str) -> str:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert caesar_encrypt('hello', 3) == 'khoor'
assert caesar_decrypt('khoor', 3) == 'hello'
assert caesar_encrypt('xyz', 2) == 'zab'
assert caesar_encrypt('Hello!', 1) == 'Ifmmp!'
freq = word_frequency('the cat sat on the mat the cat')
assert freq['the'] == 3
assert freq['cat'] == 2
assert freq['sat'] == 1
assert compress('aaabbc') == 'a3b2c'
assert compress('abcd') == 'abcd'
assert compress('aaaa') == 'a4'
assert compress('') == ''
print('✅ All tests passed!')
