# %% [markdown]
# # Day 007 — Control Flow: if / elif / else
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: FizzBuzz + Collatz
#
# Write `fizzbuzz(n)` → list of strings 1 to n (Fizz/Buzz/FizzBuzz/number).
# Write `collatz(n)` → full Collatz sequence starting at n.

# %%
def fizzbuzz(n: int) -> list:
    # write your solution
    pass

def collatz(n: int) -> list:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Nested conditionals
#
# Write `grade(score)` → 'A' (90+), 'B' (80+), 'C' (70+), 'D' (60+), 'F' (below 60).
# Write `bmi_category(bmi)` → 'Underweight' (<18.5), 'Normal' (<25), 'Overweight' (<30), 'Obese' (30+).

# %%
def grade(score: int) -> str:
    # write your solution
    pass

def bmi_category(bmi: float) -> str:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
fb = fizzbuzz(15)
assert fb[2] == 'Fizz'
assert fb[4] == 'Buzz'
assert fb[14] == 'FizzBuzz'
assert collatz(6) == [6,3,10,5,16,8,4,2,1]
assert grade(95) == 'A'
assert grade(83) == 'B'
assert grade(55) == 'F'
assert bmi_category(17.0) == 'Underweight'
assert bmi_category(22.0) == 'Normal'
assert bmi_category(32.0) == 'Obese'
print('✅ All tests passed!')
