# %% [markdown]
# # Day 018 — OOP: Class methods & static methods
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Date utility class
#
# Build `DateHelper` with:
# - `@staticmethod is_leap_year(year)` → True/False
# - `@staticmethod days_in_month(year, month)` → int
# - `@classmethod today_info(cls)` → dict with year/month/day from `datetime.date.today()`

# %%
from datetime import date

class DateHelper:
    @staticmethod
    def is_leap_year(year: int) -> bool:
        # write your solution
        pass

    @staticmethod
    def days_in_month(year: int, month: int) -> int:
        # write your solution
        pass

    @classmethod
    def today_info(cls) -> dict:
        # write your solution
        pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert DateHelper.is_leap_year(2000) == True
assert DateHelper.is_leap_year(1900) == False
assert DateHelper.days_in_month(2024, 2) == 29
assert DateHelper.days_in_month(2023, 2) == 28
assert DateHelper.days_in_month(2024, 1) == 31
info = DateHelper.today_info()
assert 'year' in info and 'month' in info and 'day' in info
print('✅ All tests passed!')
