# %% [markdown]
# # Day 004 — List Methods & Slicing
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: List methods drill
#
# Write `deduplicate(lst)` — remove duplicates preserving first-seen order (no set conversion of the whole list).
# Write `flatten_one(lst)` — flatten exactly one level of nesting.

# %%
def deduplicate(lst: list) -> list:
    # write your solution
    pass

def flatten_one(lst: list) -> list:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Matrix transpose
#
# Write `transpose(matrix)` — flip rows and columns of a 2D list.

# %%
def transpose(matrix: list) -> list:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert deduplicate([1,2,2,3,1,4]) == [1,2,3,4]
assert deduplicate(['a','b','a','c']) == ['a','b','c']
assert flatten_one([[1,2],[3,[4,5]],6]) == [1,2,3,[4,5],6]
assert flatten_one([1,2,3]) == [1,2,3]
assert transpose([[1,2,3],[4,5,6]]) == [[1,4],[2,5],[3,6]]
assert transpose([[1,2],[3,4]]) == [[1,3],[2,4]]
print('✅ All tests passed!')
