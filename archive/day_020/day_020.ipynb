# %% [markdown]
# # Day 020 — OOP Capstone: Inventory system
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Product inventory
#
# Build `Product(name, price, quantity)` and `Inventory` class.
# `Inventory`: `add_product(p)`, `remove_product(name)`, `get_product(name)`, `total_value()` → sum of price*qty, `low_stock(threshold=5)` → list of products below threshold.

# %%
class Product:
    def __init__(self, name: str, price: float, quantity: int):
        # write your solution
        pass

class Inventory:
    def __init__(self):
        # write your solution
        pass

    def add_product(self, product: Product):
        pass

    def remove_product(self, name: str):
        pass

    def get_product(self, name: str) -> Product:
        pass

    def total_value(self) -> float:
        pass

    def low_stock(self, threshold: int = 5) -> list:
        pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
inv = Inventory()
inv.add_product(Product('Widget', 9.99, 100))
inv.add_product(Product('Gadget', 24.99, 3))
assert inv.total_value() == 9.99*100 + 24.99*3
assert inv.get_product('Widget').price == 9.99
low = inv.low_stock(5)
assert len(low) == 1 and low[0].name == 'Gadget'
inv.remove_product('Widget')
assert inv.get_product('Widget') is None
print('✅ All tests passed!')
