# %% [markdown]
# # Day 013 — OOP: Methods & self
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Temperature converter class
#
# Build `Temperature` with:
# - `__init__(celsius)`
# - `to_fahrenheit()` → C * 9/5 + 32
# - `to_kelvin()` → C + 273.15
# - `@classmethod from_fahrenheit(cls, f)` → create from Fahrenheit

# %%
class Temperature:
    def __init__(self, celsius: float):
        # write your solution
        pass

    def to_fahrenheit(self) -> float:
        pass

    def to_kelvin(self) -> float:
        pass

    @classmethod
    def from_fahrenheit(cls, f: float):
        pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
t = Temperature(100)
assert t.to_fahrenheit() == 212.0
assert t.to_kelvin() == 373.15
t2 = Temperature.from_fahrenheit(32)
assert t2.celsius == 0.0
print('✅ All tests passed!')
