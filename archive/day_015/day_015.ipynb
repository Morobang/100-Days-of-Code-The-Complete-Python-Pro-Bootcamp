# %% [markdown]
# # Day 015 — OOP: Inheritance & super()
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Shape hierarchy
#
# Build `Shape` base class with `area()` and `perimeter()` raising NotImplementedError.
# Implement `Circle(radius)` and `Rectangle(width, height)` and `Square(side)` inheriting appropriately.

# %%
import math

class Shape:
    def area(self): raise NotImplementedError
    def perimeter(self): raise NotImplementedError

class Circle(Shape):
    def __init__(self, radius):
        # write your solution
        pass

class Rectangle(Shape):
    def __init__(self, width, height):
        # write your solution
        pass

class Square(Rectangle):
    def __init__(self, side):
        # write your solution
        pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert round(Circle(5).area(), 2) == 78.54
assert Rectangle(4,3).area() == 12
assert Square(4).area() == 16
assert Square(4).perimeter() == 16
print('✅ All tests passed!')
