# %% [markdown]
# # Day 017 — OOP: Encapsulation & @property
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Circle with radius validation
#
# Build `Circle` where radius is a property. Setter raises `ValueError` for negative values. Add a read-only `diameter` property and an `area` property.

# %%
import math

class Circle:
    def __init__(self, radius: float):
        # write your solution
        pass

    @property
    def radius(self):
        pass

    @radius.setter
    def radius(self, value):
        pass

    @property
    def diameter(self):
        pass

    @property
    def area(self):
        pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
c = Circle(5)
assert c.radius == 5
assert c.diameter == 10
assert round(c.area, 2) == 78.54
c.radius = 10
assert c.diameter == 20
try:
    c.radius = -1
    assert False
except ValueError:
    pass
print('✅ All tests passed!')
