# %% [markdown]
# # Day 008 — Loops: for & while
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Loop patterns
#
# Write `primes_up_to(n)` using the Sieve of Eratosthenes.
# Write `pascals_triangle(rows)` → list of lists.

# %%
def primes_up_to(n: int) -> list:
    # write your solution
    pass

def pascals_triangle(rows: int) -> list:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: While loop patterns
#
# Write `digit_sum(n)` → sum of digits of integer n.
# Write `is_power_of_two(n)` → True if n is a power of 2 (n > 0).

# %%
def digit_sum(n: int) -> int:
    # write your solution
    pass

def is_power_of_two(n: int) -> bool:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert primes_up_to(20) == [2,3,5,7,11,13,17,19]
assert pascals_triangle(4) == [[1],[1,1],[1,2,1],[1,3,3,1]]
assert digit_sum(1234) == 10
assert digit_sum(0) == 0
assert is_power_of_two(8) == True
assert is_power_of_two(6) == False
assert is_power_of_two(1) == True
print('✅ All tests passed!')
