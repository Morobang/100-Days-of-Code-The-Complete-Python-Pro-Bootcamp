# %% [markdown]
# # Day 001 — String Basics
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Reverse a string
#
# Write `reverse_string(s)` that returns `s` reversed. Use slicing — no loops.

# %%
def reverse_string(s: str) -> str:
    # write your solution
    return s[::-1]
    pass

# %% [markdown]
# ## Exercise 2: Count vowels
#
# Write `count_vowels(s)` — count vowels (a,e,i,o,u), case-insensitive.

# %%
def count_vowels(s: str) -> int:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 3: Is palindrome
#
# Write `is_palindrome(s)` — True if `s` reads the same forwards and backwards. Ignore case.

# %%
def is_palindrome(s: str) -> bool:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert reverse_string('hello') == 'olleh'
assert reverse_string('Rocket') == 'tekcoR'
assert reverse_string('a') == 'a'
assert count_vowels('Hello World') == 3
assert count_vowels('AEIOU') == 5
assert count_vowels('bcdfg') == 0
assert is_palindrome('racecar') == True
assert is_palindrome('Racecar') == True
assert is_palindrome('hello') == False
print('✅ All tests passed!')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 assert reverse_string('hello') == 'olleh'
#       2 assert reverse_string('Rocket') == 'tekcoR'
#       3 assert reverse_string('a') == 'a'
#
# AssertionError:
