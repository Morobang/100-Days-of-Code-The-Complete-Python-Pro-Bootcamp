# %% [markdown]
# # Day 005 — Tuples & Sets
#
# > Read `notes.md` first, then attempt each exercise below.
# > Run the ✅ Tests cell at the end to check your work.
# > Only open `solution.py` after you've made a genuine attempt.

# %% [markdown]
# ## Exercise 1: Tuples & unpacking
#
# Write `minmax(lst)` → return `(min, max)` as a tuple.
# Write `unzip(pairs)` → given a list of 2-tuples, return two lists.
# ```
# unzip([(1,'a'),(2,'b'),(3,'c')]) → ([1,2,3], ['a','b','c'])
# ```

# %%
def minmax(lst: list) -> tuple:
    # write your solution
    pass

def unzip(pairs: list) -> tuple:
    # write your solution
    pass

# %% [markdown]
# ## Exercise 2: Set operations
#
# Write `common_elements(a, b)` — elements in both lists (no duplicates).
# Write `unique_to_first(a, b)` — elements in `a` but not in `b`.

# %%
def common_elements(a: list, b: list) -> list:
    # write your solution
    pass

def unique_to_first(a: list, b: list) -> list:
    # write your solution
    pass

# %% [markdown]
# ## ✅ Tests
#
# Run this cell after completing all exercises above.

# %%
assert minmax([3,1,4,1,5,9]) == (1, 9)
nums, letters = unzip([(1,'a'),(2,'b'),(3,'c')])
assert nums == [1,2,3]
assert letters == ['a','b','c']
assert sorted(common_elements([1,2,3,4],[3,4,5,6])) == [3,4]
assert sorted(unique_to_first([1,2,3],[2,3,4])) == [1]
print('✅ All tests passed!')
